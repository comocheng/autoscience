# %%
# check against table 7

# %%
import cantera as ct
import numpy as np
import pandas as pd
import concurrent.futures


import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# # Load the model
# cti_path = '/work/westgroup/harris.se/autoscience/autoscience/butane/rmg_model/chem_annotated.cti'
# cti_path = '/work/westgroup/harris.se/autoscience/aramco/AramcoMech3.0.MECH.cti'
# cti_path = '/scratch/harris.se/autoscience/not_correlated/models/chem_0174.cti'

# cti_path = '/work/westgroup/harris.se/autoscience/fuels/butane/butane_rmg_1week/cantera/chem_annotated_fixed.cti'  # 1 week butane run


# cti_path = '/work/westgroup/harris.se/autoscience/autoscience/butane/improved_models/chem_2022-08-22.cti'


# cti_path = '/work/westgroup/harris.se/autoscience/fuels/butane/butane_rmg_1week/cantera/chem_edge_annotated_fixed.cti'

# cti_path = '/scratch/harris.se/autoscience/local_sensitivity/models/chem_0288.cti'
# cti_path = '/scratch/harris.se/autoscience/local_sensitivity/models/chem_0748.cti'

# cti_path = '/work/westgroup/harris.se/autoscience/autoscience/butane/improved_models/chem_2022-08-23.cti'
# cti_path = '/work/westgroup/harris.se/autoscience/autoscience/butane/improved_models/chem_2022-08-24.cti'
# cti_path = '/work/westgroup/harris.se/autoscience/autoscience/butane/improved_models/chem_2022-09-08.cti'
# cti_path = '/work/westgroup/harris.se/autoscience/autoscience/butane/improved_models/thermo_only.cti'

# cti_path = '/work/westgroup/harris.se/autoscience/autoscience/butane/improved_models/thermo_debug/thermo_only.cti'
# cti_path = '/work/westgroup/harris.se/autoscience/autoscience/butane/improved_models/thermo_debug/thermo_only_79.cti'
# cti_path = '/work/westgroup/harris.se/autoscience/autoscience/butane/improved_models/thermo_debug/thermo_only_83.cti'
# cti_path = '/work/westgroup/harris.se/autoscience/autoscience/butane/models/improved_models/thermo_debug/thermo_only_85.cti'  # this one goes wild
# cti_path = '/work/westgroup/harris.se/autoscience/autoscience/butane/improved_models/thermo_debug/thermo_only_88.cti'
# cti_path = '/work/westgroup/harris.se/autoscience/autoscience/butane/improved_models/thermo_debug/thermo_only_92.cti'
# cti_path = '/work/westgroup/harris.se/autoscience/autoscience/butane/improved_models/thermo_debug/thermo_only_96.cti'
# cti_path = '/work/westgroup/harris.se/autoscience/autoscience/butane/improved_models/thermo_debug/thermo_only_101.cti'
# cti_path = '/work/westgroup/harris.se/autoscience/autoscience/butane/improved_models/thermo_debug/thermo_only_102.cti'
# cti_path = '/work/westgroup/harris.se/autoscience/autoscience/butane/improved_models/thermo_debug/thermo_only_103.cti'
# cti_path = '/work/westgroup/harris.se/autoscience/autoscience/butane/improved_models/thermo_debug/thermo_only_102.cti'

# cti_path = '/work/westgroup/harris.se/autoscience/autoscience/butane/models/rmg_small_core/chem_annotated.cti'
# cti_path = '/work/westgroup/harris.se/autoscience/autoscience/butane/models/rmg_small_core/improved_20220914.cti'


# cti_path = '/work/westgroup/harris.se/autoscience/fuels/butane/rmg_nolib24/cantera/chem_annotated.cti'

# cti_path = '/scratch/harris.se/autoscience/naive_model/changed_models/chem_2022-08-25.cti'

# cti_path = '/work/westgroup/harris.se/autoscience/autoscience/butane/models/improved_models/all_thermo_20220922.cti'
# cti_path = '/work/westgroup/harris.se/autoscience/autoscience/butane/models/rmg_model/all_thermo_no85rotor_20220922.cti'

# cti_path = '/work/westgroup/harris.se/autoscience/autoscience/butane/models/rmg_small_core/all_thermo_no85rotor_20220922.cti'

# cti_path = '/work/westgroup/harris.se/autoscience/autoscience/butane/models/rmg_model/no_thermo_20220922.cti'
# cti_path = '/work/westgroup/harris.se/autoscience/autoscience/butane/models/rmg_small_core/no_thermo_20220922.cti'

# cti_path = '/work/westgroup/harris.se/autoscience/autoscience/butane/models/naive_rmg_model/chem_annotated.cti'

# cti_path = '/work/westgroup/harris.se/autoscience/autoscience/butane/models/rmg_model/all_rxn_thermo_20220923.cti'

cti_path = '/work/westgroup/harris.se/autoscience/autoscience/butane/models/rmg_model/only_gav_and_rxns_20220923.cti'
# cti_path = '/work/westgroup/harris.se/autoscience/autoscience/butane/models/rmg_model/only_kinetics_20220923.cti'
cti_path = '/work/westgroup/harris.se/autoscience/autoscience/butane/models/rmg_small_core/only_gav_and_rxns_20220923.cti'

cti_path = '/work/westgroup/harris.se/autoscience/autoscience/butane/models/rmg_small_core/only_rxns_20220923.cti'


cti_path = '/work/westgroup/harris.se/autoscience/autoscience/debug/individuals/top10_mech.cti'
cti_path = '/work/westgroup/harris.se/autoscience/autoscience/debug/individuals/rxns_only.cti'


cti_path = '/work/westgroup/harris.se/autoscience/autoscience/debug/thermo85/only_4rxns_20221006.cti'
cti_path = '/work/westgroup/harris.se/autoscience/autoscience/debug/thermo85/sp85_and_modified4.cti'
cti_path = '/work/westgroup/harris.se/autoscience/autoscience/debug/thermo85/sp85_only.cti'
# cti_path = '/work/westgroup/harris.se/autoscience/autoscience/butane/models/rmg_model/all_new_calcs20221006_8XX.cti'

# cti_path = '/work/westgroup/harris.se/autoscience/autoscience/butane/models/rmg_model/only85.cti'


# cti_path = '/work/westgroup/harris.se/autoscience/autoscience/debug/thermo85/sp85_rotors.cti'

# cti_path = '/work/westgroup/harris.se/autoscience/autoscience/debug/thermo85/sp85_rotors_and4rxn.cti'
cti_path = '/work/westgroup/harris.se/autoscience/autoscience/butane/models/improved_models/thermo_debug/thermo_only_85.cti'

cti_path = '/work/westgroup/harris.se/autoscience/autoscience/debug/s787_rxns/all_rxns_and_gav.cti'


cti_path = '/work/westgroup/harris.se/autoscience/autoscience/debug/s787_rxns/chem_annotated.cti'  # base model
cti_path = '/work/westgroup/harris.se/autoscience/autoscience/butane/models/modifications/sp85_20221013.cti'
cti_path = '/work/westgroup/harris.se/autoscience/autoscience/butane/models/modifications/all_rxns_and_gav_20221013.cti'
cti_path = '/work/westgroup/harris.se/autoscience/autoscience/butane/models/modifications/all_rxns_20221013.cti'
cti_path = '/work/westgroup/harris.se/autoscience/autoscience/butane/models/modifications/all_gav_20221013.cti'


cti_path = '/work/westgroup/harris.se/autoscience/autoscience/butane/models/modifications/uncertain3_20221013.cti'
cti_path = '/work/westgroup/harris.se/autoscience/autoscience/butane/models/modifications/uncertain10_20221013.cti'

cti_path = '/work/westgroup/harris.se/autoscience/autoscience/butane/models/modifications/uncertain11and12_20221014.cti'
# cti_path = '/work/westgroup/harris.se/autoscience/autoscience/butane/models/modifications/cutoff_2_3_20221014.cti'
# cti_path = '/work/westgroup/harris.se/autoscience/autoscience/butane/models/modifications/cutoff_2_2_20221014.cti'

cti_path = '/work/westgroup/harris.se/autoscience/autoscience/butane/models/modifications/cutoff3_20221017.cti'
cti_path = '/work/westgroup/harris.se/autoscience/autoscience/butane/models/modifications/cutoff3_20221018.cti'

cti_path = '/work/westgroup/harris.se/autoscience/autoscience/butane/models/modifications/cutoff3_id_fs_20221019.cti'

cti_path = '/work/westgroup/harris.se/autoscience/autoscience/butane/models/modifications/cutoff1_66thermo_20221020.cti'
cti_path = '/work/westgroup/harris.se/autoscience/autoscience/butane/models/modifications/cutoff1p5_26thermo_20221020.cti'
cti_path = '/work/westgroup/harris.se/autoscience/autoscience/butane/models/modifications/cutoff3_20221020.cti'
cti_path = '/work/westgroup/harris.se/autoscience/autoscience/butane/models/modifications/cutoff2p5_15thermo_20221020.cti'

cti_path = '/work/westgroup/harris.se/autoscience/autoscience/butane/models/modifications/cutoff3_20221026.cti'
cti_path = '/work/westgroup/harris.se/autoscience/autoscience/butane/models/modifications/cutoff3_uncorrelated_20221026.cti'

cti_path = '/work/westgroup/harris.se/autoscience/autoscience/butane/models/modifications/cutoff3_20221027.cti'

cti_path ='/work/westgroup/harris.se/autoscience/autoscience/butane/models/modifications/cutoff3_20221031.cti'


cti_path = '/work/westgroup/harris.se/autoscience/autoscience/butane/models/modifications/cutoff3_20221102_revised.cti'
cti_path = '/work/westgroup/harris.se/autoscience/autoscience/butane/models/modifications/revised_20221102.cti'

cti_path = '/work/westgroup/harris.se/autoscience/autoscience/butane/models/modifications/revised_20221103.cti'
cti_path = '/work/westgroup/harris.se/autoscience/autoscience/butane/models/modifications/revised_750_20221103.cti'
cti_path = '/work/westgroup/harris.se/autoscience/autoscience/butane/models/modifications/cutoff3_revised_20221103.cti'

# cti_path = '/work/westgroup/harris.se/autoscience/autoscience/butane/models/modifications/cutoff3_retrained_20221109.cti'


# cti_path = '/work/westgroup/harris.se/autoscience/autoscience/butane/models/modifications/cutoff_nonlib_20221110.cti'

# cti_path = '/work/westgroup/harris.se/autoscience/autoscience/butane/models/modifications/cutoff_nonlib0_20221110.cti'

cti_path = '/work/westgroup/harris.se/autoscience/autoscience/butane/models/modifications/cutoff3_20221110.cti'

gas = ct.Solution(cti_path)

# %%
gas.species()[85].thermo.coeffs
# Out:
# array([ 9.49210000e+02,  1.16605865e+01,  4.41236559e-02, -2.07772408e-05,
#         4.03962387e-09, -2.86276164e-13, -4.21917163e+04, -2.50449631e+01,
#         2.98377104e-02,  9.31369094e-02, -9.82324541e-05,  5.84404205e-08,
#        -1.46144596e-11, -3.99837532e+04,  3.04602026e+01])

# %%
# Load the experimental conditions
ignition_delay_data = '/work/westgroup/harris.se/autoscience/autoscience/butane/experimental_data/butane_ignition_delay.csv'
df_exp = pd.read_csv(ignition_delay_data)

# slice just table 7, where phi=1.0
table7 = df_exp[df_exp['Table'] == 7]
# Define Initial conditions using experimental data
tau7 = table7['time (ms)'].values.astype(float)  # ignition delay
T7 = table7['T_C'].values  # Temperatures
P7 = table7['nominal pressure(atm)'].values * ct.one_atm  # pressures in atm


# list of starting conditions
# Mixture compositions taken from table 2 of
# https://doi-org.ezproxy.neu.edu/10.1016/j.combustflame.2010.01.016
concentrations = []
# for phi = 1
x_diluent = 0.7649
conc_dict = {
    'O2(2)': 0.2038,
    'butane(1)': 0.03135
}

for i in range(0, len(table7)):
    x_N2 = table7['%N2'].values[i] / 100.0 * x_diluent
    x_Ar = table7['%Ar'].values[i] / 100.0 * x_diluent
    x_CO2 = table7['%CO2'].values[i] / 100.0 * x_diluent
    conc_dict['N2'] = x_N2
    conc_dict['Ar'] = x_Ar
    conc_dict['CO2(7)'] = x_CO2
    concentrations.append(conc_dict)

    
# # Aramco naming:
# x_diluent = 0.7649
# conc_dict = {
#     'O2': 0.2038,
#     'C4H10': 0.03135
# }

# for i in range(0, len(table7)):
#     x_N2 = table7['%N2'].values[i] / 100.0 * x_diluent
#     x_Ar = table7['%Ar'].values[i] / 100.0 * x_diluent
#     x_CO2 = table7['%CO2'].values[i] / 100.0 * x_diluent
#     conc_dict['N2'] = x_N2
#     conc_dict['AR'] = x_Ar
#     conc_dict['CO2'] = x_CO2
#     concentrations.append(conc_dict)

# %%
# Take Reactor Conditions from Table 7 of supplementary info in
# https://doi-org.ezproxy.neu.edu/10.1016/j.combustflame.2010.01.016
def get_delay(gas, T, P, X):
    # function to run a RCM simulation

    t_end = 1.0  # time in seconds
    gas.TPX = T, P, X

    env = ct.Reservoir(ct.Solution('air.yaml'))
    # env = ct.Reservoir(ct.Solution('air.xml'))
    reactor = ct.IdealGasReactor(gas)
    wall = ct.Wall(reactor, env, A=1.0, velocity=0)
    reactor_net = ct.ReactorNet([reactor])
    # # allegedly faster solving
    # reactor_net.derivative_settings = {"skip-third-bodies": True, "skip-falloff": True}
    # reactor_net.preconditioner = ct.AdaptivePreconditioner()

    times = [0]
    T = [reactor.T]
    P = [reactor.thermo.P]
    X = [reactor.thermo.X]  # mol fractions
    while reactor_net.time < t_end:
        reactor_net.step()

        times.append(reactor_net.time)
        T.append(reactor.T)
        P.append(reactor.thermo.P)
        X.append(reactor.thermo.X)

    slopes = np.gradient(P, times)
    i = np.argmax(slopes)
    return times[i]

# %%
def run_simulation(condition_index):
    gas = ct.Solution(cti_path)
    X = concentrations[condition_index]
    delay = get_delay(gas, T7[condition_index], P7[condition_index], X)
    print(f'Completed {condition_index}:\t {delay}')
    return delay

# %%
# Run all simulations in parallel
delays = np.zeros(len(table7))
condition_indices = np.arange(0, len(table7))
with concurrent.futures.ProcessPoolExecutor(max_workers=16) as executor:
    for condition_index, delay_time in zip(condition_indices, executor.map(run_simulation, condition_indices)):
        delays[condition_index] = delay_time
# Out:
# Completed 14:	 0.021915183474844998
# Completed 13:	 0.02305667210038822Completed 15:	 0.013349999826992214
#
# Completed 12:	 0.032328643630630094
# Completed 11:	 0.04832556330826753
# Completed 8:	 0.07773084572483374
# Completed 10:	 0.05510964210323283
# Completed 9:	 0.07245264771675987
# Completed 6:	 0.06232406146932491
# Completed 7:	 0.06325180240998218
# Completed 4:	 0.03800840700192823
# Completed 2:	 0.036532071977520314
# Completed 5:	 0.03830036438934357
# Completed 3:	 0.036378966294403105
# Completed 1:	 0.05073638720515454
# Completed 0:	 0.051598087869107016

# %%
delays
# Out:
# array([0.05159809, 0.05073639, 0.03653207, 0.03637897, 0.03800841,
#        0.03830036, 0.06232406, 0.0632518 , 0.07773085, 0.07245265,
#        0.05510964, 0.04832556, 0.03232864, 0.02305667, 0.02191518,
#        0.01335   ])

# %%
# Saved ignition delays for comparison:

small_core_rmg = np.array([0.01077379, 0.01051961, 0.00576432, 0.00567457, 0.00428338,
       0.00425225, 0.0042361 , 0.00426458, 0.00737937, 0.00856281,
       0.01243118, 0.01386097, 0.01574543, 0.01515089, 0.01496053,
       0.01240051])

base_rmg7 = np.array([0.04908328, 0.04854439, 0.04814446, 0.04868176, 0.075588  ,
       0.07737167, 0.14791668, 0.14857535, 0.1085917 , 0.0952434 ,
       0.06520823, 0.05563237, 0.03535775, 0.02462961, 0.02334903,
       0.01398333])  # 24 hour RMG run - 110 species

full_base_rmg7 = np.array([0.04830086, 0.04773837, 0.0462931 , 0.04678523, 0.07270171,
       0.07446053, 0.14525752, 0.14593983, 0.10720529, 0.09406754,
       0.0644564 , 0.05500488, 0.03497752, 0.02436985, 0.02310303,
       0.01383285])  # 1 week RMG model that completed - all 130 species


no_libraries = np.array([0.01237444, 0.01209319, 0.00682686, 0.00673161, 0.00528425,
       0.00525704, 0.0060358 , 0.006116  , 0.01900203, 0.02356676,
       0.02717866, 0.02604324, 0.02041384, 0.01584896, 0.01523232,
       0.01017369])

aramco7 = np.array([0.03945921, 0.03874611, 0.02817182, 0.02812066, 0.03236667,
       0.03278732, 0.06009581, 0.06085926, 0.06020536, 0.05459522,
       0.03965133, 0.03435827, 0.02245863, 0.01580939, 0.01499945,
       0.00896072])
experiment7 = np.array([0.0865 , 0.0739 , 0.0313 , 0.033  , 0.0309 , 0.03   , 0.056  ,
       0.0566 , 0.0679 , 0.0664 , 0.0652 , 0.0671 , 0.047  , 0.0279 ,
       0.02805, 0.012  ])

refit_data = np.array([0.05537965, 0.05454661, 0.04106517, 0.04092686, 0.04253229,
       0.04280338, 0.06513032, 0.06601117, 0.07934131, 0.07393557,
       0.05631925, 0.04944456, 0.03323524, 0.02382893, 0.02266964,
       0.01395443])

# %%
# plot the ignition delay
plt.plot(1000.0 / T7, delays, marker='x')
plt.plot(1000.0 / T7, small_core_rmg, marker='x')
plt.plot(1000.0 / T7, no_libraries, marker='x')
plt.plot(1000.0 / T7, base_rmg7, marker='x', linestyle='dashed')
plt.plot(1000.0 / T7, aramco7, marker='x')
plt.scatter(1000.0 / T7, tau7 / 1000.0, color='black')
ax = plt.gca()
ax.set_yscale('log')
# plt.legend(['Mechanism 174', 'Base RMG', 'Aramco', 'Experiment'])
plt.legend(['New Calculations', 'Small Core RMG', 'No Libraries', 'Base RMG', 'Aramco', 'Experiment'], loc=(1.04, 0))
plt.title('Ignition Delays Phi=1.0')
plt.xlabel('1000K / T')
plt.ylabel('Delay (s)')
plt.savefig('table7.png')
# plt.legend(bbox_to_anchor=(0, 1), , ncol=1)

# %%
# plot the ignition delay
plt.plot(1000.0 / T7, delays, marker='x')
# plt.plot(1000.0 / T7, small_core_rmg, marker='x')
# plt.plot(1000.0 / T7, no_libraries, marker='x')
plt.plot(1000.0 / T7, base_rmg7, marker='x', linestyle='dashed')
plt.plot(1000.0 / T7, aramco7, marker='x')
plt.scatter(1000.0 / T7, tau7 / 1000.0, color='black')
ax = plt.gca()
ax.set_yscale('log')
plt.legend(['New Calculations', 'Base RMG', 'Aramco', 'Experiment'])
# plt.legend(['Only thermo 85 changed', 'Small Core RMG', 'No Libraries', 'Base RMG', 'Aramco', 'Experiment'], loc=(1.04, 0))
plt.title('Ignition Delays Phi=1.0')
plt.xlabel('1000K / T')
plt.ylabel('Delay (s)')
plt.savefig('table7.png')
# plt.legend(bbox_to_anchor=(0, 1), , ncol=1)

# %%
# plot the ignition delay
plt.plot(1000.0 / T7, delays, marker='x')
# plt.plot(1000.0 / T7, small_core_rmg, marker='x')
# plt.plot(1000.0 / T7, no_libraries, marker='x')
plt.plot(1000.0 / T7, base_rmg7, marker='x', linestyle='dashed')
plt.plot(1000.0 / T7, aramco7, marker='x')
plt.scatter(1000.0 / T7, tau7 / 1000.0, color='black')
ax = plt.gca()
ax.set_yscale('log')
plt.legend(['New Calculations', 'Base RMG', 'Aramco', 'Experiment'])
# plt.legend(['New Calculations', 'Small Core RMG', 'No Libraries', 'Base RMG', 'Aramco', 'Experiment'], loc=(1.04, 0))
plt.title('Ignition Delays Phi=1.0')
plt.xlabel('1000K / T')
plt.ylabel('Delay (s)')
plt.savefig('table7.png')
# plt.legend(bbox_to_anchor=(0, 1), , ncol=1)

# %%
tau7
# Out:
# array([86.5 , 73.9 , 31.3 , 33.  , 30.9 , 30.  , 56.  , 56.6 , 67.9 ,
#        66.4 , 65.2 , 67.1 , 47.  , 27.9 , 28.05, 12.  ])

# %%
delays[7]
# Out:
# 0.06325180240998218

# %%
# plot the 
plt.plot(1000.0 / T7, delays, marker='x')
# plt.plot(1000.0 / T7, small_core_rmg, marker='x')
plt.plot(1000.0 / T7, base_rmg7, marker='x', linestyle='dashed')
# plt.plot(1000.0 / T7, aramco7, marker='x')
plt.scatter(1000.0 / T7, tau7 / 1000.0, color='black')
ax = plt.gca()
ax.set_yscale('log')
# plt.legend(['Mechanism 174', 'Base RMG', 'Aramco', 'Experiment'])
plt.legend(['Sevy\'s DFT thermo', 'RMG GAV thermo', 'Experiment'])
plt.title('Ignition Delays Phi=1.0')
plt.xlabel('1000K / T')
plt.ylabel('Delay (s)')
plt.savefig('table7.png')

# %%
print(gas.reactions()[832].rate)
print(gas.reactions()[833].rate)
print(gas.reactions()[834].rate)
# Out:
# Arrhenius(A=2.51e-14, b=6.77, E=-3.59824e+07)
# Arrhenius(A=2.51e-14, b=6.77, E=-3.59824e+07)
# Arrhenius(A=8.77928e-06, b=3.957, E=1.75268e+07)

# %%
print(gas.species()[85].thermo.coeffs)
# Out:
# [ 9.49210000e+02  1.16605865e+01  4.41236559e-02 -2.07772408e-05
#   4.03962387e-09 -2.86276164e-13 -4.21917163e+04 -2.50449631e+01
#   2.98377104e-02  9.31369094e-02 -9.82324541e-05  5.84404205e-08
#  -1.46144596e-11 -3.99837532e+04  3.04602026e+01]

# %% [markdown]
# ## Calculate Simple Linear Squared Error

# %%
def get_error(points):
    return np.dot(points - experiment7, points - experiment7)

# %%
print('Base RMG Error:\t', get_error(base_rmg7))
print('Aramco Error:\t', get_error(aramco7))
print('New Calc Error:\t', get_error(delays))
# Out:
# Base RMG Error:	 0.026513337786497698
# Aramco Error:	 0.006378394111488899
# New Calc Error:	 0.0028628940101847623

# %%
# plot the ignition delay
# plt.plot(1000.0 / T7, delays, marker='x')
# plt.plot(1000.0 / T7, small_core_rmg, marker='x')
# plt.plot(1000.0 / T7, no_libraries, marker='x')
plt.plot(1000.0 / T7, base_rmg7, marker='x')
plt.plot(1000.0 / T7, aramco7, marker='x')
plt.scatter(1000.0 / T7, tau7 / 1000.0, color='black')
ax = plt.gca()
colors = plt.rcParams['axes.prop_cycle'].by_key()['color']
ax.set_yscale('log')
plt.legend(['Base RMG', 'Aramco [1]', 'Experiment [2]'])
plt.annotate('Base RMG', (1,1))
# plt.legend(['New Calculations', 'Small Core RMG', 'No Libraries', 'Base RMG', 'Aramco', 'Experiment'], loc=(1.04, 0))
plt.title('Ignition Delays Phi=1.0')
plt.xlabel('1000K / T')
plt.ylabel('Delay (s)')
plt.savefig('table7.png')
# plt.legend(bbox_to_anchor=(0, 1), , ncol=1)

# %%
# plot the ignition delay
colors = plt.rcParams['axes.prop_cycle'].by_key()['color']
plt.plot(1000.0 / T7, base_rmg7, marker='x')
plt.plot(1000.0 / T7, aramco7, marker='x')
plt.plot(1000.0 / T7, delays, marker='x')
plt.plot(1000.0 / T7, refit_data, marker='x', color=colors[6])
plt.scatter(1000.0 / T7, tau7 / 1000.0, color='black')
ax = plt.gca()
ax.set_yscale('log')
plt.legend(['Base RMG', 'Aramco', 'New Calculations', 'Refit Tree', 'Experiment'])



# plt.annotate('Base RMG', (1.2, 0.2), color=colors[0], size=14)

# ax.annotate('Base RMG', xy=(1000.0 / T7[7], base_rmg7[7]),  xycoords='data',
#             xytext=(0.5, 0.2), textcoords='axes fraction',
#             arrowprops=dict(facecolor='black', shrink=0.05),
#             horizontalalignment='right', verticalalignment='top',
#             )

# plt.legend(['New Calculations', 'Small Core RMG', 'No Libraries', 'Base RMG', 'Aramco', 'Experiment'], loc=(1.04, 0))
plt.title('Ignition Delays Phi=1.0')
plt.xlabel('1000K / T')
plt.ylabel('Delay (s)')
plt.savefig('table7.png')
# plt.legend(bbox_to_anchor=(0, 1), , ncol=1)
