# %%
# analyze the results of the local sensitivity runs

# %%
import os
import sys
import copy
import pickle
import concurrent.futures
import numpy as np
import pandas as pd

import cantera as ct
import rmgpy.chemkin

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
# load the csv to get the ignition delay times
# csv_file = '/scratch/harris.se/autoscience/local_sensitivity/practice.csv'
csv_file = '/scratch/harris.se/autoscience/local_sensitivity/ignition_delays_007.csv'
df = pd.read_csv(csv_file, skiprows=1, names=['model', 'delay'])

# %%
base_delay
# Out:
# 0.14857534592261107

# %%
df['delay'].values[324]
# Out:
# 0.14857534592261107

# %%
# Load the base model
basedir = '/work/westgroup/harris.se/autoscience/autoscience/butane/rmg_model'

cti_path = os.path.join(basedir, 'chem_annotated.cti')
gas = ct.Solution(cti_path)

# %%
base_chemkin = os.path.join(basedir, 'chem_annotated.inp')
dictionary = os.path.join(basedir, 'species_dictionary.txt')
transport = os.path.join(basedir, 'tran.dat')
species_list, reaction_list = rmgpy.chemkin.load_chemkin_file(base_chemkin, dictionary_path=dictionary, transport_path=transport, use_chemkin_names=True)

# %%
# get the mapping between RMG and Cantera reactions
# Species Diff
common_species = []
RMG2CT_mapping = {}
CT2RMG_mapping = {}
for i, rmg_sp in enumerate(species_list):
    for j, ct_sp in enumerate(gas.species()):
        if str(rmg_sp) == ct_sp.name:
            common_species.append([rmg_sp, ct_sp])
            RMG2CT_mapping[i] = j
            CT2RMG_mapping[j] = i
            break


def ct_matches_rmg_rxn(rmg_rxn, ct_rxn):
    rmg_reactants = set()
    ct_reactants = set()
    for key in ct_rxn.reactants.keys():
        ct_reactants.add(key)
    for reactant in rmg_rxn.reactants:
        rmg_reactants.add(str(reactant))
    if rmg_reactants != ct_reactants:
        return False
    
    rmg_products = set()
    ct_products = set()
    for key in ct_rxn.products.keys():
        ct_products.add(key)
    for product in rmg_rxn.products:
        rmg_products.add(str(product))
    if rmg_products != ct_products:
        return False

    # check duplicates
    if not ct_rxn.duplicate:
        return True
    
    if type(rmg_rxn.kinetics) == rmgpy.kinetics.arrhenius.Arrhenius:
        return np.isclose(rmg_rxn.to_cantera().rate.pre_exponential_factor, ct_rxn.rate.pre_exponential_factor)
    
#     if type(rmg_rxn.kinetics) == rmgpy.kinetics.arrhenius.MultiArrhenius
    
    return False
#     if type(ct_rxn) == list:
#         return False
#     if type(rmg_rxn.to_cantera()) == list:
#         return False
    
#     if type(rmg_rxn.to_cantera() == ct._cantera.FalloffReaction):
#         return False
#     # check the rate
#     return rmg_rxn.to_cantera().rate.pre_exponential_factor == ct_rxn.rate.pre_exponential_factor
    
    
            
# Reaction Diff
common_reactions = []
RMG2CT_rxn_mapping = {}
CT2RMG_rxn_mapping = {}
for i, rmg_rxn in enumerate(reaction_list):
    for j, ct_rxn in enumerate(gas.reactions()):
        if ct_matches_rmg_rxn(rmg_rxn, ct_rxn):
            RMG2CT_rxn_mapping[i] = j
            CT2RMG_rxn_mapping[j] = i
            common_reactions.append([rmg_rxn, ct_rxn])
            break
    else:
        print(f'No match for {reaction_list.index(rmg_rxn)} {rmg_rxn}, {type(rmg_rxn.kinetics)}')
print(f'{len(common_species)} common species')
print(f'{len(common_reactions)} common reactions')
# Out:
# No match for 1 O(5) + H2(13) <=> H(14) + OH(15), <class 'rmgpy.kinetics.arrhenius.MultiArrhenius'>
# No match for 18 HO2(16) + HO2(16) <=> O2(2) + H2O2(17), <class 'rmgpy.kinetics.arrhenius.MultiArrhenius'>
# No match for 23 OH(15) + H2O2(17) <=> HO2(16) + H2O(8), <class 'rmgpy.kinetics.arrhenius.MultiArrhenius'>
# No match for 53 O2(2) + C2H3(22) <=> OH(15) + CH2CO(24), <class 'rmgpy.kinetics.arrhenius.MultiPDepArrhenius'>
# No match for 60 CH(3) + CH2CHO(21) <=> HCO(19) + C2H3(22), <class 'rmgpy.kinetics.arrhenius.MultiArrhenius'>
# No match for 83 CH2CHO(21) <=> CO(6) + CH3(18), <class 'rmgpy.kinetics.falloff.Troe'>
# No match for 98 OH(15) + CO(6) <=> H(14) + CO2(7), <class 'rmgpy.kinetics.arrhenius.MultiArrhenius'>
# No match for 110 O2(2) + C2H3(22) <=> CO2(7) + CH3(18), <class 'rmgpy.kinetics.arrhenius.MultiPDepArrhenius'>
# No match for 139 O2(2) + C2H3(22) <=> H(14) + CO(6) + CH2O(9), <class 'rmgpy.kinetics.arrhenius.MultiPDepArrhenius'>
# No match for 148 O(5) + CH2CHO(21) <=> HCO(19) + CH2O(9), <class 'rmgpy.kinetics.arrhenius.MultiArrhenius'>
# No match for 170 O(5) + C2H4(11) <=> H(14) + CO(6) + CH3(18), <class 'rmgpy.kinetics.arrhenius.MultiArrhenius'>
# No match for 173 CH2(23) + CH2CHO(21) <=> HCO(19) + C2H4(11), <class 'rmgpy.kinetics.arrhenius.MultiArrhenius'>
# No match for 175 CH3(18) + C2H3(22) <=> C3H6(12), <class 'rmgpy.kinetics.falloff.Troe'>
# No match for 176 C3H6(12) <=> CH3(18) + C2H3(22), <class 'rmgpy.kinetics.arrhenius.MultiPDepArrhenius'>
# No match for 178 H(14) + C3H6(12) <=> CH3(18) + C2H4(11), <class 'rmgpy.kinetics.arrhenius.MultiPDepArrhenius'>
# No match for 235 H(14) + C3H6(12) <=> NC3H7(92), <class 'rmgpy.kinetics.arrhenius.MultiPDepArrhenius'>
# No match for 236 CH3(18) + C2H4(11) <=> NC3H7(92), <class 'rmgpy.kinetics.arrhenius.MultiPDepArrhenius'>
# No match for 240 CH2CHO(21) <=> CO(6) + CH3(18), <class 'rmgpy.kinetics.chebyshev.Chebyshev'>
# No match for 292 PC4H9(182) <=> SC4H9(183), <class 'rmgpy.kinetics.arrhenius.MultiArrhenius'>
# No match for 356 OH(15) + C2H4(11) <=> H(14) + CH3CHO(35), <class 'rmgpy.kinetics.arrhenius.MultiArrhenius'>
# No match for 380 H(14) + C3H6(12) <=> IC3H7(93), <class 'rmgpy.kinetics.arrhenius.MultiPDepArrhenius'>
# No match for 494 CH3(18) + C2H6(32) <=> CH4(10) + C2H5(33), <class 'rmgpy.kinetics.arrhenius.MultiArrhenius'>
# No match for 527 O2(2) + C2H3(22) <=> CO(6) + CH3O(31), <class 'rmgpy.kinetics.arrhenius.MultiPDepArrhenius'>
# No match for 553 CH3(18) + C2H3(22) <=> H(14) + C3H5-A(94), <class 'rmgpy.kinetics.arrhenius.MultiPDepArrhenius'>
# No match for 554 C3H6(12) <=> H(14) + C3H5-A(94), <class 'rmgpy.kinetics.arrhenius.MultiPDepArrhenius'>
# No match for 620 CH2O(9) + C2H4(11) <=> CH2(23) + C2H4O(703), <class 'rmgpy.kinetics.chebyshev.Chebyshev'>
# No match for 623 CH2O(9) + C2H4(11) <=> CH2(23) + C2H4O(703), <class 'rmgpy.kinetics.chebyshev.Chebyshev'>
# No match for 660 C2H4(11) + C3H6(12) <=> CH2(23) + C4H8(748), <class 'rmgpy.kinetics.chebyshev.Chebyshev'>
# No match for 661 C2H4(11) + C3H6(12) <=> CH2(23) + C4H8(748), <class 'rmgpy.kinetics.chebyshev.Chebyshev'>
# No match for 776 O2(2) + C4H7(190) <=> S(4243), <class 'rmgpy.kinetics.chebyshev.Chebyshev'>
# No match for 777 O2(2) + C4H7(190) <=> S(4243), <class 'rmgpy.kinetics.chebyshev.Chebyshev'>
# No match for 778 O2(2) + C4H7(190) <=> S(4244), <class 'rmgpy.kinetics.chebyshev.Chebyshev'>
# No match for 779 O2(2) + C4H7(190) <=> S(4244), <class 'rmgpy.kinetics.chebyshev.Chebyshev'>
# No match for 1132 CH2O(9) + C3H6(12) <=> CH3(18) + C3H5O(129), <class 'rmgpy.kinetics.chebyshev.Chebyshev'>
# No match for 1237 CH3CHO(35) + C3H4O(74) <=> CH2CHO(21) + C3H5O(129), <class 'rmgpy.kinetics.chebyshev.Chebyshev'>
# No match for 1239 CH3CHO(35) + C3H4O(74) <=> CH2CHO(21) + C3H5O(129), <class 'rmgpy.kinetics.chebyshev.Chebyshev'>
# No match for 1260 HO2(16) + C3H4O(74) <=> CO(6) + C2H5O2(47), <class 'rmgpy.kinetics.chebyshev.Chebyshev'>
# No match for 1278 HO2(16) + C3H4O(74) <=> CO(6) + C2H5O2(47), <class 'rmgpy.kinetics.chebyshev.Chebyshev'>
# No match for 1376 CH2O(9) + C4H6(194) <=> CH2O(9) + C4H6(2534), <class 'rmgpy.kinetics.chebyshev.Chebyshev'>
# No match for 1377 CH2O(9) + C4H6(194) <=> CH2O(9) + C4H6(2534), <class 'rmgpy.kinetics.chebyshev.Chebyshev'>
# No match for 1378 CH2O(9) + C4H6(194) <=> CH2O(9) + C4H6(2534), <class 'rmgpy.kinetics.chebyshev.Chebyshev'>
# No match for 1379 CH2O(9) + C4H6(194) <=> CH2O(9) + C4H6(2534), <class 'rmgpy.kinetics.chebyshev.Chebyshev'>
# No match for 1380 CH2CO(24) + C4H6(194) <=> CH2CO(24) + C4H6(2534), <class 'rmgpy.kinetics.chebyshev.Chebyshev'>
# No match for 1381 CH2CO(24) + C4H6(194) <=> CH2CO(24) + C4H6(2534), <class 'rmgpy.kinetics.chebyshev.Chebyshev'>
# No match for 1382 C2H4(11) + C4H6(194) <=> C2H4(11) + C4H6(2534), <class 'rmgpy.kinetics.chebyshev.Chebyshev'>
# No match for 1383 C2H4(11) + C4H6(194) <=> C2H4(11) + C4H6(2534), <class 'rmgpy.kinetics.chebyshev.Chebyshev'>
# No match for 1384 CH2CO(24) + C4H6(194) <=> CH2CO(24) + C4H6(2534), <class 'rmgpy.kinetics.chebyshev.Chebyshev'>
# No match for 1385 CH2CO(24) + C4H6(194) <=> CH2CO(24) + C4H6(2534), <class 'rmgpy.kinetics.chebyshev.Chebyshev'>
# No match for 1386 CH2CO(24) + C4H6(194) <=> CH2CO(24) + C4H6(2534), <class 'rmgpy.kinetics.chebyshev.Chebyshev'>
# No match for 1387 CH2CO(24) + C4H6(194) <=> CH2CO(24) + C4H6(2534), <class 'rmgpy.kinetics.chebyshev.Chebyshev'>
# No match for 1389 CO2(7) + C4H6(194) <=> CO2(7) + C4H6(2534), <class 'rmgpy.kinetics.chebyshev.Chebyshev'>
# No match for 1392 CO2(7) + C4H6(194) <=> CO2(7) + C4H6(2534), <class 'rmgpy.kinetics.chebyshev.Chebyshev'>
# No match for 1393 CO2(7) + C4H6(194) <=> CO2(7) + C4H6(2534), <class 'rmgpy.kinetics.chebyshev.Chebyshev'>
# No match for 1394 CO2(7) + C4H6(194) <=> CO2(7) + C4H6(2534), <class 'rmgpy.kinetics.chebyshev.Chebyshev'>
# No match for 1395 C2H2(25) + C4H6(194) <=> C2H2(25) + C4H6(2534), <class 'rmgpy.kinetics.chebyshev.Chebyshev'>
# No match for 1396 C2H2(25) + C4H6(194) <=> C2H2(25) + C4H6(2534), <class 'rmgpy.kinetics.chebyshev.Chebyshev'>
# No match for 1458 HOCHO(40) + C4H6(194) <=> HOCHO(40) + C4H6(2534), <class 'rmgpy.kinetics.chebyshev.Chebyshev'>
# No match for 1459 HOCHO(40) + C4H6(194) <=> HOCHO(40) + C4H6(2534), <class 'rmgpy.kinetics.chebyshev.Chebyshev'>
# No match for 1460 HOCHO(40) + C4H6(194) <=> HOCHO(40) + C4H6(2534), <class 'rmgpy.kinetics.chebyshev.Chebyshev'>
# No match for 1461 HOCHO(40) + C4H6(194) <=> HOCHO(40) + C4H6(2534), <class 'rmgpy.kinetics.chebyshev.Chebyshev'>
# No match for 1605 HOCHO(40) + C3H4O(74) <=> OCHO(38) + C3H5O(129), <class 'rmgpy.kinetics.chebyshev.Chebyshev'>
# No match for 1610 HOCHO(40) + C3H4O(74) <=> OCHO(38) + C3H5O(129), <class 'rmgpy.kinetics.chebyshev.Chebyshev'>
# No match for 1801 CH2O(9) + C3H6(12) <=> CH3(18) + C3H5O(129), <class 'rmgpy.kinetics.chebyshev.Chebyshev'>
# 110 common species
# 1759 common reactions

# %%
reaction_list[1].to_cantera()

# %%
gas.reactions()[3]

# %%
len(reaction_list)

# %%
len(gas.reactions())

# %%
RMG2CT_rxn_mapping[1].

# %%
CT2RMG_rxn_mapping[1]

# %%
# find the estimated reactions
libraries = [
    'BurkeH2O2inN2',
    'CurranPentane',
    'FFCM1(-)',
    'combustion_core/version5',
    'Klippenstein_Glarborg2016',
    'C2H4+O_Klipp2017',
]

rmg_estimated = []
for i in range(0, len(reaction_list)):
    if not hasattr(reaction_list[i], 'family'):
        continue
    if reaction_list[i].family in libraries:
        continue
    rmg_estimated.append(i)

# %%
reaction_list[288].kinetics
# Out:
# Arrhenius(A=(1.054e+10,'cm^3/(mol*s)'), n=0.97, Ea=(1.586,'kcal/mol'), T0=(1,'K'))

# %%
base_delay = 0.14857534592261107

# %%
# Load the covariance matrix
covariance_file = '/work/westgroup/harris.se/autoscience/autoscience/uncertainty/butane_covariance.pickle'
with open(covariance_file, 'rb') as handle:
    Sigma_k = pickle.load(handle)

# %%
delays = df['delay'].values
for i in range(0, len(df)):
    if delays[i] == -1:
        delays[i] = base_delay

# %%
np.min(df['delay'])

# %%
np.max(df['delay'].values)

# %%
uncertainties_ct = np.zeros(len(gas.reactions()))
for i in range(0, len(uncertainties_ct)):
    try:
        rmg_index = CT2RMG_rxn_mapping[i]
        uncertainties_ct[i] = Sigma_k[rmg_index, rmg_index]
    except KeyError:
        continue

# %%
len(reaction_list)

# %%
# Out:
# 0.0

# %%
# Get the top 50:




differences = np.abs(delays - base_delay)
# multiply sensitivity times uncertainty

score = np.multiply(differences, uncertainties_ct)

best_runs = [x for _, x in sorted(zip(score, np.arange(0, len(gas.reactions()))))][::-1]

# %%
# print the top reactions
print('idx', '\t', 'ln k', '\t', 'prod', '\t', 'family', '\t', 'reaction')


for i in range(0, len(gas.reactions())):
    try:
        rmg_index = CT2RMG_rxn_mapping[best_runs[i]]
        if rmg_index not in rmg_estimated:
            continue
    except KeyError:
        print(f'Cantera reaction mapping not found for {best_runs[i]} {gas.reactions()[best_runs[i]]}')
        continue
    delta = np.round(Sigma_k[rmg_index][rmg_index], 1)
    
#     print(rmg_index, '\t', delta, '\t', np.round(score[best_runs[i]],4), '\t', reaction_list[rmg_index].family, '\t', reaction_list[rmg_index])
    print(rmg_index, '\t', delta, '\t', np.round(score[best_runs[i]],4), '\t', reaction_list[rmg_index].family, '\t', reaction_list[rmg_index])
# Out:
# idx 	 ln k 	 prod 	 family 	 reaction
# 324 	 3.6 	 0.003 	 intra_H_migration 	 S(229) <=> S(225)
# 915 	 10.7 	 0.0025 	 Disproportionation 	 O2(2) + S(777) <=> HO2(16) + S(252)
# 748 	 3.2 	 0.0019 	 H_Abstraction 	 HCO(19) + C4H8(189) <=> CH2O(9) + C4H7(190)
# 1287 	 3.9 	 0.0015 	 H_Abstraction 	 C3H6O3(73) + SC4H9(183) <=> C3H5O3(72) + butane(1)
# 749 	 11.0 	 0.0013 	 H_Abstraction 	 HCO(19) + C4H8(188) <=> CH2O(9) + C4H7(190)
# 809 	 1.8 	 0.001 	 H_Abstraction 	 PC4H9(182) + S(787) <=> S(225) + butane(1)
# 419 	 10.7 	 0.0008 	 Disproportionation 	 HO2(16) + CH2CHO(21) <=> H2O2(17) + CH2CO(24)
# 213 	 3.2 	 0.0005 	 Disproportionation 	 HO2(16) + C2H5(33) <=> H2O2(17) + C2H4(11)
# 1288 	 4.3 	 0.0005 	 H_Abstraction 	 C3H6O3(73) + PC4H9(182) <=> C3H5O3(72) + butane(1)
# 805 	 1.8 	 0.0004 	 H_Abstraction 	 PC4H9(182) + S(787) <=> S(229) + butane(1)
# 370 	 4.3 	 0.0004 	 H_Abstraction 	 CH3CHO(35) + SC4H9(183) <=> CH2CHO(21) + butane(1)
# 793 	 1.8 	 0.0003 	 Disproportionation 	 HO2(16) + C4H7(190) <=> H2O2(17) + C4H6(194)
# 808 	 1.8 	 0.0002 	 H_Abstraction 	 SC4H9(183) + S(787) <=> S(225) + butane(1)
# 371 	 3.6 	 0.0002 	 H_Abstraction 	 CH3CHO(35) + PC4H9(182) <=> CH2CHO(21) + butane(1)
# 1717 	 1.8 	 0.0002 	 H_Abstraction 	 C4H7(191) + S(187) <=> C4H8(188) + S(186)
# 422 	 1.8 	 0.0002 	 Disproportionation 	 HO2(16) + SC4H9(183) <=> H2O2(17) + C4H8(188)
# 804 	 1.8 	 0.0001 	 H_Abstraction 	 SC4H9(183) + S(787) <=> S(229) + butane(1)
# 813 	 1.0 	 0.0001 	 H_Abstraction 	 HO2(16) + S(225) <=> O2(2) + S(787)
# 294 	 1.8 	 0.0001 	 H_Abstraction 	 CH2O(9) + PC4H9(182) <=> HCO(19) + butane(1)
# 211 	 0.5 	 0.0001 	 H_Abstraction 	 H2O2(17) + C2H3(22) <=> HO2(16) + C2H4(11)
# 1656 	 1.8 	 0.0001 	 H_Abstraction 	 C2H6O2(48) + C4H7(191) <=> C2H5O2(47) + C4H8(188)
# 1509 	 1.8 	 0.0001 	 H_Abstraction 	 CH3OH(30) + C4H7(192) <=> CH3O(31) + C4H8(188)
# 420 	 4.2 	 0.0001 	 Disproportionation 	 HO2(16) + SC4H9(183) <=> H2O2(17) + C4H8(189)
# 812 	 1.0 	 0.0001 	 H_Abstraction 	 HO2(16) + S(229) <=> O2(2) + S(787)
# 1103 	 10.7 	 0.0001 	 Disproportionation 	 CH3O2(45) + CH2CHO(21) <=> CH3O2H(46) + CH2CO(24)
# 591 	 0.5 	 0.0001 	 H_Abstraction 	 CH3CHO(35) + C3H5-A(94) <=> CH3CO(20) + C3H6(12)
# 212 	 1.8 	 0.0 	 CO_Disproportionation 	 HO2(16) + HCO(19) <=> H2O2(17) + CO(6)
# 325 	 1.0 	 0.0 	 intra_H_migration 	 S(225) <=> S(244)
# 1294 	 1.0 	 0.0 	 H_Abstraction 	 C3H5O3(72) + C4H8(188) <=> C3H6O3(73) + C4H7(190)
# 774 	 1.0 	 0.0 	 H_Abstraction 	 CH3CHO(35) + C4H7(190) <=> CH3CO(20) + C4H8(189)
# 724 	 1.8 	 0.0 	 CO_Disproportionation 	 HCO(19) + C4H7(190) <=> CO(6) + C4H8(188)
# 1157 	 0.5 	 0.0 	 H_Abstraction 	 H2O2(17) + C4H7(192) <=> HO2(16) + C4H8(188)
# 1736 	 3.2 	 0.0 	 Disproportionation 	 CH3O(31) + S(186) <=> CH2O(9) + S(187)
# 931 	 1.8 	 0.0 	 R_Recombination 	 OH(15) + S(777) <=> S(787)
# 586 	 2.0 	 0.0 	 H_Abstraction 	 CH2O(9) + C3H5-A(94) <=> HCO(19) + C3H6(12)
# 1715 	 2.0 	 0.0 	 H_Abstraction 	 S(223) + butane(1) <=> PC4H9(182) + S(187)
# 1665 	 3.2 	 0.0 	 Disproportionation 	 CH3O(31) + C2H5O2(47) <=> CH2O(9) + C2H6O2(48)
# 1166 	 1.8 	 0.0 	 H_Abstraction 	 CH3O2H(46) + C4H7(192) <=> CH3O2(45) + C4H8(188)
# 729 	 2.0 	 0.0 	 Disproportionation 	 C4H7(190) + SC4H9(183) <=> C4H8(188) + C4H8(189)
# 1685 	 3.2 	 0.0 	 Disproportionation 	 C2H5(33) + C2H5O2(47) <=> C2H4(11) + C2H6O2(48)
# 1291 	 1.0 	 0.0 	 H_Abstraction 	 HO2(16) + C3H6O3(73) <=> H2O2(17) + C3H5O3(72)
# 1289 	 4.3 	 0.0 	 H_Abstraction 	 C3H6O3(73) + SC4H9(183) <=> S(911) + butane(1)
# 577 	 1.8 	 0.0 	 Disproportionation 	 C3H5-A(94) + SC4H9(183) <=> C3H6(12) + C4H8(189)
# 1766 	 3.2 	 0.0 	 Disproportionation 	 C2H5(33) + S(186) <=> C2H4(11) + S(187)
# 714 	 1.8 	 0.0 	 Disproportionation 	 C2H5(33) + C4H7(190) <=> C2H4(11) + C4H8(189)
# 800 	 1.8 	 0.0 	 Disproportionation 	 OH(15) + C4H7(190) <=> H2O(8) + C4H6(194)
# 581 	 9.2 	 0.0 	 Disproportionation 	 CH2CHO(21) + C3H5-A(94) <=> CH2CO(24) + C3H6(12)
# 1714 	 3.3 	 0.0 	 H_Abstraction 	 S(223) + butane(1) <=> SC4H9(183) + S(187)
# 723 	 1.8 	 0.0 	 CO_Disproportionation 	 HCO(19) + C4H7(190) <=> CO(6) + C4H8(189)
# 833 	 1.8 	 0.0 	 R_Recombination 	 HO2(16) + S(219) <=> S(787)
# 1722 	 1.8 	 0.0 	 H_Abstraction 	 CH2O(9) + S(223) <=> HCO(19) + S(187)
# 459 	 1.8 	 0.0 	 Disproportionation 	 CH3(18) + SC4H9(183) <=> CH4(10) + C4H8(189)
# 574 	 4.6 	 0.0 	 Disproportionation 	 CH3O(31) + C3H5-A(94) <=> CH2O(9) + C3H6(12)
# 1098 	 1.8 	 0.0 	 Disproportionation 	 CH3O2(45) + C4H7(190) <=> CH3O2H(46) + C4H6(194)
# 814 	 1.0 	 0.0 	 H_Abstraction 	 H2O2(17) + S(225) <=> HO2(16) + S(787)
# 726 	 1.8 	 0.0 	 Disproportionation 	 C4H7(190) + SC4H9(183) <=> C4H8(189) + C4H8(189)
# 327 	 1.0 	 0.0 	 intra_H_migration 	 S(229) <=> S(238)
# 418 	 3.6 	 0.0 	 Disproportionation 	 HO2(16) + CH3CO(20) <=> H2O2(17) + CH2CO(24)
# 464 	 9.2 	 0.0 	 Disproportionation 	 CH3(18) + CH2CHO(21) <=> CH4(10) + CH2CO(24)
# 794 	 1.8 	 0.0 	 Disproportionation 	 CH3(18) + C4H7(190) <=> CH4(10) + C4H6(194)
# 1290 	 3.6 	 0.0 	 H_Abstraction 	 C3H6O3(73) + PC4H9(182) <=> S(911) + butane(1)
# 795 	 1.8 	 0.0 	 Disproportionation 	 C4H7(190) + C4H7(190) <=> C4H6(194) + C4H8(189)
# 725 	 4.6 	 0.0 	 Disproportionation 	 CH3O(31) + C4H7(190) <=> CH2O(9) + C4H8(189)
# 1293 	 1.8 	 0.0 	 H_Abstraction 	 C3H6O3(73) + C4H7(190) <=> C3H5O3(72) + C4H8(189)
# 730 	 2.0 	 0.0 	 Disproportionation 	 C4H7(190) + PC4H9(182) <=> C4H8(188) + C4H8(188)
# 722 	 9.2 	 0.0 	 Disproportionation 	 CH2CHO(21) + C4H7(190) <=> CH2CO(24) + C4H8(188)
# 720 	 9.2 	 0.0 	 Disproportionation 	 CH2CHO(21) + C4H7(190) <=> CH2CO(24) + C4H8(189)
# 584 	 3.2 	 0.0 	 Disproportionation 	 HO2(16) + C2H3(22) <=> H2O2(17) + C2H2(25)
# 603 	 1.8 	 0.0 	 H_Abstraction 	 CH3CHO(35) + PC4H9(182) <=> CH3CO(20) + butane(1)
# 578 	 1.8 	 0.0 	 Disproportionation 	 C3H5-A(94) + PC4H9(182) <=> C3H6(12) + C4H8(188)
# 822 	 1.0 	 0.0 	 H_Abstraction 	 H2O2(17) + S(229) <=> HO2(16) + S(787)
# 545 	 2.0 	 0.0 	 H_Abstraction 	 CH2O(9) + CH2CHO(21) <=> HCO(19) + CH3CHO(35)
# 1309 	 1.8 	 0.0 	 H_Abstraction 	 CH3CHO(35) + S(911) <=> CH3CO(20) + C3H6O3(73)
# 251 	 1.8 	 0.0 	 H_Abstraction 	 CH2O(9) + SC4H9(183) <=> HCO(19) + butane(1)
# 546 	 1.8 	 0.0 	 H_Abstraction 	 CH2CHO(21) + CH3CHO(35) <=> CH3CO(20) + CH3CHO(35)
# 1658 	 10.7 	 0.0 	 Disproportionation 	 CH2CHO(21) + C2H5O2(47) <=> CH2CO(24) + C2H6O2(48)
# 410 	 1.8 	 0.0 	 Disproportionation 	 CH3(18) + PC4H9(182) <=> CH4(10) + C4H8(188)
# 417 	 2.0 	 0.0 	 Disproportionation 	 OH(15) + SC4H9(183) <=> H2O(8) + C4H8(189)
# 734 	 1.0 	 0.0 	 H_Abstraction 	 C2H6(32) + C4H7(190) <=> C2H5(33) + C4H8(189)
# 1778 	 1.8 	 0.0 	 Disproportionation 	 SC4H9(183) + S(186) <=> C4H8(188) + S(187)
# 727 	 1.8 	 0.0 	 Disproportionation 	 C4H7(190) + PC4H9(182) <=> C4H8(188) + C4H8(189)
# 421 	 2.8 	 0.0 	 Disproportionation 	 HO2(16) + PC4H9(182) <=> H2O2(17) + C4H8(188)
# 1116 	 1.8 	 0.0 	 Disproportionation 	 CH3O2(45) + SC4H9(183) <=> CH3O2H(46) + C4H8(188)
# 1690 	 1.8 	 0.0 	 Disproportionation 	 C2H5O2(47) + SC4H9(183) <=> C2H6O2(48) + C4H8(188)
# 1110 	 1.8 	 0.0 	 CO_Disproportionation 	 HCO(19) + CH3O2(45) <=> CO(6) + CH3O2H(46)
# 1761 	 1.8 	 0.0 	 CO_Disproportionation 	 HCO(19) + S(186) <=> CO(6) + S(187)
# 1716 	 1.8 	 0.0 	 H_Abstraction 	 OH(15) + S(187) <=> H2O(8) + S(186)
# 1683 	 1.8 	 0.0 	 CO_Disproportionation 	 HCO(19) + C2H5O2(47) <=> CO(6) + C2H6O2(48)
# 1659 	 1.8 	 0.0 	 Disproportionation 	 C2H5O2(47) + C4H7(190) <=> C2H6O2(48) + C4H6(194)
# 834 	 2.4 	 0.0 	 R_Recombination 	 HO2(16) + S(223) <=> S(787)
# 1735 	 1.8 	 0.0 	 H_Abstraction 	 CH3CHO(35) + S(223) <=> CH3CO(20) + S(187)
# 1719 	 1.0 	 0.0 	 H_Abstraction 	 CH2CHO(21) + S(187) <=> CH3CHO(35) + S(186)
# 1729 	 1.8 	 0.0 	 Disproportionation 	 C4H7(190) + S(186) <=> C4H6(194) + S(187)
# 427 	 9.2 	 0.0 	 Disproportionation 	 CH2CHO(21) + CH2CHO(21) <=> CH2CO(24) + CH3CHO(35)
# 1577 	 1.0 	 0.0 	 H_Abstraction 	 HOCHO(40) + CH3(18) <=> OCHO(38) + CH4(10)
# 1773 	 4.2 	 0.0 	 Disproportionation 	 SC4H9(183) + S(186) <=> C4H8(189) + S(187)
# 1114 	 4.2 	 0.0 	 Disproportionation 	 CH3O2(45) + SC4H9(183) <=> CH3O2H(46) + C4H8(189)
# 1023 	 2.0 	 0.0 	 H_Abstraction 	 O(5) + C4H8(188) <=> OH(15) + C4H7(191)
# 1525 	 2.0 	 0.0 	 Disproportionation 	 CH3O(31) + SC4H9(183) <=> CH3OH(30) + C4H8(189)
# 280 	 2.0 	 0.0 	 Disproportionation 	 SC4H9(183) + SC4H9(183) <=> C4H8(189) + butane(1)
# 1328 	 3.2 	 0.0 	 Disproportionation 	 CH3O(31) + C3H5O3(72) <=> CH2O(9) + C3H6O3(73)
# 739 	 3.6 	 0.0 	 H_Abstraction 	 CH2CHO(21) + C4H8(188) <=> CH3CHO(35) + C4H7(190)
# 741 	 1.8 	 0.0 	 H_Abstraction 	 C4H8(188) + SC4H9(183) <=> C4H7(190) + butane(1)
# 744 	 1.8 	 0.0 	 H_Abstraction 	 C4H8(188) + PC4H9(182) <=> C4H7(190) + butane(1)
# 1688 	 4.2 	 0.0 	 Disproportionation 	 C2H5O2(47) + SC4H9(183) <=> C2H6O2(48) + C4H8(189)
# 404 	 2.0 	 0.0 	 Disproportionation 	 OH(15) + PC4H9(182) <=> H2O(8) + C4H8(188)
# 582 	 3.2 	 0.0 	 Disproportionation 	 C2H3(22) + C3H5-A(94) <=> C2H2(25) + C3H6(12)
# 742 	 1.0 	 0.0 	 H_Abstraction 	 C3H6(12) + C4H7(190) <=> C3H5-A(94) + C4H8(189)
# 1531 	 1.8 	 0.0 	 Disproportionation 	 CH3O(31) + C4H7(190) <=> CH3OH(30) + C4H6(194)
# 743 	 2.4 	 0.0 	 H_Abstraction 	 C4H8(189) + PC4H9(182) <=> C4H7(190) + butane(1)
# 440 	 1.8 	 0.0 	 Disproportionation 	 CH2CHO(21) + SC4H9(183) <=> CH3CHO(35) + C4H8(189)
# 547 	 1.8 	 0.0 	 H_Abstraction 	 CH3CHO(35) + SC4H9(183) <=> CH3CO(20) + butane(1)
# 405 	 1.8 	 0.0 	 Disproportionation 	 OH(15) + SC4H9(183) <=> H2O(8) + C4H8(188)
# 869 	 10.7 	 0.0 	 Disproportionation 	 CH2CHO(21) + S(225) <=> CH2CO(24) + S(787)
# 821 	 1.0 	 0.0 	 H_Abstraction 	 C4H8(188) + S(225) <=> C4H7(190) + S(787)
# 1026 	 3.6 	 0.0 	 H_Abstraction 	 CH3CHO(35) + C4H7(191) <=> CH2CHO(21) + C4H8(188)
# 1522 	 1.8 	 0.0 	 Disproportionation 	 CH3O(31) + C2H5(33) <=> CH3OH(30) + C2H4(11)
# 1721 	 10.7 	 0.0 	 Disproportionation 	 CH2CHO(21) + S(186) <=> CH2CO(24) + S(187)
# 1718 	 1.8 	 0.0 	 H_Abstraction 	 C4H7(192) + S(187) <=> C4H8(188) + S(186)
# 1727 	 1.0 	 0.0 	 H_Abstraction 	 H2O2(17) + S(223) <=> HO2(16) + S(187)
# 1111 	 3.2 	 0.0 	 Disproportionation 	 CH3O2(45) + C2H5(33) <=> CH3O2H(46) + C2H4(11)
# 737 	 4.3 	 0.0 	 H_Abstraction 	 CH2CHO(21) + C4H8(189) <=> CH3CHO(35) + C4H7(190)
# 843 	 3.2 	 0.0 	 Disproportionation 	 CH3O(31) + S(225) <=> CH2O(9) + S(787)
# 1043 	 2.0 	 0.0 	 Disproportionation 	 C4H7(190) + C4H7(191) <=> C4H6(194) + C4H8(188)
# 1295 	 4.3 	 0.0 	 H_Abstraction 	 C3H6O3(73) + C4H7(191) <=> C3H5O3(72) + C4H8(188)
# 1342 	 3.2 	 0.0 	 Disproportionation 	 C2H5(33) + C3H5O3(72) <=> C2H4(11) + C3H6O3(73)
# 538 	 4.6 	 0.0 	 Disproportionation 	 CH3O(31) + CH2CHO(21) <=> CH2O(9) + CH3CHO(35)
# 434 	 1.8 	 0.0 	 Disproportionation 	 CH2CHO(21) + C2H5(33) <=> C2H4(11) + CH3CHO(35)
# 253 	 9.2 	 0.0 	 Disproportionation 	 CH2CHO(21) + SC4H9(183) <=> CH2CO(24) + butane(1)
# 1526 	 2.0 	 0.0 	 Disproportionation 	 CH3O(31) + PC4H9(182) <=> CH3OH(30) + C4H8(188)
# 319 	 2.0 	 0.0 	 Disproportionation 	 PC4H9(182) + SC4H9(183) <=> C4H8(188) + butane(1)
# 255 	 1.8 	 0.0 	 CO_Disproportionation 	 HCO(19) + SC4H9(183) <=> CO(6) + butane(1)
# 579 	 1.8 	 0.0 	 Disproportionation 	 C3H5-A(94) + SC4H9(183) <=> C3H6(12) + C4H8(188)
# 1730 	 2.4 	 0.0 	 H_Abstraction 	 C4H8(189) + S(223) <=> C4H7(190) + S(187)
# 1657 	 1.8 	 0.0 	 H_Abstraction 	 C2H6O2(48) + C4H7(192) <=> C2H5O2(47) + C4H8(188)
# 532 	 4.6 	 0.0 	 Disproportionation 	 CH3O(31) + SC4H9(183) <=> CH2O(9) + butane(1)
# 1049 	 1.8 	 0.0 	 Disproportionation 	 C3H5-A(94) + C4H7(191) <=> C3H6(12) + C4H6(194)
# 1731 	 1.8 	 0.0 	 H_Abstraction 	 C4H8(188) + S(223) <=> C4H7(190) + S(187)
# 429 	 1.8 	 0.0 	 CO_Disproportionation 	 HCO(19) + CH2CHO(21) <=> CO(6) + CH3CHO(35)
# 1109 	 3.6 	 0.0 	 Disproportionation 	 CH3O2(45) + CH3CO(20) <=> CH3O2H(46) + CH2CO(24)
# 411 	 1.8 	 0.0 	 Disproportionation 	 CH3(18) + SC4H9(183) <=> CH4(10) + C4H8(188)
# 870 	 10.7 	 0.0 	 Disproportionation 	 CH2CHO(21) + S(229) <=> CH2CO(24) + S(787)
# 839 	 2.5 	 0.0 	 H_Abstraction 	 H2O2(17) + S(244) <=> HO2(16) + S(787)
# 735 	 0.5 	 0.0 	 H_Abstraction 	 C2H6(32) + C4H7(190) <=> C2H5(33) + C4H8(188)
# 877 	 3.2 	 0.0 	 Disproportionation 	 C2H5(33) + S(225) <=> C2H4(11) + S(787)
# 802 	 1.8 	 0.0 	 Disproportionation 	 CH2CHO(21) + C4H7(190) <=> CH3CHO(35) + C4H6(194)
# 399 	 1.8 	 0.0 	 Disproportionation 	 HO2(16) + IC3H7(93) <=> H2O2(17) + C3H6(12)
# 256 	 2.0 	 0.0 	 Disproportionation 	 C2H5(33) + SC4H9(183) <=> C2H4(11) + butane(1)
# 1042 	 1.8 	 0.0 	 Disproportionation 	 C4H7(190) + C4H7(191) <=> C4H6(194) + C4H8(189)
# 844 	 3.2 	 0.0 	 Disproportionation 	 CH3O(31) + S(229) <=> CH2O(9) + S(787)
# 1666 	 1.8 	 0.0 	 H_Abstraction 	 CH3O2(45) + C2H6O2(48) <=> CH3O2H(46) + C2H5O2(47)
# 798 	 1.8 	 0.0 	 Disproportionation 	 C4H7(190) + SC4H9(183) <=> C4H6(194) + butane(1)
# 731 	 1.8 	 0.0 	 Disproportionation 	 C4H7(190) + SC4H9(183) <=> C4H8(188) + C4H8(188)
# 728 	 1.8 	 0.0 	 Disproportionation 	 C4H7(190) + SC4H9(183) <=> C4H8(188) + C4H8(189)
# 733 	 3.2 	 0.0 	 Disproportionation 	 C2H3(22) + C4H7(190) <=> C2H2(25) + C4H8(188)
# 732 	 3.2 	 0.0 	 Disproportionation 	 C2H3(22) + C4H7(190) <=> C2H2(25) + C4H8(189)
# 442 	 1.8 	 0.0 	 Disproportionation 	 CH2CHO(21) + PC4H9(182) <=> CH3CHO(35) + C4H8(188)
# 1056 	 1.8 	 0.0 	 Disproportionation 	 CH3(18) + C4H7(191) <=> CH4(10) + C4H6(194)
# 764 	 0.5 	 0.0 	 H_Abstraction 	 C2H3(22) + C4H8(188) <=> C2H4(11) + C4H7(190)
# 820 	 1.8 	 0.0 	 H_Abstraction 	 C4H7(190) + S(787) <=> C4H8(189) + S(225)
# 1305 	 3.6 	 0.0 	 H_Abstraction 	 S(911) + C4H8(188) <=> C3H6O3(73) + C4H7(190)
# 1175 	 1.0 	 0.0 	 H_Abstraction 	 H(14) + C4H8(188) <=> H2(13) + C4H7(192)
# 1302 	 2.0 	 0.0 	 H_Abstraction 	 CH2O(9) + S(911) <=> HCO(19) + C3H6O3(73)
# 301 	 1.8 	 0.0 	 Disproportionation 	 PC4H9(182) + SC4H9(183) <=> C4H8(189) + butane(1)
# 1297 	 2.0 	 0.0 	 H_Abstraction 	 CH2CHO(21) + C3H6O3(73) <=> CH3CHO(35) + C3H5O3(72)
# 1020 	 1.8 	 0.0 	 H_Abstraction 	 C4H7(191) + S(787) <=> C4H8(188) + S(225)
# 598 	 2.8 	 0.0 	 H_Abstraction 	 CH3CHO(35) + C2H5(33) <=> CH2CHO(21) + C2H6(32)
# 1021 	 1.8 	 0.0 	 H_Abstraction 	 C4H7(191) + S(787) <=> C4H8(188) + S(229)
# 721 	 3.6 	 0.0 	 Disproportionation 	 CH3CO(20) + C4H7(190) <=> CH2CO(24) + C4H8(188)
# 878 	 3.2 	 0.0 	 Disproportionation 	 C2H5(33) + S(229) <=> C2H4(11) + S(787)
# 509 	 2.0 	 0.0 	 Disproportionation 	 C2H5(33) + SC4H9(183) <=> C2H6(32) + C4H8(189)
# 1352 	 1.8 	 0.0 	 Disproportionation 	 C3H5O3(72) + SC4H9(183) <=> C3H6O3(73) + C4H8(188)
# 533 	 4.6 	 0.0 	 Disproportionation 	 CH3O(31) + PC4H9(182) <=> CH2O(9) + butane(1)
# 296 	 9.2 	 0.0 	 Disproportionation 	 CH2CHO(21) + PC4H9(182) <=> CH2CO(24) + butane(1)
# 1115 	 2.8 	 0.0 	 Disproportionation 	 CH3O2(45) + PC4H9(182) <=> CH3O2H(46) + C4H8(188)
# 580 	 3.6 	 0.0 	 Disproportionation 	 CH3CO(20) + C3H5-A(94) <=> CH2CO(24) + C3H6(12)
# 551 	 9.2 	 0.0 	 Disproportionation 	 CH2CHO(21) + C2H5(33) <=> CH2CO(24) + C2H6(32)
# 1734 	 3.6 	 0.0 	 H_Abstraction 	 CH3CHO(35) + S(223) <=> CH2CHO(21) + S(187)
# 719 	 3.6 	 0.0 	 Disproportionation 	 CH3CO(20) + C4H7(190) <=> CH2CO(24) + C4H8(189)
# 1527 	 1.8 	 0.0 	 Disproportionation 	 CH3O(31) + SC4H9(183) <=> CH3OH(30) + C4H8(188)
# 299 	 1.8 	 0.0 	 Disproportionation 	 C2H5(33) + PC4H9(182) <=> C2H4(11) + butane(1)
# 1039 	 2.0 	 0.0 	 Disproportionation 	 OH(15) + C4H7(191) <=> H2O(8) + C4H6(194)
# 1122 	 3.2 	 0.0 	 Disproportionation 	 CH3O2(45) + C2H3(22) <=> CH3O2H(46) + C2H2(25)
# 1259 	 1.8 	 0.0 	 H_Abstraction 	 CH3CHO(35) + C4H7(191) <=> CH3CO(20) + C4H8(188)
# 542 	 4.6 	 0.0 	 Disproportionation 	 CH3O(31) + C2H5(33) <=> CH2O(9) + C2H6(32)
# 1737 	 1.8 	 0.0 	 H_Abstraction 	 CH3O2(45) + S(187) <=> CH3O2H(46) + S(186)
# 1304 	 4.3 	 0.0 	 H_Abstraction 	 S(911) + C4H8(189) <=> C3H6O3(73) + C4H7(190)
# 855 	 1.8 	 0.0 	 Disproportionation 	 SC4H9(183) + S(225) <=> C4H8(188) + S(787)
# 904 	 1.8 	 0.0 	 Disproportionation 	 C4H7(190) + S(225) <=> C4H6(194) + S(787)
# 823 	 1.0 	 0.0 	 H_Abstraction 	 C4H8(188) + S(229) <=> C4H7(190) + S(787)
# 993 	 1.8 	 0.0 	 Disproportionation 	 O(5) + C4H7(190) <=> OH(15) + C4H6(194)
# 717 	 2.0 	 0.0 	 Disproportionation 	 NC3H7(92) + C4H7(190) <=> C3H6(12) + C4H8(188)
# 1348 	 4.2 	 0.0 	 Disproportionation 	 C3H5O3(72) + SC4H9(183) <=> C3H6O3(73) + C4H8(189)
# 799 	 1.8 	 0.0 	 Disproportionation 	 C4H7(190) + PC4H9(182) <=> C4H6(194) + butane(1)
# 590 	 0.5 	 0.0 	 H_Abstraction 	 C2H3(22) + C3H6(12) <=> C2H4(11) + C3H5-A(94)
# 1339 	 1.8 	 0.0 	 CO_Disproportionation 	 HCO(19) + C3H5O3(72) <=> CO(6) + C3H6O3(73)
# 1029 	 2.0 	 0.0 	 H_Abstraction 	 C4H7(191) + butane(1) <=> C4H8(188) + PC4H9(182)
# 298 	 1.8 	 0.0 	 CO_Disproportionation 	 HCO(19) + PC4H9(182) <=> CO(6) + butane(1)
# 1326 	 10.7 	 0.0 	 Disproportionation 	 CH2CHO(21) + C3H5O3(72) <=> CH2CO(24) + C3H6O3(73)
# 1180 	 2.8 	 0.0 	 H_Abstraction 	 CH3CHO(35) + C4H7(192) <=> CH2CHO(21) + C4H8(188)
# 1300 	 1.8 	 0.0 	 H_Abstraction 	 C2H3(22) + C3H6O3(73) <=> C2H4(11) + C3H5O3(72)
# 1303 	 1.8 	 0.0 	 H_Abstraction 	 C3H5-A(94) + C3H6O3(73) <=> C3H5O3(72) + C3H6(12)
# 510 	 2.0 	 0.0 	 Disproportionation 	 C2H5(33) + PC4H9(182) <=> C2H6(32) + C4H8(188)
# 1322 	 1.8 	 0.0 	 Disproportionation 	 C3H5O3(72) + C4H7(190) <=> C3H6O3(73) + C4H6(194)
# 423 	 3.6 	 0.0 	 Disproportionation 	 HCO(19) + CH3CO(20) <=> CH2O(9) + CH2CO(24)
# 321 	 1.8 	 0.0 	 Disproportionation 	 PC4H9(182) + PC4H9(182) <=> C4H8(188) + butane(1)
# 835 	 1.8 	 0.0 	 R_Recombination 	 H(14) + S(225) <=> S(787)
# 1213 	 10.7 	 0.0 	 Disproportionation 	 HO2(16) + C3H5O(129) <=> H2O2(17) + C3H4O(74)
# 847 	 4.2 	 0.0 	 Disproportionation 	 SC4H9(183) + S(225) <=> C4H8(189) + S(787)
# 856 	 1.8 	 0.0 	 Disproportionation 	 SC4H9(183) + S(229) <=> C4H8(188) + S(787)
# 765 	 1.0 	 0.0 	 H_Abstraction 	 C2H4(11) + C4H7(190) <=> C2H3(22) + C4H8(189)
# 1520 	 10.7 	 0.0 	 Disproportionation 	 CH3O(31) + CH2CHO(21) <=> CH3OH(30) + CH2CO(24)
# 715 	 1.8 	 0.0 	 Disproportionation 	 NC3H7(92) + C4H7(190) <=> C3H6(12) + C4H8(189)
# 905 	 1.8 	 0.0 	 Disproportionation 	 C4H7(190) + S(229) <=> C4H6(194) + S(787)
# 1028 	 2.0 	 0.0 	 H_Abstraction 	 C3H6(12) + C4H7(191) <=> C3H5-A(94) + C4H8(188)
# 740 	 3.2 	 0.0 	 H_Abstraction 	 C4H8(189) + SC4H9(183) <=> C4H7(190) + butane(1)
# 1720 	 2.0 	 0.0 	 H_Abstraction 	 OH(15) + S(187) <=> H2O(8) + S(223)
# 1296 	 1.8 	 0.0 	 H_Abstraction 	 C3H6O3(73) + C4H7(192) <=> C3H5O3(72) + C4H8(188)
# 1034 	 2.4 	 0.0 	 H_Abstraction 	 C4H7(191) + C4H8(189) <=> C4H7(190) + C4H8(188)
# 1033 	 1.8 	 0.0 	 H_Abstraction 	 C4H7(191) + C4H8(188) <=> C4H7(190) + C4H8(188)
# 458 	 1.8 	 0.0 	 Disproportionation 	 H(14) + SC4H9(183) <=> H2(13) + C4H8(188)
# 1181 	 3.3 	 0.0 	 H_Abstraction 	 C4H7(192) + butane(1) <=> C4H8(188) + SC4H9(183)
# 819 	 1.8 	 0.0 	 H_Abstraction 	 C4H7(190) + S(787) <=> C4H8(189) + S(229)
# 1024 	 2.0 	 0.0 	 H_Abstraction 	 C2H6(32) + C4H7(191) <=> C2H5(33) + C4H8(188)
# 1012 	 1.8 	 0.0 	 CO_Disproportionation 	 HCO(19) + C4H7(191) <=> CO(6) + C4H8(188)
# 836 	 1.8 	 0.0 	 R_Recombination 	 H(14) + S(229) <=> S(787)
# 444 	 1.8 	 0.0 	 Disproportionation 	 CH2CHO(21) + SC4H9(183) <=> CH3CHO(35) + C4H8(188)
# 1301 	 1.0 	 0.0 	 H_Abstraction 	 HO2(16) + C3H6O3(73) <=> H2O2(17) + S(911)
# 848 	 4.2 	 0.0 	 Disproportionation 	 SC4H9(183) + S(229) <=> C4H8(189) + S(787)
# 480 	 2.4 	 0.0 	 H_Abstraction 	 OH(15) + CH2(23) <=> O(5) + CH3(18)
# 1732 	 2.0 	 0.0 	 H_Abstraction 	 C4H8(188) + S(223) <=> C4H7(191) + S(187)
# 1007 	 1.8 	 0.0 	 Disproportionation 	 C2H5(33) + C4H7(191) <=> C2H4(11) + C4H8(188)
# 1681 	 3.6 	 0.0 	 Disproportionation 	 CH3CO(20) + C2H5O2(47) <=> CH2CO(24) + C2H6O2(48)
# 1031 	 1.8 	 0.0 	 H_Abstraction 	 CH2O(9) + C4H7(191) <=> HCO(19) + C4H8(188)
# 873 	 1.8 	 0.0 	 CO_Disproportionation 	 HCO(19) + S(225) <=> CO(6) + S(787)
# 1753 	 2.0 	 0.0 	 H_Abstraction 	 CH3(18) + S(187) <=> CH4(10) + S(223)
# 252 	 3.6 	 0.0 	 Disproportionation 	 CH3CO(20) + SC4H9(183) <=> CH2CO(24) + butane(1)
# 1299 	 1.0 	 0.0 	 H_Abstraction 	 OH(15) + C3H6O3(73) <=> H2O(8) + S(911)
# 1747 	 1.8 	 0.0 	 H_Abstraction 	 C2H6O2(48) + S(186) <=> C2H5O2(47) + S(187)
# 1027 	 3.3 	 0.0 	 H_Abstraction 	 C4H7(191) + butane(1) <=> C4H8(188) + SC4H9(183)
# 320 	 1.8 	 0.0 	 Disproportionation 	 SC4H9(183) + SC4H9(183) <=> C4H8(188) + butane(1)
# 456 	 1.8 	 0.0 	 Disproportionation 	 H(14) + SC4H9(183) <=> H2(13) + C4H8(189)
# 1776 	 2.8 	 0.0 	 Disproportionation 	 PC4H9(182) + S(186) <=> C4H8(188) + S(187)
# 426 	 3.6 	 0.0 	 Disproportionation 	 CH3CO(20) + CH3CO(20) <=> CH2CO(24) + CH3CHO(35)
# 398 	 4.2 	 0.0 	 Disproportionation 	 HO2(16) + NC3H7(92) <=> H2O2(17) + C3H6(12)
# 1113 	 1.8 	 0.0 	 Disproportionation 	 CH3O2(45) + IC3H7(93) <=> CH3O2H(46) + C3H6(12)
# 575 	 0.5 	 0.0 	 Disproportionation 	 C3H5-A(94) + NC3H7(92) <=> C3H6(12) + C3H6(12)
# 1530 	 2.0 	 0.0 	 Disproportionation 	 CH3O(31) + C4H7(191) <=> CH3OH(30) + C4H6(194)
# 1787 	 2.0 	 0.0 	 H_Abstraction 	 C3H6(12) + S(223) <=> C3H5-A(94) + S(187)
# 1066 	 1.8 	 0.0 	 H_Abstraction 	 C2H3(22) + C4H8(188) <=> C2H4(11) + C4H7(191)
# 1183 	 1.8 	 0.0 	 H_Abstraction 	 C4H7(192) + butane(1) <=> C4H8(188) + PC4H9(182)
# 1037 	 2.0 	 0.0 	 Disproportionation 	 C4H7(191) + SC4H9(183) <=> C4H6(194) + butane(1)
# 1682 	 3.2 	 0.0 	 Disproportionation 	 C2H3(22) + C2H5O2(47) <=> C2H2(25) + C2H6O2(48)
# 1058 	 2.0 	 0.0 	 Disproportionation 	 C2H5(33) + C4H7(191) <=> C2H6(32) + C4H6(194)
# 552 	 3.2 	 0.0 	 Disproportionation 	 C2H3(22) + C2H5(33) <=> C2H2(25) + C2H6(32)
# 576 	 1.8 	 0.0 	 Disproportionation 	 C3H5-A(94) + IC3H7(93) <=> C3H6(12) + C3H6(12)
# 874 	 1.8 	 0.0 	 CO_Disproportionation 	 HCO(19) + S(229) <=> CO(6) + S(787)
# 840 	 1.0 	 0.0 	 H_Abstraction 	 HO2(16) + S(787) <=> H2O2(17) + S(238)
# 918 	 10.7 	 0.0 	 Disproportionation 	 HO2(16) + S(777) <=> H2O2(17) + S(252)
# 477 	 5.4 	 0.0 	 Disproportionation 	 O(5) + SC4H9(183) <=> OH(15) + C4H8(189)
# 408 	 0.5 	 0.0 	 Disproportionation 	 CH3(18) + NC3H7(92) <=> CH4(10) + C3H6(12)
# 388 	 1.8 	 0.0 	 H_Abstraction 	 H2O2(17) + CH2(23) <=> HO2(16) + CH3(18)
# 1045 	 1.8 	 0.0 	 Disproportionation 	 C4H7(190) + C4H7(191) <=> C4H6(194) + C4H8(188)
# 1521 	 0.5 	 0.0 	 CO_Disproportionation 	 HCO(19) + CH3O(31) <=> CO(6) + CH3OH(30)
# 1245 	 1.8 	 0.0 	 Disproportionation 	 O(5) + C2H3(22) <=> OH(15) + C2H2(25)
# 505 	 0.5 	 0.0 	 H_Abstraction 	 C2H3(22) + C2H6(32) <=> C2H4(11) + C2H5(33)
# 963 	 10.7 	 0.0 	 Disproportionation 	 HO2(16) + C2H5O(49) <=> H2O2(17) + CH3CHO(35)
# 219 	 1.8 	 0.0 	 Disproportionation 	 HCO(19) + C2H5(33) <=> CH2O(9) + C2H4(11)
# 1325 	 2.0 	 0.0 	 H_Abstraction 	 HO2(16) + S(911) <=> O2(2) + C3H6O3(73)
# 1292 	 1.0 	 0.0 	 H_Abstraction 	 OH(15) + C3H6O3(73) <=> H2O(8) + C3H5O3(72)
# 1036 	 2.8 	 0.0 	 Disproportionation 	 HO2(16) + C4H7(191) <=> H2O2(17) + C4H6(194)
# 1046 	 1.8 	 0.0 	 Disproportionation 	 CH2CHO(21) + C4H7(191) <=> CH3CHO(35) + C4H6(194)
# 409 	 1.8 	 0.0 	 Disproportionation 	 CH3(18) + IC3H7(93) <=> CH4(10) + C3H6(12)
# 1687 	 1.8 	 0.0 	 Disproportionation 	 C2H5O2(47) + IC3H7(93) <=> C2H6O2(48) + C3H6(12)
# 716 	 1.8 	 0.0 	 Disproportionation 	 IC3H7(93) + C4H7(190) <=> C3H6(12) + C4H8(189)
# 718 	 1.8 	 0.0 	 Disproportionation 	 IC3H7(93) + C4H7(190) <=> C3H6(12) + C4H8(188)
# 1424 	 1.0 	 0.0 	 H_Abstraction 	 C2H3(22) + C4H8(188) <=> C2H4(11) + C4H7(192)
# 588 	 3.2 	 0.0 	 Disproportionation 	 C2H3(22) + CH2CHO(21) <=> C2H2(25) + CH3CHO(35)
# 425 	 3.6 	 0.0 	 Disproportionation 	 CH2CHO(21) + CH3CO(20) <=> CH2CO(24) + CH3CHO(35)
# 826 	 1.0 	 0.0 	 H_Abstraction 	 CH2CHO(21) + S(787) <=> CH3CHO(35) + S(225)
# 322 	 1.8 	 0.0 	 Disproportionation 	 PC4H9(182) + SC4H9(183) <=> C4H8(188) + butane(1)
# 457 	 1.8 	 0.0 	 Disproportionation 	 H(14) + PC4H9(182) <=> H2(13) + C4H8(188)
# 1306 	 3.6 	 0.0 	 H_Abstraction 	 C3H6O3(73) + C4H7(191) <=> S(911) + C4H8(188)
# 829 	 1.8 	 0.0 	 H_Abstraction 	 C2H3(22) + S(787) <=> C2H4(11) + S(225)
# 403 	 0.5 	 0.0 	 Disproportionation 	 OH(15) + NC3H7(92) <=> H2O(8) + C3H6(12)
# 1014 	 1.8 	 0.0 	 Disproportionation 	 C4H7(191) + SC4H9(183) <=> C4H8(188) + C4H8(189)
# 1101 	 2.0 	 0.0 	 H_Abstraction 	 CH3O2H(46) + S(244) <=> CH3O2(45) + S(787)
# 1308 	 8.2 	 0.0 	 H_Abstraction 	 CH2CHO(21) + C3H6O3(73) <=> CH3CHO(35) + S(911)
# 1222 	 3.9 	 0.0 	 Disproportionation 	 C3H5-A(94) + C3H5O(129) <=> C3H4O(74) + C3H6(12)
# 1349 	 1.8 	 0.0 	 Disproportionation 	 S(911) + SC4H9(183) <=> C3H6O3(73) + C4H8(189)
# 587 	 3.9 	 0.0 	 H_Abstraction 	 CH2CHO(21) + C3H6(12) <=> CH3CHO(35) + C3H5-A(94)
# 1310 	 1.0 	 0.0 	 H_Abstraction 	 CH4(10) + C3H5O3(72) <=> CH3(18) + C3H6O3(73)
# 977 	 10.7 	 0.0 	 Disproportionation 	 O(5) + C2H5O(49) <=> OH(15) + CH3CHO(35)
# 534 	 4.6 	 0.0 	 Disproportionation 	 HCO(19) + CH3O(31) <=> CH2O(9) + CH2O(9)
# 1631 	 9.2 	 0.0 	 Disproportionation 	 CH2CHO(21) + C4H6(2534) <=> CH2CO(24) + C4H7(191)
# 511 	 1.8 	 0.0 	 Disproportionation 	 C2H5(33) + SC4H9(183) <=> C2H6(32) + C4H8(188)
# 816 	 1.8 	 0.0 	 H_Abstraction 	 OH(15) + S(787) <=> H2O(8) + S(225)
# 416 	 1.8 	 0.0 	 Disproportionation 	 H(14) + IC3H7(93) <=> H2(13) + C3H6(12)
# 830 	 1.8 	 0.0 	 H_Abstraction 	 C3H5-A(94) + S(787) <=> C3H6(12) + S(225)
# 424 	 9.2 	 0.0 	 Disproportionation 	 HCO(19) + CH2CHO(21) <=> CH2O(9) + CH2CO(24)
# 1013 	 4.6 	 0.0 	 Disproportionation 	 CH3O(31) + C4H7(191) <=> CH2O(9) + C4H8(188)
# 1770 	 1.8 	 0.0 	 Disproportionation 	 IC3H7(93) + S(186) <=> C3H6(12) + S(187)
# 650 	 13.4 	 0.0 	 H_Abstraction 	 HO2(16) + C4H8(748) <=> O2(2) + SC4H9(183)
# 1432 	 3.6 	 0.0 	 H_Abstraction 	 CH3(18) + C3H6O3(73) <=> CH4(10) + S(911)
# 693 	 10.7 	 0.0 	 Disproportionation 	 O2(2) + C2H4O(703) <=> HO2(16) + CH2CHO(21)
# 1629 	 10.7 	 0.0 	 Disproportionation 	 CH3O(31) + C2H4O(703) <=> CH3OH(30) + CH2CHO(21)
# 1563 	 10.7 	 0.0 	 Disproportionation 	 OCHO(38) + S(225) <=> CO2(7) + S(787)
# 1357 	 10.7 	 0.0 	 Disproportionation 	 C2H5O(49) + C3H5O3(72) <=> CH3CHO(35) + C3H6O3(73)
# 1627 	 0.5 	 0.0 	 H_Abstraction 	 C2H3(22) + CH3CHO(35) <=> CH3CO(20) + C2H4(11)
# 478 	 5.4 	 0.0 	 Disproportionation 	 O(5) + PC4H9(182) <=> OH(15) + C4H8(188)
# 1555 	 9.2 	 0.0 	 Disproportionation 	 OCHO(38) + C4H7(191) <=> CO2(7) + C4H8(188)
# 865 	 3.6 	 0.0 	 Disproportionation 	 CH3CO(20) + S(225) <=> CH2CO(24) + S(787)
# 815 	 1.8 	 0.0 	 H_Abstraction 	 OH(15) + S(787) <=> H2O(8) + S(229)
# 254 	 3.2 	 0.0 	 Disproportionation 	 C2H3(22) + SC4H9(183) <=> C2H2(25) + butane(1)
# 1793 	 10.7 	 0.0 	 Disproportionation 	 C3H5O(129) + S(186) <=> C3H4O(74) + S(187)
# 435 	 1.8 	 0.0 	 Disproportionation 	 CH3CO(20) + C2H5(33) <=> C2H4(11) + CH3CHO(35)
# 1225 	 3.9 	 0.0 	 Disproportionation 	 C3H5O(129) + C4H7(190) <=> C3H4O(74) + C4H8(189)
# 1749 	 1.8 	 0.0 	 H_Abstraction 	 HO2(16) + S(223) <=> O2(2) + S(187)
# 1523 	 2.0 	 0.0 	 Disproportionation 	 CH3O(31) + NC3H7(92) <=> CH3OH(30) + C3H6(12)
# 773 	 11.2 	 0.0 	 H_Abstraction 	 CH3CO(20) + C4H8(188) <=> CH3CHO(35) + C4H7(190)
# 1187 	 1.0 	 0.0 	 H_Abstraction 	 C4H7(190) + C4H8(188) <=> C4H7(192) + C4H8(188)
# 754 	 3.2 	 0.0 	 H_Abstraction 	 CH2(23) + C4H8(189) <=> CH3(18) + C4H7(190)
# 1695 	 10.7 	 0.0 	 Disproportionation 	 C2H5O2(47) + C3H5O(129) <=> C2H6O2(48) + C3H4O(74)
# 1428 	 10.7 	 0.0 	 Disproportionation 	 C3H5O(129) + C3H5O3(72) <=> C3H4O(74) + C3H6O3(73)
# 1578 	 10.7 	 0.0 	 Disproportionation 	 OCHO(38) + C2H4O(703) <=> HOCHO(40) + CH2CHO(21)
# 1158 	 1.0 	 0.0 	 H_Abstraction 	 CH3(18) + C4H8(188) <=> CH4(10) + C4H7(192)
# 1557 	 9.2 	 0.0 	 Disproportionation 	 OCHO(38) + CH2CHO(21) <=> CO2(7) + CH3CHO(35)
# 479 	 1.8 	 0.0 	 Disproportionation 	 O(5) + SC4H9(183) <=> OH(15) + C4H8(188)
# 1226 	 2.8 	 0.0 	 Disproportionation 	 C3H5O(129) + C4H7(190) <=> C3H4O(74) + C4H8(188)
# 1564 	 10.7 	 0.0 	 Disproportionation 	 OCHO(38) + S(229) <=> CO2(7) + S(787)
# 933 	 10.7 	 0.0 	 Disproportionation 	 S(777) + S(229) <=> S(252) + S(787)
# 1774 	 1.8 	 0.0 	 Disproportionation 	 SC4H9(183) + S(223) <=> C4H8(189) + S(187)
# 1781 	 10.7 	 0.0 	 Disproportionation 	 S(186) + S(777) <=> S(252) + S(187)
# 1341 	 4.6 	 0.0 	 Disproportionation 	 CH3O(31) + S(911) <=> CH2O(9) + C3H6O3(73)
# 1241 	 10.7 	 0.0 	 Disproportionation 	 C3H5O(129) + S(225) <=> C3H4O(74) + S(787)
# 1011 	 9.2 	 0.0 	 Disproportionation 	 CH2CHO(21) + C4H7(191) <=> CH2CO(24) + C4H8(188)
# 1212 	 10.7 	 0.0 	 Disproportionation 	 O(5) + C3H5O(129) <=> OH(15) + C3H4O(74)
# 1038 	 1.8 	 0.0 	 Disproportionation 	 C4H7(191) + PC4H9(182) <=> C4H6(194) + butane(1)
# 1562 	 9.2 	 0.0 	 Disproportionation 	 OCHO(38) + C4H6(2534) <=> CO2(7) + C4H7(190)
# 1754 	 10.7 	 0.0 	 Disproportionation 	 C2H4O(703) + S(186) <=> CH2CHO(21) + S(187)
# 1057 	 1.8 	 0.0 	 Disproportionation 	 H(14) + C4H7(191) <=> H2(13) + C4H6(194)
# 1003 	 13.4 	 0.0 	 H_Abstraction 	 HO2(16) + C4H7(191) <=> O2(2) + C4H8(188)
# 928 	 10.7 	 0.0 	 Disproportionation 	 O(5) + S(777) <=> OH(15) + S(252)
# 1015 	 1.8 	 0.0 	 Disproportionation 	 C4H7(191) + PC4H9(182) <=> C4H8(188) + C4H8(188)
# 1545 	 10.7 	 0.0 	 Disproportionation 	 OH(15) + OCHO(38) <=> H2O(8) + CO2(7)
# 257 	 2.0 	 0.0 	 Disproportionation 	 NC3H7(92) + SC4H9(183) <=> C3H6(12) + butane(1)
# 295 	 3.6 	 0.0 	 Disproportionation 	 CH3CO(20) + PC4H9(182) <=> CH2CO(24) + butane(1)
# 1565 	 9.2 	 0.0 	 Disproportionation 	 OCHO(38) + S(244) <=> CO2(7) + S(787)
# 1528 	 10.7 	 0.0 	 Disproportionation 	 CH3O(31) + S(777) <=> CH3OH(30) + S(252)
# 1553 	 9.2 	 0.0 	 Disproportionation 	 H(14) + OCHO(38) <=> H2(13) + CO2(7)
# 1765 	 4.6 	 0.0 	 Disproportionation 	 CH3O(31) + S(223) <=> CH2O(9) + S(187)
# 1100 	 1.8 	 0.0 	 H_Abstraction 	 CH3O2(45) + S(787) <=> CH3O2H(46) + S(229)
# 832 	 1.0 	 0.0 	 H_Abstraction 	 CH4(10) + S(225) <=> CH3(18) + S(787)
# 1327 	 3.9 	 0.0 	 H_Abstraction 	 S(911) + C3H6(12) <=> C3H5-A(94) + C3H6O3(73)
# 1584 	 10.7 	 0.0 	 Disproportionation 	 OCHO(38) + OCHO(38) <=> CO2(7) + HOCHO(40)
# 801 	 1.8 	 0.0 	 Disproportionation 	 HCO(19) + C4H7(190) <=> CH2O(9) + C4H6(194)
# 1242 	 10.7 	 0.0 	 Disproportionation 	 C3H5O(129) + S(229) <=> C3H4O(74) + S(787)
# 1660 	 1.8 	 0.0 	 H_Abstraction 	 C2H6O2(48) + S(225) <=> C2H5O2(47) + S(787)
# 1551 	 9.2 	 0.0 	 Disproportionation 	 OCHO(38) + CH3(18) <=> CO2(7) + CH4(10)
# 602 	 9.2 	 0.0 	 Disproportionation 	 C2H(4) + CH2CHO(21) <=> C2H2(25) + CH2CO(24)
# 824 	 1.0 	 0.0 	 H_Abstraction 	 CH2CHO(21) + S(787) <=> CH3CHO(35) + S(229)
# 549 	 2.8 	 0.0 	 H_Abstraction 	 C2H3(22) + CH3CHO(35) <=> CH2CHO(21) + C2H4(11)
# 986 	 1.0 	 0.0 	 H_Abstraction 	 CH4(10) + S(229) <=> CH3(18) + S(787)
# 550 	 3.6 	 0.0 	 Disproportionation 	 CH3CO(20) + C2H5(33) <=> CH2CO(24) + C2H6(32)
# 1670 	 1.8 	 0.0 	 H_Abstraction 	 C2H6O2(48) + C3H5O3(72) <=> C2H5O2(47) + C3H6O3(73)
# 1099 	 1.8 	 0.0 	 H_Abstraction 	 CH3O2(45) + S(787) <=> CH3O2H(46) + S(225)
# 866 	 3.6 	 0.0 	 Disproportionation 	 CH3CO(20) + S(229) <=> CH2CO(24) + S(787)
# 1182 	 1.0 	 0.0 	 H_Abstraction 	 C3H5-A(94) + C4H8(188) <=> C3H6(12) + C4H7(192)
# 1680 	 10.7 	 0.0 	 Disproportionation 	 C2H4O(703) + C2H5O2(47) <=> CH2CHO(21) + C2H6O2(48)
# 828 	 1.8 	 0.0 	 H_Abstraction 	 C2H3(22) + S(787) <=> C2H4(11) + S(229)
# 912 	 1.0 	 0.0 	 Birad_R_Recombination 	 O(5) + S(777) <=> S(229)
# 1797 	 3.6 	 0.0 	 H_Abstraction 	 H2O2(17) + C4H8(748) <=> HO2(16) + SC4H9(183)
# 217 	 9.2 	 0.0 	 Disproportionation 	 C2H3(22) + CH2CHO(21) <=> CH2CO(24) + C2H4(11)
# 1218 	 10.7 	 0.0 	 Disproportionation 	 OH(15) + C3H5O(129) <=> H2O(8) + C3H4O(74)
# 1547 	 10.7 	 0.0 	 Disproportionation 	 HO2(16) + OCHO(38) <=> H2O2(17) + CO2(7)
# 595 	 10.7 	 0.0 	 Disproportionation 	 O(5) + CH2CHO(21) <=> OH(15) + CH2CO(24)
# 1117 	 10.7 	 0.0 	 Disproportionation 	 CH3O2(45) + S(777) <=> CH3O2H(46) + S(252)
# 1756 	 3.6 	 0.0 	 Disproportionation 	 CH3CO(20) + S(186) <=> CH2CO(24) + S(187)
# 1102 	 1.8 	 0.0 	 H_Abstraction 	 CH3O2H(46) + S(238) <=> CH3O2(45) + S(787)
# 769 	 1.0 	 0.0 	 H_Abstraction 	 C4H7(190) + C4H8(188) <=> C4H7(190) + C4H8(189)
# 932 	 10.7 	 0.0 	 Disproportionation 	 S(777) + S(225) <=> S(252) + S(787)
# 837 	 5.9 	 0.0 	 R_Recombination 	 H(14) + S(244) <=> S(787)
# 1566 	 9.2 	 0.0 	 Disproportionation 	 OCHO(38) + S(238) <=> CO2(7) + S(787)
# 831 	 1.8 	 0.0 	 H_Abstraction 	 C3H5-A(94) + S(787) <=> C3H6(12) + S(229)
# 965 	 3.9 	 0.0 	 Disproportionation 	 C2H3(22) + C2H5O(49) <=> C2H4(11) + CH3CHO(35)
# 1602 	 10.7 	 0.0 	 Disproportionation 	 OCHO(38) + C3H5O(129) <=> HOCHO(40) + C3H4O(74)
# 629 	 10.7 	 0.0 	 Disproportionation 	 HO2(16) + C2H4O(703) <=> H2O2(17) + CH2CHO(21)
# 1614 	 9.2 	 0.0 	 Disproportionation 	 OCHO(38) + C4H8(748) <=> CO2(7) + SC4H9(183)
# 1350 	 2.8 	 0.0 	 Disproportionation 	 C3H5O3(72) + PC4H9(182) <=> C3H6O3(73) + C4H8(188)
# 1786 	 3.9 	 0.0 	 Disproportionation 	 C2H5O(49) + S(223) <=> CH3CHO(35) + S(187)
# 984 	 9.2 	 0.0 	 Disproportionation 	 CH2CHO(21) + C4H8(748) <=> CH2CO(24) + PC4H9(182)
# 436 	 1.8 	 0.0 	 Disproportionation 	 CH2CHO(21) + NC3H7(92) <=> CH3CHO(35) + C3H6(12)
# 803 	 1.8 	 0.0 	 Disproportionation 	 CH3CO(20) + C4H7(190) <=> CH3CHO(35) + C4H6(194)
# 583 	 8.5 	 0.0 	 H_Abstraction 	 H2O2(17) + C2H(4) <=> HO2(16) + C2H2(25)
# 1789 	 3.9 	 0.0 	 Disproportionation 	 C4H8(748) + S(223) <=> C4H7(190) + S(187)
# 1795 	 9.2 	 0.0 	 Disproportionation 	 OCHO(38) + C4H6(2534) <=> CO2(7) + C4H7(191)
# 1619 	 10.7 	 0.0 	 Disproportionation 	 OCHO(38) + CH3O(31) <=> CO2(7) + CH3OH(30)
# 1524 	 1.8 	 0.0 	 Disproportionation 	 CH3O(31) + IC3H7(93) <=> CH3OH(30) + C3H6(12)
# 1371 	 3.9 	 0.0 	 Disproportionation 	 C4H6(2534) + PC4H9(182) <=> C4H7(190) + C4H8(188)
# 630 	 10.7 	 0.0 	 Disproportionation 	 OH(15) + C2H4O(703) <=> H2O(8) + CH2CHO(21)
# 1764 	 9.2 	 0.0 	 Disproportionation 	 OCHO(38) + S(223) <=> CO2(7) + S(187)
# 535 	 4.6 	 0.0 	 Disproportionation 	 CH3O(31) + C2H3(22) <=> CH2O(9) + C2H4(11)
# 1467 	 4.3 	 0.0 	 H_Abstraction 	 OH(15) + C2H(4) <=> O(5) + C2H2(25)
# 762 	 6.3 	 0.0 	 Disproportionation 	 CH3(18) + C4H8(748) <=> CH4(10) + C4H7(190)
# 1581 	 10.7 	 0.0 	 Disproportionation 	 OCHO(38) + CH2CHO(21) <=> HOCHO(40) + CH2CO(24)
# 1220 	 6.3 	 0.0 	 Disproportionation 	 CH3(18) + C3H5O(129) <=> CH4(10) + C3H4O(74)
# 1118 	 10.7 	 0.0 	 Disproportionation 	 CH3O2(45) + C2H5O(49) <=> CH3O2H(46) + CH3CHO(35)
# 1595 	 10.7 	 0.0 	 Disproportionation 	 OCHO(38) + C2H5O(49) <=> HOCHO(40) + CH3CHO(35)
# 1554 	 9.2 	 0.0 	 Disproportionation 	 OCHO(38) + C4H7(190) <=> CO2(7) + C4H8(188)
# 1561 	 9.2 	 0.0 	 Disproportionation 	 OCHO(38) + C2H(4) <=> CO2(7) + C2H2(25)
# 846 	 4.6 	 0.0 	 Disproportionation 	 CH3O(31) + S(238) <=> CH2O(9) + S(787)
# 851 	 2.8 	 0.0 	 Disproportionation 	 PC4H9(182) + S(225) <=> C4H8(188) + S(787)
# 1228 	 3.9 	 0.0 	 Disproportionation 	 C3H5O(129) + C4H7(192) <=> C3H4O(74) + C4H8(188)
# 1397 	 3.9 	 0.0 	 Disproportionation 	 C4H6(2534) + C4H7(191) <=> C4H6(194) + C4H7(190)
# 930 	 6.3 	 0.0 	 Disproportionation 	 CH2(23) + S(777) <=> CH3(18) + S(252)
# 985 	 13.4 	 0.0 	 H_Abstraction 	 HO2(16) + C2H4O(703) <=> O2(2) + C2H5O(49)
# 1470 	 1.8 	 0.0 	 H_Abstraction 	 CH3CHO(35) + C4H7(192) <=> CH3CO(20) + C4H8(188)
# 1802 	 9.2 	 0.0 	 Disproportionation 	 OCHO(38) + C4H8(748) <=> CO2(7) + PC4H9(182)
# 1374 	 3.9 	 0.0 	 Disproportionation 	 C4H6(2534) + C4H8(748) <=> C4H7(190) + C4H7(190)
# 430 	 1.8 	 0.0 	 CO_Disproportionation 	 HCO(19) + CH3CO(20) <=> CO(6) + CH3CHO(35)
# 881 	 4.2 	 0.0 	 Disproportionation 	 NC3H7(92) + S(225) <=> C3H6(12) + S(787)
# 1515 	 2.8 	 0.0 	 H_Abstraction 	 CH3O(31) + C3H6O3(73) <=> CH3OH(30) + C3H5O3(72)
# 1355 	 3.9 	 0.0 	 Disproportionation 	 S(911) + S(777) <=> C3H6O3(73) + S(252)
# 987 	 4.0 	 0.0 	 H_Abstraction 	 H(14) + S(787) <=> H2(13) + S(229)
# 1338 	 9.2 	 0.0 	 Disproportionation 	 CH2CHO(21) + S(911) <=> CH2CO(24) + C3H6O3(73)
# 469 	 9.2 	 0.0 	 Disproportionation 	 CH2(23) + CH2CHO(21) <=> CH3(18) + CH2CO(24)
# 845 	 4.6 	 0.0 	 Disproportionation 	 CH3O(31) + S(244) <=> CH2O(9) + S(787)
# 761 	 4.6 	 0.0 	 Disproportionation 	 HCO(19) + C4H8(748) <=> CH2O(9) + C4H7(190)
# 1336 	 3.6 	 0.0 	 Disproportionation 	 CH3CO(20) + C3H5O3(72) <=> CH2CO(24) + C3H6O3(73)
# 1312 	 2.8 	 0.0 	 H_Abstraction 	 C2H3(22) + C3H6O3(73) <=> C2H4(11) + S(911)
# 1427 	 1.8 	 0.0 	 Disproportionation 	 S(911) + C4H7(190) <=> C3H6O3(73) + C4H6(194)
# 1759 	 3.2 	 0.0 	 Disproportionation 	 C2H3(22) + S(186) <=> C2H2(25) + S(187)
# 1763 	 10.7 	 0.0 	 Disproportionation 	 OCHO(38) + S(186) <=> CO2(7) + S(187)
# 1739 	 1.8 	 0.0 	 H_Abstraction 	 C2H3(22) + S(187) <=> C2H4(11) + S(223)
# 1010 	 3.6 	 0.0 	 Disproportionation 	 CH3CO(20) + C4H7(191) <=> CH2CO(24) + C4H8(188)
# 1214 	 6.3 	 0.0 	 Disproportionation 	 CH2(23) + C3H5O(129) <=> CH3(18) + C3H4O(74)
# 683 	 4.6 	 0.0 	 Disproportionation 	 CH3O(31) + C4H8(748) <=> CH2O(9) + PC4H9(182)
# 1580 	 3.6 	 0.0 	 Disproportionation 	 OCHO(38) + CH3CO(20) <=> HOCHO(40) + CH2CO(24)
# 1351 	 1.8 	 0.0 	 Disproportionation 	 S(911) + PC4H9(182) <=> C3H6O3(73) + C4H8(188)
# 1119 	 2.8 	 0.0 	 Disproportionation 	 CH3O2(45) + C4H8(748) <=> CH3O2H(46) + C4H7(190)
# 412 	 1.8 	 0.0 	 Disproportionation 	 C2H3(22) + SC4H9(183) <=> C2H4(11) + C4H8(189)
# 1593 	 10.7 	 0.0 	 Disproportionation 	 OCHO(38) + S(777) <=> HOCHO(40) + S(252)
# 1438 	 3.9 	 0.0 	 Disproportionation 	 S(911) + C4H8(748) <=> C3H6O3(73) + C4H7(190)
# 926 	 3.9 	 0.0 	 Disproportionation 	 C4H8(748) + S(777) <=> S(252) + SC4H9(183)
# 1022 	 3.2 	 0.0 	 Disproportionation 	 C2H3(22) + C4H7(191) <=> C2H2(25) + C4H8(188)
# 1689 	 2.8 	 0.0 	 Disproportionation 	 C2H5O2(47) + PC4H9(182) <=> C2H6O2(48) + C4H8(188)
# 760 	 5.4 	 0.0 	 Disproportionation 	 OH(15) + C4H8(748) <=> H2O(8) + C4H7(190)
# 441 	 2.0 	 0.0 	 Disproportionation 	 CH3CO(20) + SC4H9(183) <=> CH3CHO(35) + C4H8(189)
# 1433 	 10.7 	 0.0 	 Disproportionation 	 C2H4O(703) + C3H5O3(72) <=> CH2CHO(21) + C3H6O3(73)
# 1343 	 1.8 	 0.0 	 Disproportionation 	 C2H5(33) + S(911) <=> C2H4(11) + C3H6O3(73)
# 1550 	 9.2 	 0.0 	 Disproportionation 	 HCO(19) + OCHO(38) <=> CO2(7) + CH2O(9)
# 967 	 3.9 	 0.0 	 Disproportionation 	 C2H5O(49) + C4H7(190) <=> CH3CHO(35) + C4H8(189)
# 454 	 5.4 	 0.0 	 Disproportionation 	 O(5) + NC3H7(92) <=> OH(15) + C3H6(12)
# 758 	 2.8 	 0.0 	 Disproportionation 	 C4H8(748) + SC4H9(183) <=> C4H7(190) + butane(1)
# 1794 	 3.9 	 0.0 	 Disproportionation 	 C3H5O(129) + S(223) <=> C3H4O(74) + S(187)
# 1185 	 2.0 	 0.0 	 H_Abstraction 	 CH2O(9) + C4H7(192) <=> HCO(19) + C4H8(188)
# 1324 	 2.0 	 0.0 	 H_Abstraction 	 CH3O2H(46) + S(911) <=> CH3O2(45) + C3H6O3(73)
# 979 	 10.7 	 0.0 	 Disproportionation 	 C2H5O(49) + S(225) <=> CH3CHO(35) + S(787)
# 297 	 3.2 	 0.0 	 Disproportionation 	 C2H3(22) + PC4H9(182) <=> C2H2(25) + butane(1)
# 1112 	 4.2 	 0.0 	 Disproportionation 	 CH3O2(45) + NC3H7(92) <=> CH3O2H(46) + C3H6(12)
# 1307 	 2.8 	 0.0 	 H_Abstraction 	 C3H6O3(73) + C4H7(192) <=> S(911) + C4H8(188)
# 604 	 11.9 	 0.0 	 H_Abstraction 	 C2H(4) + C3H6(12) <=> C2H2(25) + C3H5-A(94)
# 1784 	 3.6 	 0.0 	 H_Abstraction 	 C3H6O3(73) + S(223) <=> S(911) + S(187)
# 655 	 13.5 	 0.0 	 H_Abstraction 	 HO2(16) + C4H8(748) <=> O2(2) + PC4H9(182)
# 1217 	 3.9 	 0.0 	 Disproportionation 	 C3H5O(129) + PC4H9(182) <=> C3H4O(74) + butane(1)
# 1434 	 3.9 	 0.0 	 Disproportionation 	 C2H4O(703) + S(911) <=> CH2CHO(21) + C3H6O3(73)
# 1767 	 1.8 	 0.0 	 Disproportionation 	 C2H5(33) + S(223) <=> C2H4(11) + S(187)
# 1724 	 1.8 	 0.0 	 H_Abstraction 	 S(229) + S(187) <=> S(186) + S(787)
# 1532 	 10.7 	 0.0 	 Disproportionation 	 CH3O(31) + C3H5O(129) <=> CH3OH(30) + C3H4O(74)
# 1344 	 4.2 	 0.0 	 Disproportionation 	 C3H5O3(72) + NC3H7(92) <=> C3H6(12) + C3H6O3(73)
# 1231 	 3.9 	 0.0 	 Disproportionation 	 C2H5(33) + C3H5O(129) <=> C2H6(32) + C3H4O(74)
# 1367 	 3.2 	 0.0 	 Disproportionation 	 C2H5(33) + C4H6(2534) <=> C2H4(11) + C4H7(190)
# 1768 	 4.2 	 0.0 	 Disproportionation 	 NC3H7(92) + S(186) <=> C3H6(12) + S(187)
# 1173 	 1.8 	 0.0 	 H_Abstraction 	 C4H7(192) + S(787) <=> C4H8(188) + S(225)
# 766 	 3.9 	 0.0 	 Disproportionation 	 C3H5-A(94) + C4H8(748) <=> C3H6(12) + C4H7(190)
# 1600 	 2.0 	 0.0 	 Disproportionation 	 OCHO(38) + C4H7(191) <=> HOCHO(40) + C4H6(194)
# 632 	 3.9 	 0.0 	 Disproportionation 	 CH2CHO(21) + C2H4O(703) <=> CH2CHO(21) + CH3CHO(35)
# 1060 	 5.4 	 0.0 	 Disproportionation 	 O(5) + C4H7(191) <=> OH(15) + C4H6(194)
# 1630 	 3.6 	 0.0 	 Disproportionation 	 CH3CO(20) + C4H6(2534) <=> CH2CO(24) + C4H7(191)
# 1762 	 1.8 	 0.0 	 CO_Disproportionation 	 HCO(19) + S(223) <=> CO(6) + S(187)
# 1178 	 1.0 	 0.0 	 H_Abstraction 	 C2H5(33) + C4H8(188) <=> C2H6(32) + C4H7(192)
# 1188 	 1.0 	 0.0 	 H_Abstraction 	 C4H7(190) + C4H8(188) <=> C4H7(192) + C4H8(189)
# 1120 	 2.8 	 0.0 	 Disproportionation 	 CH3O2(45) + C4H7(191) <=> CH3O2H(46) + C4H6(194)
# 806 	 3.7 	 0.0 	 H_Abstraction 	 SC4H9(183) + S(787) <=> S(244) + butane(1)
# 631 	 4.6 	 0.0 	 Disproportionation 	 HCO(19) + C2H4O(703) <=> CH2O(9) + CH2CHO(21)
# 772 	 2.8 	 0.0 	 Disproportionation 	 CH3CO(20) + C4H8(748) <=> CH3CHO(35) + C4H7(190)
# 1606 	 2.0 	 0.0 	 H_Abstraction 	 OCHO(38) + S(787) <=> HOCHO(40) + S(229)
# 482 	 1.8 	 0.0 	 Disproportionation 	 HCO(19) + C2H3(22) <=> CH2O(9) + C2H2(25)
# 468 	 3.6 	 0.0 	 Disproportionation 	 CH2(23) + CH3CO(20) <=> CH3(18) + CH2CO(24)
# 1572 	 10.7 	 0.0 	 Disproportionation 	 OCHO(38) + C3H5O3(72) <=> CO2(7) + C3H6O3(73)
# 1556 	 9.2 	 0.0 	 Disproportionation 	 OCHO(38) + C4H7(192) <=> CO2(7) + C4H8(188)
# 860 	 10.7 	 0.0 	 Disproportionation 	 C2H4O(703) + S(229) <=> CH2CHO(21) + S(787)
# 897 	 2.8 	 0.0 	 Disproportionation 	 C4H8(748) + S(229) <=> C4H7(190) + S(787)
# 1694 	 2.8 	 0.0 	 Disproportionation 	 C2H5O2(47) + C4H7(191) <=> C2H6O2(48) + C4H6(194)
# 428 	 9.2 	 0.0 	 Disproportionation 	 CH2CHO(21) + CH3CO(20) <=> CH2CO(24) + CH3CHO(35)
# 919 	 1.8 	 0.0 	 Disproportionation 	 HCO(19) + S(777) <=> CH2O(9) + S(252)
# 1529 	 10.7 	 0.0 	 Disproportionation 	 CH3O(31) + C2H5O(49) <=> CH3OH(30) + CH3CHO(35)
# 455 	 1.8 	 0.0 	 Disproportionation 	 O(5) + IC3H7(93) <=> OH(15) + C3H6(12)
# 1009 	 1.8 	 0.0 	 Disproportionation 	 IC3H7(93) + C4H7(191) <=> C3H6(12) + C4H8(188)
# 1691 	 10.7 	 0.0 	 Disproportionation 	 C2H5O2(47) + S(777) <=> C2H6O2(48) + S(252)
# 970 	 2.8 	 0.0 	 Disproportionation 	 CH3CO(20) + C2H5O(49) <=> CH3CHO(35) + CH3CHO(35)
# 1073 	 1.8 	 0.0 	 Disproportionation 	 C3H5-A(94) + C4H8(748) <=> C3H6(12) + C4H7(191)
# 1790 	 2.8 	 0.0 	 Disproportionation 	 C4H7(191) + S(186) <=> C4H6(194) + S(187)
# 771 	 3.9 	 0.0 	 Disproportionation 	 CH2CHO(21) + C4H8(748) <=> CH3CHO(35) + C4H7(190)
# 1154 	 1.0 	 0.0 	 H_Abstraction 	 O2(2) + C4H8(188) <=> HO2(16) + C4H7(192)
# 1607 	 2.0 	 0.0 	 H_Abstraction 	 OCHO(38) + S(787) <=> HOCHO(40) + S(225)
# 1032 	 3.9 	 0.0 	 Disproportionation 	 C4H7(191) + C4H8(748) <=> C4H7(190) + C4H8(188)
# 898 	 2.8 	 0.0 	 Disproportionation 	 C4H8(748) + S(244) <=> C4H7(190) + S(787)
# 1788 	 2.8 	 0.0 	 Disproportionation 	 C4H8(748) + S(186) <=> C4H7(190) + S(187)
# 1314 	 1.8 	 0.0 	 H_Abstraction 	 C3H6O3(73) + S(229) <=> C3H5O3(72) + S(787)
# 852 	 2.8 	 0.0 	 Disproportionation 	 PC4H9(182) + S(229) <=> C4H8(188) + S(787)
# 901 	 5.4 	 0.0 	 H_Abstraction 	 C4H8(188) + S(238) <=> C4H7(190) + S(787)
# 1740 	 4.0 	 0.0 	 H_Abstraction 	 C2H(4) + S(187) <=> C2H2(25) + S(186)
# 431 	 1.8 	 0.0 	 Disproportionation 	 HCO(19) + SC4H9(183) <=> CH2O(9) + C4H8(189)
# 407 	 1.8 	 0.0 	 Disproportionation 	 HCO(19) + IC3H7(93) <=> CH2O(9) + C3H6(12)
# 1738 	 1.8 	 0.0 	 H_Abstraction 	 CH3O2H(46) + S(223) <=> CH3O2(45) + S(187)
# 882 	 4.2 	 0.0 	 Disproportionation 	 NC3H7(92) + S(229) <=> C3H6(12) + S(787)
# 1686 	 4.2 	 0.0 	 Disproportionation 	 C2H5O2(47) + NC3H7(92) <=> C2H6O2(48) + C3H6(12)
# 807 	 3.7 	 0.0 	 H_Abstraction 	 PC4H9(182) + S(787) <=> S(244) + butane(1)
# 962 	 3.9 	 0.0 	 Disproportionation 	 C2H5O(49) + PC4H9(182) <=> CH3CHO(35) + butane(1)
# 507 	 0.5 	 0.0 	 Disproportionation 	 C2H5(33) + NC3H7(92) <=> C2H6(32) + C3H6(12)
# 923 	 3.9 	 0.0 	 Disproportionation 	 CH2CHO(21) + S(777) <=> CH3CHO(35) + S(252)
# 973 	 6.3 	 0.0 	 Disproportionation 	 CH2(23) + C2H5O(49) <=> CH3(18) + CH3CHO(35)
# 1549 	 9.2 	 0.0 	 Disproportionation 	 OCHO(38) + CH2(23) <=> CO2(7) + CH3(18)
# 1558 	 9.2 	 0.0 	 Disproportionation 	 OCHO(38) + CH3CO(20) <=> CO2(7) + CH3CHO(35)
# 1337 	 3.6 	 0.0 	 Disproportionation 	 CH3CO(20) + S(911) <=> CH2CO(24) + C3H6O3(73)
# 1758 	 9.2 	 0.0 	 Disproportionation 	 CH2CHO(21) + S(223) <=> CH2CO(24) + S(187)
# 1596 	 1.8 	 0.0 	 H_Abstraction 	 OCHO(38) + C3H6(12) <=> HOCHO(40) + C3H5-A(94)
# 616 	 3.9 	 0.0 	 Disproportionation 	 C2H4O(703) + PC4H9(182) <=> CH2CHO(21) + butane(1)
# 1692 	 10.7 	 0.0 	 Disproportionation 	 C2H5O(49) + C2H5O2(47) <=> CH3CHO(35) + C2H6O2(48)
# 853 	 1.8 	 0.0 	 Disproportionation 	 PC4H9(182) + S(244) <=> C4H8(188) + S(787)
# 691 	 3.9 	 0.0 	 Disproportionation 	 C2H4O(703) + C2H5(33) <=> CH2CHO(21) + C2H6(32)
# 1388 	 3.9 	 0.0 	 Disproportionation 	 C4H6(2534) + S(777) <=> C4H7(190) + S(252)
# 1661 	 1.8 	 0.0 	 H_Abstraction 	 C2H6O2(48) + S(229) <=> C2H5O2(47) + S(787)
# 1186 	 1.8 	 0.0 	 Disproportionation 	 C4H7(192) + C4H8(748) <=> C4H7(190) + C4H8(188)
# 917 	 3.9 	 0.0 	 Disproportionation 	 C4H7(190) + S(777) <=> C4H8(189) + S(252)
# 1746 	 1.8 	 0.0 	 H_Abstraction 	 CH3O(31) + S(187) <=> CH3OH(30) + S(223)
# 891 	 1.8 	 0.0 	 H_Abstraction 	 S(238) + S(787) <=> S(229) + S(787)
# 872 	 9.2 	 0.0 	 Disproportionation 	 CH2CHO(21) + S(238) <=> CH2CO(24) + S(787)
# 920 	 3.9 	 0.0 	 Disproportionation 	 C2H3(22) + S(777) <=> C2H4(11) + S(252)
# 1621 	 1.8 	 0.0 	 H_Abstraction 	 CH2(23) + C2H4(11) <=> CH3(18) + C2H3(22)
# 916 	 10.7 	 0.0 	 Disproportionation 	 OH(15) + S(777) <=> H2O(8) + S(252)
# 433 	 1.8 	 0.0 	 Disproportionation 	 HCO(19) + SC4H9(183) <=> CH2O(9) + C4H8(188)
# 751 	 2.8 	 0.0 	 Disproportionation 	 HO2(16) + C4H8(748) <=> H2O2(17) + C4H7(190)
# 1534 	 5.4 	 0.0 	 Disproportionation 	 CH3O(31) + C4H8(748) <=> CH3OH(30) + C4H7(190)
# 1221 	 3.9 	 0.0 	 Disproportionation 	 C2H3(22) + C3H5O(129) <=> C2H4(11) + C3H4O(74)
# 1576 	 2.0 	 0.0 	 Disproportionation 	 OCHO(38) + SC4H9(183) <=> HOCHO(40) + C4H8(189)
# 1573 	 9.2 	 0.0 	 Disproportionation 	 OCHO(38) + S(911) <=> CO2(7) + C3H6O3(73)
# 1775 	 2.0 	 0.0 	 H_Abstraction 	 S(223) + S(787) <=> S(229) + S(187)
# 382 	 1.8 	 0.0 	 Disproportionation 	 IC3H7(93) + PC4H9(182) <=> C3H6(12) + butane(1)
# 1741 	 1.8 	 0.0 	 H_Abstraction 	 C3H5O3(72) + S(187) <=> C3H6O3(73) + S(186)
# 1405 	 3.9 	 0.0 	 Disproportionation 	 C3H5O(129) + C4H6(2534) <=> C3H4O(74) + C4H7(190)
# 1353 	 1.8 	 0.0 	 Disproportionation 	 S(911) + SC4H9(183) <=> C3H6O3(73) + C4H8(188)
# 1792 	 1.8 	 0.0 	 Disproportionation 	 C4H7(190) + S(223) <=> C4H6(194) + S(187)
# 862 	 2.8 	 0.0 	 Disproportionation 	 C2H4O(703) + S(238) <=> CH2CHO(21) + S(787)
# 914 	 3.9 	 0.0 	 Disproportionation 	 PC4H9(182) + S(777) <=> S(252) + butane(1)
# 770 	 2.8 	 0.0 	 Disproportionation 	 C4H7(190) + C4H8(748) <=> C4H7(190) + C4H8(188)
# 1364 	 3.2 	 0.0 	 Disproportionation 	 C2H3(22) + C4H6(2534) <=> C2H2(25) + C4H7(190)
# 924 	 2.8 	 0.0 	 Disproportionation 	 CH3CO(20) + S(777) <=> CH3CHO(35) + S(252)
# 1356 	 2.0 	 0.0 	 H_Abstraction 	 S(911) + C3H6O3(73) <=> C3H5O3(72) + C3H6O3(73)
# 1174 	 1.8 	 0.0 	 H_Abstraction 	 C4H7(192) + S(787) <=> C4H8(188) + S(229)
# 406 	 1.8 	 0.0 	 Disproportionation 	 HCO(19) + NC3H7(92) <=> CH2O(9) + C3H6(12)
# 678 	 3.6 	 0.0 	 Disproportionation 	 CH3CO(20) + C4H8(748) <=> CH2CO(24) + SC4H9(183)
# 1519 	 3.6 	 0.0 	 Disproportionation 	 CH3O(31) + CH3CO(20) <=> CH3OH(30) + CH2CO(24)
# 1047 	 2.0 	 0.0 	 Disproportionation 	 CH3CO(20) + C4H7(191) <=> CH3CHO(35) + C4H6(194)
# 1362 	 3.6 	 0.0 	 Disproportionation 	 CH3CO(20) + C4H6(2534) <=> CH2CO(24) + C4H7(190)
# 1050 	 2.8 	 0.0 	 Disproportionation 	 C4H7(191) + S(225) <=> C4H6(194) + S(787)
# 1435 	 3.2 	 0.0 	 Disproportionation 	 C2H3(22) + C3H5O3(72) <=> C2H2(25) + C3H6O3(73)
# 1313 	 1.8 	 0.0 	 H_Abstraction 	 C3H6O3(73) + S(225) <=> C3H5O3(72) + S(787)
# 1044 	 1.8 	 0.0 	 Disproportionation 	 C4H7(191) + C4H7(191) <=> C4H6(194) + C4H8(188)
# 615 	 2.8 	 0.0 	 Disproportionation 	 C2H4O(703) + SC4H9(183) <=> CH2CHO(21) + butane(1)
# 381 	 1.8 	 0.0 	 Disproportionation 	 IC3H7(93) + SC4H9(183) <=> C3H6(12) + butane(1)
# 1254 	 1.8 	 0.0 	 Disproportionation 	 C4H7(191) + C4H8(748) <=> C4H7(191) + C4H8(188)
# 972 	 6.3 	 0.0 	 Disproportionation 	 CH3(18) + C2H5O(49) <=> CH4(10) + CH3CHO(35)
# 755 	 1.8 	 0.0 	 Disproportionation 	 C2H(4) + C4H8(748) <=> C2H2(25) + C4H7(190)
# 670 	 1.8 	 0.0 	 CO_Disproportionation 	 HCO(19) + C4H8(748) <=> CO(6) + SC4H9(183)
# 1171 	 3.9 	 0.0 	 Disproportionation 	 C2H5O(49) + C4H7(192) <=> CH3CHO(35) + C4H8(188)
# 902 	 3.6 	 0.0 	 H_Abstraction 	 C4H8(189) + S(244) <=> C4H7(190) + S(787)
# ...
# 982 	 2.8 	 0.0 	 Disproportionation 	 C2H5O(49) + S(238) <=> CH3CHO(35) + S(787)
# 969 	 3.9 	 0.0 	 Disproportionation 	 CH2CHO(21) + C2H5O(49) <=> CH3CHO(35) + CH3CHO(35)
# 1662 	 1.0 	 0.0 	 H_Abstraction 	 C2H6O2(48) + S(244) <=> C2H5O2(47) + S(787)
# 1369 	 1.8 	 0.0 	 Disproportionation 	 IC3H7(93) + C4H6(2534) <=> C3H6(12) + C4H7(190)
# 736 	 3.9 	 0.0 	 Disproportionation 	 C2H4O(703) + C4H7(190) <=> CH2CHO(21) + C4H8(189)
# 961 	 2.8 	 0.0 	 Disproportionation 	 C2H5O(49) + SC4H9(183) <=> CH3CHO(35) + butane(1)
# 1216 	 2.8 	 0.0 	 Disproportionation 	 C3H5O(129) + SC4H9(183) <=> C3H4O(74) + butane(1)
# 1745 	 2.8 	 0.0 	 H_Abstraction 	 CH3O(31) + S(187) <=> CH3OH(30) + S(186)
# 1059 	 1.8 	 0.0 	 Disproportionation 	 C4H7(191) + C4H8(748) <=> C4H6(194) + SC4H9(183)
# 674 	 1.8 	 0.0 	 Disproportionation 	 C4H8(748) + SC4H9(183) <=> C4H8(188) + SC4H9(183)
# 871 	 9.2 	 0.0 	 Disproportionation 	 CH2CHO(21) + S(244) <=> CH2CO(24) + S(787)
# 692 	 13.4 	 0.0 	 H_Abstraction 	 HO2(16) + C4H8O(766) <=> O2(2) + C4H9O(217)
# 1108 	 10.7 	 0.0 	 Disproportionation 	 CH3O2(45) + C2H4O(703) <=> CH3O2H(46) + CH2CHO(21)
# 484 	 0.5 	 0.0 	 Disproportionation 	 C2H(4) + NC3H7(92) <=> C2H2(25) + C3H6(12)
# 1252 	 1.8 	 0.0 	 Disproportionation 	 HCO(19) + C4H8(748) <=> CH2O(9) + C4H7(191)
# 684 	 1.8 	 0.0 	 CO_Disproportionation 	 HCO(19) + C4H8(748) <=> CO(6) + PC4H9(182)
# 218 	 0.5 	 0.0 	 H_Abstraction 	 O2(2) + C2H2(25) <=> HO2(16) + C2H(4)
# 1051 	 2.8 	 0.0 	 Disproportionation 	 C4H7(191) + S(229) <=> C4H6(194) + S(787)
# 483 	 0.5 	 0.0 	 Disproportionation 	 C2H(4) + C2H5(33) <=> C2H2(25) + C2H4(11)
# 1484 	 1.0 	 0.0 	 H_Abstraction 	 C2H6(32) + S(229) <=> C2H5(33) + S(787)
# 1250 	 1.8 	 0.0 	 Disproportionation 	 HO2(16) + C4H8(748) <=> H2O2(17) + C4H7(191)
# 633 	 2.8 	 0.0 	 Disproportionation 	 CH3CO(20) + C2H4O(703) <=> CH2CHO(21) + CH3CHO(35)
# 934 	 2.8 	 0.0 	 Disproportionation 	 S(777) + S(244) <=> S(252) + S(787)
# 1311 	 1.0 	 0.0 	 H_Abstraction 	 H(14) + C3H6O3(73) <=> H2(13) + C3H5O3(72)
# 974 	 3.9 	 0.0 	 Disproportionation 	 C2H5(33) + C2H5O(49) <=> CH3CHO(35) + C2H6(32)
# 1318 	 1.0 	 0.0 	 H_Abstraction 	 S(911) + S(787) <=> C3H6O3(73) + S(229)
# 1582 	 1.8 	 0.0 	 Disproportionation 	 OCHO(38) + C2H3(22) <=> HOCHO(40) + C2H2(25)
# 1121 	 1.8 	 0.0 	 Disproportionation 	 C2H(4) + S(777) <=> C2H2(25) + S(252)
# 486 	 1.8 	 0.0 	 Disproportionation 	 C2H(4) + SC4H9(183) <=> C2H2(25) + C4H8(189)
# 1251 	 1.8 	 0.0 	 H_Abstraction 	 CH3O2H(46) + C2H(4) <=> CH3O2(45) + C2H2(25)
# 1625 	 1.8 	 0.0 	 Disproportionation 	 CH3(18) + C4H8(748) <=> CH4(10) + C4H7(191)
# 1167 	 1.8 	 0.0 	 Disproportionation 	 C4H7(192) + SC4H9(183) <=> C4H8(188) + C4H8(189)
# 1283 	 3.9 	 0.0 	 Disproportionation 	 C2H4O(703) + C2H5O(49) <=> CH3CHO(35) + C2H5O(49)
# 890 	 1.0 	 0.0 	 H_Abstraction 	 S(244) + S(787) <=> S(229) + S(787)
# 415 	 0.5 	 0.0 	 Disproportionation 	 H(14) + NC3H7(92) <=> H2(13) + C3H6(12)
# 753 	 11.0 	 0.0 	 H_Abstraction 	 CH2(23) + C4H8(188) <=> CH3(18) + C4H7(190)
# 1370 	 3.9 	 0.0 	 Disproportionation 	 C4H6(2534) + SC4H9(183) <=> C4H7(190) + C4H8(189)
# 864 	 2.0 	 0.0 	 H_Abstraction 	 CH3CHO(35) + S(238) <=> CH2CHO(21) + S(787)
# 875 	 1.8 	 0.0 	 CO_Disproportionation 	 HCO(19) + S(244) <=> CO(6) + S(787)
# 1244 	 2.8 	 0.0 	 Disproportionation 	 C3H5O(129) + S(238) <=> C3H4O(74) + S(787)
# 1546 	 9.2 	 0.0 	 Disproportionation 	 OCHO(38) + C2H3(22) <=> CO2(7) + C2H4(11)
# 886 	 1.8 	 0.0 	 Disproportionation 	 IC3H7(93) + S(229) <=> C3H6(12) + S(787)
# 1579 	 1.8 	 0.0 	 H_Abstraction 	 OCHO(38) + CH3CHO(35) <=> HOCHO(40) + CH2CHO(21)
# 811 	 1.8 	 0.0 	 H_Abstraction 	 PC4H9(182) + S(787) <=> S(238) + butane(1)
# 1409 	 2.0 	 0.0 	 Disproportionation 	 C4H6(2534) + PC4H9(182) <=> C4H7(191) + C4H8(188)
# 1590 	 2.0 	 0.0 	 H_Abstraction 	 OCHO(38) + CH3O2H(46) <=> HOCHO(40) + CH3O2(45)
# 893 	 1.8 	 0.0 	 H_Abstraction 	 S(238) + S(787) <=> S(225) + S(787)
# 756 	 11.0 	 0.0 	 H_Abstraction 	 C2H(4) + C4H8(188) <=> C2H2(25) + C4H7(190)
# 1548 	 9.2 	 0.0 	 Disproportionation 	 OCHO(38) + C4H7(190) <=> CO2(7) + C4H8(189)
# 1663 	 1.8 	 0.0 	 H_Abstraction 	 C2H6O2(48) + S(238) <=> C2H5O2(47) + S(787)
# 1411 	 2.8 	 0.0 	 Disproportionation 	 C2H5O(49) + C4H6(2534) <=> CH3CHO(35) + C4H7(191)
# 214 	 3.6 	 0.0 	 H_Abstraction 	 HO2(16) + CH2(23) <=> O2(2) + CH3(18)
# 818 	 1.8 	 0.0 	 H_Abstraction 	 HCO(19) + S(787) <=> CH2O(9) + S(225)
# 1742 	 1.0 	 0.0 	 H_Abstraction 	 S(911) + S(187) <=> C3H6O3(73) + S(186)
# 968 	 2.8 	 0.0 	 Disproportionation 	 C2H5O(49) + C4H7(190) <=> CH3CHO(35) + C4H8(188)
# 1055 	 1.8 	 0.0 	 Disproportionation 	 C2H(4) + C4H7(191) <=> C2H2(25) + C4H6(194)
# 1583 	 1.8 	 0.0 	 CO_Disproportionation 	 HCO(19) + OCHO(38) <=> CO(6) + HOCHO(40)
# 1726 	 1.8 	 0.0 	 H_Abstraction 	 S(238) + S(187) <=> S(186) + S(787)
# 1684 	 10.7 	 0.0 	 Disproportionation 	 OCHO(38) + C2H5O2(47) <=> CO2(7) + C2H6O2(48)
# 438 	 1.8 	 0.0 	 Disproportionation 	 CH2CHO(21) + IC3H7(93) <=> CH3CHO(35) + C3H6(12)
# 1567 	 10.7 	 0.0 	 Disproportionation 	 OCHO(38) + CH3O2(45) <=> CO2(7) + CH3O2H(46)
# 738 	 2.8 	 0.0 	 Disproportionation 	 C2H4O(703) + C4H7(190) <=> CH2CHO(21) + C4H8(188)
# 1398 	 1.8 	 0.0 	 Disproportionation 	 C4H6(2534) + C4H7(190) <=> C4H6(194) + C4H7(190)
# 1471 	 1.0 	 0.0 	 H_Abstraction 	 C2H6(32) + S(225) <=> C2H5(33) + S(787)
# 1601 	 1.8 	 0.0 	 Disproportionation 	 OCHO(38) + C4H7(190) <=> HOCHO(40) + C4H6(194)
# 1592 	 1.8 	 0.0 	 Disproportionation 	 OCHO(38) + SC4H9(183) <=> HOCHO(40) + C4H8(188)
# 1514 	 2.8 	 0.0 	 H_Abstraction 	 CH3O(31) + CH3O2H(46) <=> CH3O2(45) + CH3OH(30)
# 991 	 1.8 	 0.0 	 Disproportionation 	 C4H7(190) + C4H8(748) <=> C4H6(194) + SC4H9(183)
# 752 	 6.3 	 0.0 	 Disproportionation 	 CH2(23) + C4H8(748) <=> CH3(18) + C4H7(190)
# 929 	 3.9 	 0.0 	 Disproportionation 	 C2H5(33) + S(777) <=> C2H6(32) + S(252)
# 1510 	 2.8 	 0.0 	 H_Abstraction 	 CH3O(31) + S(787) <=> CH3OH(30) + S(225)
# 1513 	 1.8 	 0.0 	 H_Abstraction 	 CH3O(31) + S(787) <=> CH3OH(30) + S(238)
# 1365 	 1.8 	 0.0 	 CO_Disproportionation 	 HCO(19) + C4H6(2534) <=> CO(6) + C4H7(190)
# 1624 	 0.5 	 0.0 	 H_Abstraction 	 C2H(4) + C2H6(32) <=> C2H2(25) + C2H5(33)
# 907 	 1.8 	 0.0 	 Disproportionation 	 C4H7(190) + S(238) <=> C4H6(194) + S(787)
# 1412 	 2.0 	 0.0 	 Disproportionation 	 C4H6(2534) + C4H7(191) <=> C4H6(194) + C4H7(191)
# 1232 	 10.7 	 0.0 	 Disproportionation 	 CH3O2(45) + C3H5O(129) <=> CH3O2H(46) + C3H4O(74)
# 1769 	 1.8 	 0.0 	 Disproportionation 	 NC3H7(92) + S(223) <=> C3H6(12) + S(187)
# 1779 	 1.8 	 0.0 	 Disproportionation 	 SC4H9(183) + S(223) <=> C4H8(188) + S(187)
# 1258 	 1.8 	 0.0 	 Disproportionation 	 CH3CO(20) + C4H8(748) <=> CH3CHO(35) + C4H7(191)
# 1063 	 1.8 	 0.0 	 Disproportionation 	 C4H8(748) + SC4H9(183) <=> C4H7(191) + butane(1)
# 668 	 1.8 	 0.0 	 Disproportionation 	 NC3H7(92) + C4H8(748) <=> C3H6(12) + SC4H9(183)
# 391 	 0.5 	 0.0 	 Disproportionation 	 C2H3(22) + NC3H7(92) <=> C2H4(11) + C3H6(12)
# 636 	 3.9 	 0.0 	 Disproportionation 	 C2H4O(703) + C3H5-A(94) <=> CH2CHO(21) + C3H6(12)
# 1249 	 1.8 	 0.0 	 Disproportionation 	 C4H7(190) + C4H8(748) <=> C4H7(191) + C4H8(189)
# 1243 	 2.8 	 0.0 	 Disproportionation 	 C3H5O(129) + S(244) <=> C3H4O(74) + S(787)
# 1169 	 1.8 	 0.0 	 Disproportionation 	 C4H7(192) + SC4H9(183) <=> C4H8(188) + C4H8(188)
# 1598 	 1.8 	 0.0 	 H_Abstraction 	 OCHO(38) + C4H8(188) <=> HOCHO(40) + C4H7(190)
# 849 	 1.8 	 0.0 	 Disproportionation 	 SC4H9(183) + S(244) <=> C4H8(189) + S(787)
# 976 	 1.8 	 0.0 	 Disproportionation 	 C2H(4) + C2H5O(49) <=> C2H2(25) + CH3CHO(35)
# 857 	 1.8 	 0.0 	 Disproportionation 	 SC4H9(183) + S(244) <=> C4H8(188) + S(787)
# 599 	 0.5 	 0.0 	 H_Abstraction 	 CH3CO(20) + C2H6(32) <=> CH3CHO(35) + C2H5(33)
# 1698 	 1.8 	 0.0 	 Disproportionation 	 C2H5O2(47) + C4H8(748) <=> C2H6O2(48) + C4H7(191)
# 601 	 3.6 	 0.0 	 Disproportionation 	 C2H(4) + CH3CO(20) <=> C2H2(25) + CH2CO(24)
# 508 	 1.8 	 0.0 	 Disproportionation 	 C2H5(33) + IC3H7(93) <=> C2H6(32) + C3H6(12)
# 390 	 1.8 	 0.0 	 Disproportionation 	 CH2(23) + IC3H7(93) <=> CH3(18) + C3H6(12)
# 757 	 3.2 	 0.0 	 H_Abstraction 	 C2H(4) + C4H8(189) <=> C2H2(25) + C4H7(190)
# 1597 	 5.4 	 0.0 	 Disproportionation 	 OCHO(38) + C4H8(748) <=> HOCHO(40) + C4H7(190)
# 1511 	 2.8 	 0.0 	 H_Abstraction 	 CH3O(31) + S(787) <=> CH3OH(30) + S(229)
# 1635 	 1.8 	 0.0 	 H_Abstraction 	 OCHO(38) + C4H8(188) <=> HOCHO(40) + C4H7(191)
# Cantera reaction mapping not found for 1843 O2(2) + S(5425) <=> HO2(16) + S(5951)
# Cantera reaction mapping not found for 1829 C3H6(12) + CH2O(9) <=> C3H5O(129) + CH3(18)
# Cantera reaction mapping not found for 1638 C3H4O(74) + HOCHO(40) <=> C3H5O(129) + OCHO(38)
# Cantera reaction mapping not found for 1633 C3H4O(74) + HOCHO(40) <=> C3H5O(129) + OCHO(38)
# Cantera reaction mapping not found for 1489 C4H6(194) + HOCHO(40) <=> C4H6(2534) + HOCHO(40)
# Cantera reaction mapping not found for 1488 C4H6(194) + HOCHO(40) <=> C4H6(2534) + HOCHO(40)
# Cantera reaction mapping not found for 1487 C4H6(194) + HOCHO(40) <=> C4H6(2534) + HOCHO(40)
# Cantera reaction mapping not found for 1486 C4H6(194) + HOCHO(40) <=> C4H6(2534) + HOCHO(40)
# Cantera reaction mapping not found for 1424 C2H2(25) + C4H6(194) <=> C2H2(25) + C4H6(2534)
# Cantera reaction mapping not found for 1423 C2H2(25) + C4H6(194) <=> C2H2(25) + C4H6(2534)
# Cantera reaction mapping not found for 1422 C4H6(194) + CO2(7) <=> C4H6(2534) + CO2(7)
# Cantera reaction mapping not found for 1421 C4H6(194) + CO2(7) <=> C4H6(2534) + CO2(7)
# Cantera reaction mapping not found for 1420 C4H6(194) + CO2(7) <=> C4H6(2534) + CO2(7)
# Cantera reaction mapping not found for 1417 C4H6(194) + CO2(7) <=> C4H6(2534) + CO2(7)
# Cantera reaction mapping not found for 1415 C4H6(194) + CH2CO(24) <=> C4H6(2534) + CH2CO(24)
# Cantera reaction mapping not found for 1414 C4H6(194) + CH2CO(24) <=> C4H6(2534) + CH2CO(24)
# Cantera reaction mapping not found for 1413 C4H6(194) + CH2CO(24) <=> C4H6(2534) + CH2CO(24)
# Cantera reaction mapping not found for 1412 C4H6(194) + CH2CO(24) <=> C4H6(2534) + CH2CO(24)
# Cantera reaction mapping not found for 1411 C2H4(11) + C4H6(194) <=> C2H4(11) + C4H6(2534)
# Cantera reaction mapping not found for 1410 C2H4(11) + C4H6(194) <=> C2H4(11) + C4H6(2534)
# Cantera reaction mapping not found for 1409 C4H6(194) + CH2CO(24) <=> C4H6(2534) + CH2CO(24)
# Cantera reaction mapping not found for 1408 C4H6(194) + CH2CO(24) <=> C4H6(2534) + CH2CO(24)
# Cantera reaction mapping not found for 1407 C4H6(194) + CH2O(9) <=> C4H6(2534) + CH2O(9)
# Cantera reaction mapping not found for 1406 C4H6(194) + CH2O(9) <=> C4H6(2534) + CH2O(9)
# Cantera reaction mapping not found for 1405 C4H6(194) + CH2O(9) <=> C4H6(2534) + CH2O(9)
# Cantera reaction mapping not found for 1404 C4H6(194) + CH2O(9) <=> C4H6(2534) + CH2O(9)
# Cantera reaction mapping not found for 1306 C3H4O(74) + HO2(16) <=> C2H5O2(47) + CO(6)
# Cantera reaction mapping not found for 1288 C3H4O(74) + HO2(16) <=> C2H5O2(47) + CO(6)
# Cantera reaction mapping not found for 1267 C3H4O(74) + CH3CHO(35) <=> C3H5O(129) + CH2CHO(21)
# Cantera reaction mapping not found for 1265 C3H4O(74) + CH3CHO(35) <=> C3H5O(129) + CH2CHO(21)
# Cantera reaction mapping not found for 1160 C3H6(12) + CH2O(9) <=> C3H5O(129) + CH3(18)
# Cantera reaction mapping not found for 807 C4H7(190) + O2(2) <=> S(4244)
# Cantera reaction mapping not found for 806 C4H7(190) + O2(2) <=> S(4244)
# Cantera reaction mapping not found for 805 C4H7(190) + O2(2) <=> S(4243)
# Cantera reaction mapping not found for 804 C4H7(190) + O2(2) <=> S(4243)
# Cantera reaction mapping not found for 689 C2H4(11) + C3H6(12) <=> C4H8(748) + CH2(23)
# Cantera reaction mapping not found for 688 C2H4(11) + C3H6(12) <=> C4H8(748) + CH2(23)
# Cantera reaction mapping not found for 651 C2H4(11) + CH2O(9) <=> C2H4O(703) + CH2(23)
# Cantera reaction mapping not found for 648 C2H4(11) + CH2O(9) <=> C2H4O(703) + CH2(23)
# Cantera reaction mapping not found for 582 C3H6(12) <=> C3H5-A(94) + H(14)
# Cantera reaction mapping not found for 581 C3H6(12) <=> C3H5-A(94) + H(14)
# Cantera reaction mapping not found for 580 C2H3(22) + CH3(18) <=> C3H5-A(94) + H(14)
# Cantera reaction mapping not found for 579 C2H3(22) + CH3(18) <=> C3H5-A(94) + H(14)
# Cantera reaction mapping not found for 553 C2H3(22) + O2(2) <=> CH3O(31) + CO(6)
# Cantera reaction mapping not found for 552 C2H3(22) + O2(2) <=> CH3O(31) + CO(6)
# Cantera reaction mapping not found for 519 C2H6(32) + CH3(18) <=> C2H5(33) + CH4(10)
# Cantera reaction mapping not found for 518 C2H6(32) + CH3(18) <=> C2H5(33) + CH4(10)
# Cantera reaction mapping not found for 404 C3H6(12) + H(14) <=> IC3H7(93)
# Cantera reaction mapping not found for 403 C3H6(12) + H(14) <=> IC3H7(93)
# Cantera reaction mapping not found for 379 C2H4(11) + OH(15) <=> CH3CHO(35) + H(14)
# Cantera reaction mapping not found for 378 C2H4(11) + OH(15) <=> CH3CHO(35) + H(14)
# Cantera reaction mapping not found for 314 PC4H9(182) <=> SC4H9(183)
# Cantera reaction mapping not found for 313 PC4H9(182) <=> SC4H9(183)
# Cantera reaction mapping not found for 261 CH2CHO(21) <=> CH3(18) + CO(6)
# Cantera reaction mapping not found for 257 C2H4(11) + CH3(18) <=> NC3H7(92)
# Cantera reaction mapping not found for 256 C2H4(11) + CH3(18) <=> NC3H7(92)
# Cantera reaction mapping not found for 255 C3H6(12) + H(14) <=> NC3H7(92)
# Cantera reaction mapping not found for 254 C3H6(12) + H(14) <=> NC3H7(92)
# Cantera reaction mapping not found for 217 H2(13) + O(5) <=> H(14) + OH(15)
# Cantera reaction mapping not found for 216 H2(13) + O(5) <=> H(14) + OH(15)
# Cantera reaction mapping not found for 195 C3H6(12) + H(14) <=> C2H4(11) + CH3(18)
# Cantera reaction mapping not found for 194 C3H6(12) + H(14) <=> C2H4(11) + CH3(18)
# Cantera reaction mapping not found for 192 C3H6(12) <=> C2H3(22) + CH3(18)
# Cantera reaction mapping not found for 191 C3H6(12) <=> C2H3(22) + CH3(18)
# Cantera reaction mapping not found for 190 C2H3(22) + CH3(18) (+M) <=> C3H6(12) (+M)
# Cantera reaction mapping not found for 188 CH2(23) + CH2CHO(21) <=> C2H4(11) + HCO(19)
# Cantera reaction mapping not found for 187 CH2(23) + CH2CHO(21) <=> C2H4(11) + HCO(19)
# Cantera reaction mapping not found for 184 C2H4(11) + O(5) <=> CH3(18) + CO(6) + H(14)
# Cantera reaction mapping not found for 183 C2H4(11) + O(5) <=> CH3(18) + CO(6) + H(14)
# Cantera reaction mapping not found for 161 CH2CHO(21) + O(5) <=> CH2O(9) + HCO(19)
# Cantera reaction mapping not found for 160 CH2CHO(21) + O(5) <=> CH2O(9) + HCO(19)
# Cantera reaction mapping not found for 151 C2H3(22) + O2(2) <=> CH2O(9) + CO(6) + H(14)
# Cantera reaction mapping not found for 150 C2H3(22) + O2(2) <=> CH2O(9) + CO(6) + H(14)
# Cantera reaction mapping not found for 132 H2O2(17) + OH(15) <=> H2O(8) + HO2(16)
# Cantera reaction mapping not found for 131 H2O2(17) + OH(15) <=> H2O(8) + HO2(16)
# Cantera reaction mapping not found for 119 C2H3(22) + O2(2) <=> CH3(18) + CO2(7)
# Cantera reaction mapping not found for 118 C2H3(22) + O2(2) <=> CH3(18) + CO2(7)
# Cantera reaction mapping not found for 106 CO(6) + OH(15) <=> CO2(7) + H(14)
# Cantera reaction mapping not found for 105 CO(6) + OH(15) <=> CO2(7) + H(14)
# Cantera reaction mapping not found for 90 CH2CHO(21) (+M) <=> CH3(18) + CO(6) (+M)
# Cantera reaction mapping not found for 67 CH(3) + CH2CHO(21) <=> C2H3(22) + HCO(19)
# Cantera reaction mapping not found for 66 CH(3) + CH2CHO(21) <=> C2H3(22) + HCO(19)
# Cantera reaction mapping not found for 60 2 HO2(16) <=> H2O2(17) + O2(2)
# Cantera reaction mapping not found for 59 2 HO2(16) <=> H2O2(17) + O2(2)
# Cantera reaction mapping not found for 57 C2H3(22) + O2(2) <=> CH2CO(24) + OH(15)
# Cantera reaction mapping not found for 56 C2H3(22) + O2(2) <=> CH2CO(24) + OH(15)
# Cantera reaction mapping not found for 26 H2O2(17) + OH(15) <=> H2O(8) + HO2(16)
# Cantera reaction mapping not found for 25 H2O2(17) + OH(15) <=> H2O(8) + HO2(16)
# Cantera reaction mapping not found for 20 2 HO2(16) <=> H2O2(17) + O2(2)
# Cantera reaction mapping not found for 19 2 HO2(16) <=> H2O2(17) + O2(2)
# Cantera reaction mapping not found for 2 H2(13) + O(5) <=> H(14) + OH(15)
# Cantera reaction mapping not found for 1 H2(13) + O(5) <=> H(14) + OH(15)

# %%
reaction_index = 915
print('Reactants:')
for reactant in reaction_list[reaction_index].reactants:
    print('\t', reactant.smiles)

print('Products:')
for product in reaction_list[reaction_index].products:
    print('\t', product.smiles)

print(Sigma_k[reaction_index][reaction_index])
