# %%
# script to compare two cti files with same species names

# %%
import numpy as np
import cantera as ct

# %%
cti1 = '/work/westgroup/harris.se/autoscience/autoscience/butane/models/rmg_model/chem_annotated.cti'
cti2 = '/work/westgroup/harris.se/autoscience/autoscience/butane/sensitivity_analysis/base_rmg24/models/chem_0000.cti'
cti3 = '/work/westgroup/harris.se/autoscience/autoscience/butane/sensitivity_analysis/base_rmg24/models/chem_0001.cti'

gas1 = ct.Solution(cti3)
gas2 = ct.Solution(cti2)

# %%
reactions1 = gas1.reactions()
reactions2 = gas2.reactions()
species1 = gas1.species()
species2 = gas2.species()

# %%
def same_reactants_and_products(rxn1, rxn2):
    return (rxn1.reactants == rxn2.reactants) and (rxn1.products == rxn2.products)

# %%
def same_type(rxn1, rxn2):
    return rxn1.reaction_type == rxn2.reaction_type

# %%
def same_kinetics(rxn1, rxn2):
    if rxn1.reaction_type == 1 or rxn1.reaction_type == 2:
        if (rxn1.rate.pre_exponential_factor == rxn2.rate.pre_exponential_factor) and \
            (rxn1.rate.temperature_exponent == rxn2.rate.temperature_exponent) and \
            (rxn1.rate.activation_energy == rxn2.rate.activation_energy):
            return True
        
#         if np.isclose(rxn1.rate.pre_exponential_factor, rxn2.rate.pre_exponential_factor) and \
#             np.isclose(rxn1.rate.temperature_exponent, rxn2.rate.temperature_exponent) and \
#             np.isclose(rxn1.rate.activation_energy, rxn2.rate.activation_energy):
#             return True
        
    # For this project, I haven't messed with any of the other types of reactions, so assume they're the same
    return True
#     elif rxn1.reaction_type == 4  # ct._cantera.FalloffReaction
#         if rxn1.efficiencies != rxn2.efficiencies:
#             return False

# %%
model1_rxns_only = []
model2_rxns_only = []
model1_sp_only = []
model2_sp_only = []
different_rxns = []
different_sp = []
common_rxns = []  # common has same stoichiometry
identical_rxns = []  # identical also has same kinetics
common_sp = []
identical_sp = []

for rxn1 in reactions1:
    for rxn2 in reactions2:
        if not same_reactants_and_products(rxn1, rxn2) or not same_type(rxn1, rxn2):
            continue
        
        common_rxns.append([rxn1, rxn2])
        
        if same_kinetics(rxn1, rxn2):
            identical_rxns.append([rxn1, rxn2])
        else:
            different_rxns.append([rxn1, rxn2])
            break
    model1_rxns_only.append(rxn1)

# %%
print('\t\t\tModel 1\t\tModel 2')
print(f'Total Reactions\t\t{len(reactions1)}\t\t{len(reactions2)}')
print(f'Common Reactions\t{len(common_rxns)}\t\t{len(common_rxns)}')
print(f'Identical Reactions\t{len(identical_rxns)}\t\t{len(identical_rxns)}')
print(f'Different Reactions\t{len(different_rxns)}\t\t{len(different_rxns)}')
# Out:
# 			Model 1		Model 2
# Total Reactions		1850		1850
# Common Reactions	2018		2018
# Identical Reactions	2018		2018
# Different Reactions	0		0

# %%
different_rxns
# Out:
# [[<FalloffReaction: CH2CHO(21) (+M) <=> CH3(18) + CO(6) (+M)>,
#   <ChebyshevReaction: CH2CHO(21) <=> CH3(18) + CO(6)>],
#  [<ChebyshevReaction: CH2CHO(21) <=> CH3(18) + CO(6)>,
#   <FalloffReaction: CH2CHO(21) (+M) <=> CH3(18) + CO(6) (+M)>],
#  [<ElementaryReaction: O2(2) + S(5425) <=> HO2(16) + S(5951)>,
#   <ChebyshevReaction: O2(2) + S(5425) <=> HO2(16) + S(5951)>],
#  [<ChebyshevReaction: O2(2) + S(5425) <=> HO2(16) + S(5951)>,
#   <ElementaryReaction: O2(2) + S(5425) <=> HO2(16) + S(5951)>]]

# %%
common_rxns
# Out:
# [<ElementaryReaction: H(14) + O2(2) <=> O(5) + OH(15)>,
#  <ElementaryReaction: H2(13) + O(5) <=> H(14) + OH(15)>,
#  <ElementaryReaction: H2(13) + O(5) <=> H(14) + OH(15)>,
#  <ElementaryReaction: H2(13) + OH(15) <=> H(14) + H2O(8)>,
#  <ElementaryReaction: 2 OH(15) <=> H2O(8) + O(5)>,
#  <ThreeBodyReaction: H2(13) + M <=> 2 H(14) + M>,
#  <ElementaryReaction: Ar + H2(13) <=> Ar + 2 H(14)>,
#  <ElementaryReaction: H2(13) + He <=> 2 H(14) + He>,
#  <ThreeBodyReaction: 2 O(5) + M <=> O2(2) + M>,
#  <ElementaryReaction: Ar + 2 O(5) <=> Ar + O2(2)>,
#  <ElementaryReaction: He + 2 O(5) <=> He + O2(2)>,
#  <ThreeBodyReaction: H(14) + O(5) + M <=> OH(15) + M>,
#  <ThreeBodyReaction: H2O(8) + M <=> H(14) + OH(15) + M>,
#  <ElementaryReaction: 2 H2O(8) <=> H(14) + H2O(8) + OH(15)>,
#  <FalloffReaction: H(14) + O2(2) (+M) <=> HO2(16) (+M)>,
#  <ElementaryReaction: H(14) + HO2(16) <=> H2(13) + O2(2)>,
#  <ElementaryReaction: H(14) + HO2(16) <=> 2 OH(15)>,
#  <ElementaryReaction: HO2(16) + O(5) <=> O2(2) + OH(15)>,
#  <ElementaryReaction: HO2(16) + OH(15) <=> H2O(8) + O2(2)>,
#  <ElementaryReaction: 2 HO2(16) <=> H2O2(17) + O2(2)>,
#  <ElementaryReaction: 2 HO2(16) <=> H2O2(17) + O2(2)>,
#  <FalloffReaction: H2O2(17) (+M) <=> 2 OH(15) (+M)>,
#  <ElementaryReaction: H(14) + H2O2(17) <=> H2O(8) + OH(15)>,
#  <ElementaryReaction: H(14) + H2O2(17) <=> H2(13) + HO2(16)>,
#  <ElementaryReaction: H2O2(17) + O(5) <=> HO2(16) + OH(15)>,
#  <ElementaryReaction: H2O2(17) + OH(15) <=> H2O(8) + HO2(16)>,
#  <ElementaryReaction: H2O2(17) + OH(15) <=> H2O(8) + HO2(16)>,
#  <ElementaryReaction: H(14) + HO2(16) <=> H2O(8) + O(5)>,
#  <ThreeBodyReaction: H(14) + HO2(16) + M <=> H2O2(17) + M>,
#  <ElementaryReaction: 2 OH(15) <=> H2(13) + O2(2)>,
#  <ElementaryReaction: H2O(8) + O(5) <=> H2(13) + O2(2)>,
#  <ElementaryReaction: H2O2(17) + O(5) <=> H2O(8) + O2(2)>,
#  <ThreeBodyReaction: O(5) + OH(15) + M <=> HO2(16) + M>,
#  <ElementaryReaction: C2H4(11) + O(5) <=> CH3(18) + HCO(19)>,
#  <ElementaryReaction: C2H4(11) + O(5) <=> CH3CO(20) + H(14)>,
#  <ElementaryReaction: C2H4(11) + O(5) <=> CH2CHO(21) + H(14)>,
#  <ElementaryReaction: C2H4(11) + O(5) <=> C2H3(22) + OH(15)>,
#  <ElementaryReaction: C2H4(11) + O(5) <=> CH2(23) + CH2O(9)>,
#  <ElementaryReaction: C2H4(11) + O(5) <=> CH2CO(24) + H2(13)>,
#  <ElementaryReaction: C2H4(11) + O(5) <=> CH4(10) + CO(6)>,
#  <ElementaryReaction: C2H4(11) + O(5) <=> C2H2(25) + H2O(8)>,
#  <ElementaryReaction: 2 CH2(23) <=> C2H2(25) + 2 H(14)>,
#  <ElementaryReaction: C2H2(25) + OH(15) <=> CH2CO(24) + H(14)>,
#  <ElementaryReaction: C2H3(22) + OH(15) <=> CH3(18) + HCO(19)>,
#  <ElementaryReaction: C2H3(22) + OH(15) <=> CH3CO(20) + H(14)>,
#  <ElementaryReaction: CH2CHO(21) + H(14) <=> CH3(18) + HCO(19)>,
#  <ElementaryReaction: CH2CHO(21) + H(14) <=> CH3CO(20) + H(14)>,
#  <ElementaryReaction: CH3CO(20) + H(14) <=> CH3(18) + HCO(19)>,
#  <FalloffReaction: CH3CO(20) (+M) <=> CH2CO(24) + H(14) (+M)>,
#  <ElementaryReaction: C2H2(25) + HO2(16) <=> CH2CO(24) + OH(15)>,
#  <ElementaryReaction: C2H3(22) + CH2(23) <=> C2H2(25) + CH3(18)>,
#  <ElementaryReaction: C2H3(22) + HO2(16) <=> CH2CHO(21) + OH(15)>,
#  <ElementaryReaction: C2H3(22) + O2(2) <=> C2H2(25) + HO2(16)>,
#  <ElementaryReaction: CH3CO(20) + O2(2) <=> CH2CO(24) + HO2(16)>,
#  <ElementaryReaction: CH2(23) + O2(2) <=> HCO(19) + OH(15)>,
#  <PlogReaction: CH2CHO(21) + O2(2) <=> CH2CO(24) + HO2(16)>,
#  <PlogReaction: C2H3(22) + O2(2) <=> CH2CO(24) + OH(15)>,
#  <PlogReaction: C2H3(22) + O2(2) <=> CH2CO(24) + OH(15)>,
#  <ElementaryReaction: C2H2(25) + O2(2) <=> 2 HCO(19)>,
#  <ElementaryReaction: 2 HO2(16) <=> H2O2(17) + O2(2)>,
#  <ElementaryReaction: 2 HO2(16) <=> H2O2(17) + O2(2)>,
#  <ElementaryReaction: CH(3) + OH(15) <=> H(14) + HCO(19)>,
#  <ElementaryReaction: CH(3) + CH2(23) <=> C2H2(25) + H(14)>,
#  <ElementaryReaction: CH(3) + CH3(18) <=> C2H3(22) + H(14)>,
#  <ThreeBodyReaction: CH2(23) + M <=> CH(3) + H(14) + M>,
#  <ElementaryReaction: C2H3(22) + CH(3) <=> C2H2(25) + CH2(23)>,
#  <ElementaryReaction: CH(3) + CH2CHO(21) <=> C2H3(22) + HCO(19)>,
#  <ElementaryReaction: CH(3) + CH2CHO(21) <=> C2H3(22) + HCO(19)>,
#  <ElementaryReaction: C2H(4) + C2H3(22) <=> 2 C2H2(25)>,
#  <ElementaryReaction: CH(3) + O2(2) <=> HCO(19) + O(5)>,
#  <ElementaryReaction: CH2CO(24) + O(5) <=> 2 HCO(19)>,
#  <ElementaryReaction: C2H3(22) + O(5) <=> CH2CO(24) + H(14)>,
#  <ElementaryReaction: C2H3(22) + O2(2) <=> CH2CHO(21) + O(5)>,
#  <ElementaryReaction: CH3CO(20) + O(5) <=> CH2CO(24) + OH(15)>,
#  <PlogReaction: C2H2(25) + HO2(16) <=> CH2CHO(21) + O(5)>,
#  <ThreeBodyReaction: HCO(19) + M <=> CO(6) + H(14) + M>,
#  <ElementaryReaction: HCO(19) + O(5) <=> CO(6) + OH(15)>,
#  <ElementaryReaction: HCO(19) + O2(2) <=> CO(6) + HO2(16)>,
#  <ElementaryReaction: CH(3) + O(5) <=> CO(6) + H(14)>,
#  <ElementaryReaction: CH(3) + O2(2) <=> CO(6) + OH(15)>,
#  <ElementaryReaction: CH(3) + O2(2) <=> CO(6) + H(14) + O(5)>,
#  <ElementaryReaction: CH2(23) + O(5) <=> CO(6) + 2 H(14)>,
#  <ElementaryReaction: CH2(23) + O2(2) <=> CO(6) + H(14) + OH(15)>,
#  <ElementaryReaction: C2H(4) + O(5) <=> CH(3) + CO(6)>,
#  <ElementaryReaction: C2H(4) + O2(2) <=> CO(6) + HCO(19)>,
#  <ElementaryReaction: C2H2(25) + O(5) <=> CH2(23) + CO(6)>,
#  <ElementaryReaction: C2H2(25) + OH(15) <=> CH3(18) + CO(6)>,
#  <FalloffReaction: CH2(23) + CO(6) (+M) <=> CH2CO(24) (+M)>,
#  <ElementaryReaction: CH2CO(24) + H(14) <=> CH3(18) + CO(6)>,
#  <ElementaryReaction: CH(3) + CH2CO(24) <=> C2H3(22) + CO(6)>,
#  <FalloffReaction: CH2CHO(21) (+M) <=> CH3(18) + CO(6) (+M)>,
#  <ElementaryReaction: CH3CO(20) + OH(15) <=> CH3(18) + CO(6) + OH(15)>,
#  <ElementaryReaction: C2H2(25) + HCO(19) <=> C2H3(22) + CO(6)>,
#  <ElementaryReaction: CH2CO(24) + O(5) <=> CO(6) + H(14) + HCO(19)>,
#  <ElementaryReaction: C2H(4) + OH(15) <=> CH2(23) + CO(6)>,
#  <ElementaryReaction: C2H3(22) + O(5) <=> CH3(18) + CO(6)>,
#  <ElementaryReaction: CH2(23) + HCO(19) <=> CH3(18) + CO(6)>,
#  <ElementaryReaction: CH(3) + OH(15) <=> CO(6) + 2 H(14)>,
#  <ElementaryReaction: C2H2(25) + O2(2) <=> CO(6) + H(14) + HCO(19)>,
#  <ElementaryReaction: C2H(4) + O2(2) <=> 2 CO(6) + H(14)>,
#  <ElementaryReaction: CH3CO(20) + H(14) <=> CH3(18) + CO(6) + H(14)>,
#  <PlogReaction: CH2CHO(21) + H(14) <=> CH3(18) + CO(6) + H(14)>,
#  <ElementaryReaction: CH(3) + CH2CHO(21) <=> C2H3(22) + CO(6) + H(14)>,
#  <FalloffReaction: CO(6) + O(5) (+M) <=> CO2(7) (+M)>,
#  <ElementaryReaction: CO(6) + O2(2) <=> CO2(7) + O(5)>,
#  <ElementaryReaction: CO(6) + OH(15) <=> CO2(7) + H(14)>,
#  <ElementaryReaction: CO(6) + OH(15) <=> CO2(7) + H(14)>,
#  <ElementaryReaction: CO(6) + HO2(16) <=> CO2(7) + OH(15)>,
#  <ElementaryReaction: HCO(19) + O(5) <=> CO2(7) + H(14)>,
#  <ElementaryReaction: CH(3) + O2(2) <=> CO2(7) + H(14)>,
#  <ElementaryReaction: CH(3) + CO2(7) <=> CO(6) + HCO(19)>,
#  <ElementaryReaction: CH2(23) + O2(2) <=> CO2(7) + 2 H(14)>,
#  <ElementaryReaction: CH2CO(24) + O(5) <=> CH2(23) + CO2(7)>,
#  <ElementaryReaction: CH2CO(24) + OH(15) <=> CH3(18) + CO2(7)>,
#  <ElementaryReaction: CH2CHO(21) + O(5) <=> CH2(23) + CO2(7) + H(14)>,
#  <ElementaryReaction: CH3CO(20) + O(5) <=> CH3(18) + CO2(7)>,
#  <ElementaryReaction: CH3CO(20) + HO2(16) <=> CH3(18) + CO2(7) + OH(15)>,
#  <ElementaryReaction: HCO(19) + HO2(16) => CO2(7) + H(14) + OH(15)>,
#  <PlogReaction: C2H3(22) + O2(2) <=> CH3(18) + CO2(7)>,
#  <PlogReaction: C2H3(22) + O2(2) <=> CH3(18) + CO2(7)>,
#  <ElementaryReaction: CH(3) + CO2(7) <=> 2 CO(6) + H(14)>,
#  <PlogReaction: C2H2(25) + HO2(16) <=> CH3(18) + CO2(7)>,
#  <ElementaryReaction: HCO(19) + OH(15) <=> CO(6) + H2O(8)>,
#  <ElementaryReaction: CH2(23) + OH(15) <=> CH(3) + H2O(8)>,
#  <ElementaryReaction: CH2(23) + O2(2) <=> CO(6) + H2O(8)>,
#  <ElementaryReaction: CH3(18) + OH(15) <=> CH2(23) + H2O(8)>,
#  <ElementaryReaction: C2H2(25) + OH(15) <=> C2H(4) + H2O(8)>,
#  <ElementaryReaction: C2H3(22) + OH(15) <=> C2H2(25) + H2O(8)>,
#  <ElementaryReaction: CH2CHO(21) + OH(15) <=> CH2CO(24) + H2O(8)>,
#  <ElementaryReaction: CH3CO(20) + OH(15) <=> CH2CO(24) + H2O(8)>,
#  <ElementaryReaction: H(14) + H2O(8) + O2(2) <=> H2O(8) + HO2(16)>,
#  <ElementaryReaction: H2O2(17) + OH(15) <=> H2O(8) + HO2(16)>,
#  <ElementaryReaction: H2O2(17) + OH(15) <=> H2O(8) + HO2(16)>,
#  <ElementaryReaction: CH(3) + H2O(8) <=> CH2O(9) + H(14)>,
#  <ElementaryReaction: CH2(23) + OH(15) <=> CH2O(9) + H(14)>,
#  <ElementaryReaction: CH2(23) + HO2(16) <=> CH2O(9) + OH(15)>,
#  <ElementaryReaction: CH2(23) + O2(2) <=> CH2O(9) + O(5)>,
#  <ElementaryReaction: CH2O(9) + O(5) <=> HCO(19) + OH(15)>,
#  <ElementaryReaction: CH2O(9) + OH(15) <=> H2O(8) + HCO(19)>,
#  <ElementaryReaction: CH2O(9) + O2(2) <=> HCO(19) + HO2(16)>,
#  <ElementaryReaction: CH2O(9) + HO2(16) <=> H2O2(17) + HCO(19)>,
#  <ElementaryReaction: CH(3) + CH2O(9) <=> CH2CO(24) + H(14)>,
#  <ElementaryReaction: CH2(23) + CH2O(9) <=> CH3(18) + HCO(19)>,
#  <ElementaryReaction: C2H(4) + CH2O(9) <=> C2H2(25) + HCO(19)>,
#  <ElementaryReaction: CH3(18) + O(5) <=> CH2O(9) + H(14)>,
#  <ElementaryReaction: CH3(18) + O2(2) <=> CH2O(9) + OH(15)>,
#  <ElementaryReaction: CH2CO(24) + O(5) <=> CH2O(9) + CO(6)>,
#  <ElementaryReaction: C2H3(22) + O2(2) <=> CH2O(9) + HCO(19)>,
#  <ElementaryReaction: CH2CHO(21) + O2(2) <=> CH2O(9) + CO(6) + OH(15)>,
#  <ElementaryReaction: 2 HCO(19) <=> CH2O(9) + CO(6)>,
#  <PlogReaction: C2H3(22) + O2(2) <=> CH2O(9) + CO(6) + H(14)>,
#  <PlogReaction: C2H3(22) + O2(2) <=> CH2O(9) + CO(6) + H(14)>,
#  <ElementaryReaction: CH2(23) + CO2(7) <=> CH2O(9) + CO(6)>,
#  <ElementaryReaction: CH2O(9) + O(5) <=> CO(6) + H(14) + OH(15)>,
#  <ElementaryReaction: CH2O(9) + O2(2) <=> CO(6) + H(14) + HO2(16)>,
#  <PlogReaction: CH2O(9) + OH(15) <=> CO(6) + H(14) + H2O(8)>,
#  <ElementaryReaction: CH2O(9) + HO2(16) <=> CO(6) + H(14) + H2O2(17)>,
#  <PlogReaction: C2H2(25) + HO2(16) <=> CH2O(9) + HCO(19)>,
#  <PlogReaction: C2H2(25) + HO2(16) <=> CH2O(9) + CO(6) + H(14)>,
#  <PlogReaction: CH3CO(20) + O2(2) <=> CH2O(9) + CO(6) + OH(15)>,
#  <ElementaryReaction: CH2CHO(21) + O(5) <=> CH2O(9) + HCO(19)>,
#  <ElementaryReaction: CH2CHO(21) + O(5) <=> CH2O(9) + HCO(19)>,
#  <ElementaryReaction: CH2CHO(21) + O(5) <=> CH2O(9) + CO(6) + H(14)>,
#  <ElementaryReaction: CH2CHO(21) + HO2(16) <=> CH2O(9) + HCO(19) + OH(15)>,
#  <ElementaryReaction: CH3(18) + HO2(16) <=> CH4(10) + O2(2)>,
#  <ElementaryReaction: CH3(18) + HCO(19) <=> CH4(10) + CO(6)>,
#  <ElementaryReaction: CH2O(9) + CH3(18) <=> CH4(10) + HCO(19)>,
#  <ElementaryReaction: CH4(10) + O(5) <=> CH3(18) + OH(15)>,
#  <ElementaryReaction: CH4(10) + OH(15) <=> CH3(18) + H2O(8)>,
#  <ElementaryReaction: CH4(10) + HO2(16) <=> CH3(18) + H2O2(17)>,
#  <ElementaryReaction: CH2(23) + CH4(10) <=> 2 CH3(18)>,
#  <ElementaryReaction: C2H(4) + CH4(10) <=> C2H2(25) + CH3(18)>,
#  <ElementaryReaction: C2H3(22) + CH3(18) <=> C2H2(25) + CH4(10)>,
#  <ElementaryReaction: CH3(18) + CH3CO(20) <=> CH2CO(24) + CH4(10)>,
#  <ElementaryReaction: CH2O(9) + CH3(18) <=> CH4(10) + CO(6) + H(14)>,
#  <ElementaryReaction: C2H3(22) + CH2O(9) <=> C2H4(11) + HCO(19)>,
#  <ElementaryReaction: CH2(23) + CH3(18) <=> C2H4(11) + H(14)>,
#  <ElementaryReaction: CH(3) + CH4(10) <=> C2H4(11) + H(14)>,
#  <ElementaryReaction: C2H4(11) + OH(15) <=> C2H3(22) + H2O(8)>,
#  <ElementaryReaction: C2H4(11) + OH(15) <=> CH2O(9) + CH3(18)>,
#  <ElementaryReaction: C2H4(11) + CH3(18) <=> C2H3(22) + CH4(10)>,
#  <ElementaryReaction: C2H4(11) + O2(2) <=> C2H3(22) + HO2(16)>,
#  <ElementaryReaction: 2 C2H3(22) <=> C2H2(25) + C2H4(11)>,
#  <ElementaryReaction: C2H4(11) + O(5) <=> CH3(18) + CO(6) + H(14)>,
#  <ElementaryReaction: C2H4(11) + O(5) <=> CH3(18) + CO(6) + H(14)>,
#  <PlogReaction: C2H3(22) + CH2O(9) <=> C2H4(11) + CO(6) + H(14)>,
#  <ElementaryReaction: C2H3(22) + HCO(19) <=> C2H4(11) + CO(6)>,
#  <ElementaryReaction: CH2(23) + CH2CHO(21) <=> C2H4(11) + HCO(19)>,
#  <ElementaryReaction: CH2(23) + CH2CHO(21) <=> C2H4(11) + HCO(19)>,
#  <ElementaryReaction: CH2(23) + CH2CHO(21) <=> C2H4(11) + CO(6) + H(14)>,
#  <FalloffReaction: C2H3(22) + CH3(18) (+M) <=> C3H6(12) (+M)>,
#  <PlogReaction: C3H6(12) <=> C2H3(22) + CH3(18)>,
#  <PlogReaction: C3H6(12) <=> C2H3(22) + CH3(18)>,
#  <ElementaryReaction: C3H6(12) + O(5) => CH2CO(24) + CH3(18) + H(14)>,
#  <PlogReaction: C3H6(12) + H(14) <=> C2H4(11) + CH3(18)>,
#  <PlogReaction: C3H6(12) + H(14) <=> C2H4(11) + CH3(18)>,
#  <ElementaryReaction: H(14) + HCO(19) <=> CO(6) + H2(13)>,
#  <ElementaryReaction: CH(3) + H2(13) <=> CH2(23) + H(14)>,
#  <FalloffReaction: CH(3) + H2(13) (+M) <=> CH3(18) (+M)>,
#  <ElementaryReaction: CH2(23) + H2(13) <=> CH3(18) + H(14)>,
#  <ElementaryReaction: CH2(23) + O2(2) <=> CO2(7) + H2(13)>,
#  <ElementaryReaction: CH2O(9) + H(14) <=> H2(13) + HCO(19)>,
#  <ElementaryReaction: CH3(18) + O(5) <=> CO(6) + H(14) + H2(13)>,
#  <ElementaryReaction: CH3(18) + OH(15) <=> CH2O(9) + H2(13)>,
#  <ElementaryReaction: CH4(10) + H(14) <=> CH3(18) + H2(13)>,
#  <ElementaryReaction: C2H(4) + H2(13) <=> C2H2(25) + H(14)>,
#  <ElementaryReaction: C2H3(22) + H(14) <=> C2H2(25) + H2(13)>,
#  <ElementaryReaction: CH2CHO(21) + H(14) <=> CH2CO(24) + H2(13)>,
#  <ElementaryReaction: C2H4(11) + H(14) <=> C2H3(22) + H2(13)>,
#  <ElementaryReaction: 2 HCO(19) => 2 CO(6) + H2(13)>,
#  <ElementaryReaction: CH3CO(20) + H(14) <=> CH2CO(24) + H2(13)>,
#  <ElementaryReaction: CH2(23) + O(5) <=> CO(6) + H2(13)>,
#  <ElementaryReaction: 2 CH2(23) <=> C2H2(25) + H2(13)>,
#  <ThreeBodyReaction: C2H4(11) + M <=> C2H2(25) + H2(13) + M>,
#  <PlogReaction: CH2O(9) + H(14) <=> CO(6) + H(14) + H2(13)>,
#  <PlogReaction: CH3(18) + HCO(19) <=> CH2CO(24) + H2(13)>,
#  <ElementaryReaction: H2(13) + O(5) <=> H(14) + OH(15)>,
#  <ElementaryReaction: H2(13) + O(5) <=> H(14) + OH(15)>,
#  <ElementaryReaction: 2 CH3(18) <=> C2H5(33) + H(14)>,
#  <ElementaryReaction: C2H5(33) + H(14) <=> C2H4(11) + H2(13)>,
#  <ElementaryReaction: C2H5(33) + O(5) <=> CH2O(9) + CH3(18)>,
#  <ElementaryReaction: C2H5(33) + O(5) <=> C2H4(11) + OH(15)>,
#  <ElementaryReaction: C2H5(33) + O2(2) <=> C2H4(11) + HO2(16)>,
#  <ElementaryReaction: C2H5(33) + CH3(18) <=> C2H4(11) + CH4(10)>,
#  <ElementaryReaction: 2 C2H4(11) <=> C2H3(22) + C2H5(33)>,
#  <ElementaryReaction: CH2CO(24) + CH3(18) <=> C2H5(33) + CO(6)>,
#  <ElementaryReaction: C3H6(12) + O(5) <=> C2H5(33) + HCO(19)>,
#  <FalloffReaction: butane(1) (+M) <=> 2 C2H5(33) (+M)>,
#  <PlogReaction: C2H5(33) + OH(15) <=> C2H4(11) + H2O(8)>,
#  <PlogReaction: C2H5(33) + HCO(19) <=> CH2CHO(21) + CH3(18)>,
#  <ElementaryReaction: C2H3(22) + H2O2(17) <=> C2H4(11) + HO2(16)>,
#  <ElementaryReaction: HCO(19) + HO2(16) <=> CO(6) + H2O2(17)>,
#  <ElementaryReaction: C2H5(33) + HO2(16) <=> C2H4(11) + H2O2(17)>,
#  <ElementaryReaction: CH2(23) + HO2(16) <=> CH3(18) + O2(2)>,
#  <ElementaryReaction: C2H5(33) + CH2(23) <=> C2H4(11) + CH3(18)>,
#  <ElementaryReaction: C2H3(22) + CH3CO(20) <=> C2H4(11) + CH2CO(24)>,
#  <ElementaryReaction: C2H3(22) + CH2CHO(21) <=> C2H4(11) + CH2CO(24)>,
#  <ElementaryReaction: C2H2(25) + O2(2) <=> C2H(4) + HO2(16)>,
#  <ElementaryReaction: C2H5(33) + HCO(19) <=> C2H4(11) + CH2O(9)>,
#  <ChebyshevReaction: CH3(18) <=> CH2(23) + H(14)>,
#  <ChebyshevReaction: CH3(18) + CO(6) <=> CH3CO(20)>,
#  <ChebyshevReaction: CH2CHO(21) <=> CH3CO(20)>,
#  <ChebyshevReaction: CH2CHO(21) <=> CH2(23) + HCO(19)>,
#  <ChebyshevReaction: CH2CO(24) + H(14) <=> CH2CHO(21)>,
#  <ChebyshevReaction: CH2CHO(21) <=> C2H3(22) + O(5)>,
#  <ChebyshevReaction: C2H2(25) + H(14) <=> C2H3(22)>,
#  <ChebyshevReaction: C2H2(25) <=> C2H(4) + H(14)>,
#  <ChebyshevReaction: CH2O(9) <=> CO(6) + H2(13)>,
#  <ChebyshevReaction: CH2O(9) <=> H(14) + HCO(19)>,
#  <ChebyshevReaction: CH3(18) + H(14) <=> CH4(10)>,
#  <ChebyshevReaction: C2H4(11) <=> C2H3(22) + H(14)>,
#  <ChebyshevReaction: C2H5(33) <=> CH2(23) + CH3(18)>,
#  <ChebyshevReaction: C2H4(11) + H(14) <=> C2H5(33)>,
#  <ElementaryReaction: NC3H7(92) + O2(2) <=> C3H6(12) + HO2(16)>,
#  <PlogReaction: C3H6(12) + H(14) <=> NC3H7(92)>,
#  <PlogReaction: C3H6(12) + H(14) <=> NC3H7(92)>,
#  <PlogReaction: C2H4(11) + CH3(18) <=> NC3H7(92)>,
#  <PlogReaction: C2H4(11) + CH3(18) <=> NC3H7(92)>,
#  <FalloffReaction: butane(1) (+M) <=> CH3(18) + NC3H7(92) (+M)>,
#  <ChebyshevReaction: CH3CO(20) <=> CH2(23) + HCO(19)>,
#  <ChebyshevReaction: CH3CO(20) <=> C2H3(22) + O(5)>,
#  <ChebyshevReaction: CH2CHO(21) <=> CH3(18) + CO(6)>,
#  <ChebyshevReaction: NC3H7(92) <=> C2H5(33) + CH2(23)>,
#  <ElementaryReaction: H(14) + SC4H9(183) <=> butane(1)>,
#  <ElementaryReaction: O2(2) + butane(1) <=> HO2(16) + SC4H9(183)>,
#  <ElementaryReaction: C2H3(22) + butane(1) <=> C2H4(11) + SC4H9(183)>,
#  <ElementaryReaction: CH3(18) + butane(1) <=> CH4(10) + SC4H9(183)>,
#  <ElementaryReaction: H(14) + butane(1) <=> H2(13) + SC4H9(183)>,
#  <ElementaryReaction: OH(15) + butane(1) <=> H2O(8) + SC4H9(183)>,
#  <ElementaryReaction: O(5) + butane(1) <=> OH(15) + SC4H9(183)>,
#  <ElementaryReaction: HO2(16) + butane(1) <=> H2O2(17) + SC4H9(183)>,
#  <PlogReaction: SC4H9(183) <=> C3H6(12) + CH3(18)>,
#  <ElementaryReaction: CH2O(9) + SC4H9(183) <=> HCO(19) + butane(1)>,
#  <ElementaryReaction: CH3CO(20) + SC4H9(183) <=> CH2CO(24) + butane(1)>,
#  <ElementaryReaction: CH2CHO(21) + SC4H9(183) <=> CH2CO(24) + butane(1)>,
#  <ElementaryReaction: C2H3(22) + SC4H9(183) <=> C2H2(25) + butane(1)>,
#  <ElementaryReaction: HCO(19) + SC4H9(183) <=> CO(6) + butane(1)>,
#  <ElementaryReaction: C2H5(33) + SC4H9(183) <=> C2H4(11) + butane(1)>,
#  <ElementaryReaction: NC3H7(92) + SC4H9(183) <=> C3H6(12) + butane(1)>,
#  <PlogReaction: NC3H7(92) + O2(2) <=> C3H7O2(95)>,
#  <ElementaryReaction: C3H7O2(95) <=> C3H6(12) + HO2(16)>,
#  <ElementaryReaction: O2(2) + SC4H9(183) <=> S(186)>,
#  <ElementaryReaction: C3H7O2(95) <=> S(114)>,
#  <ElementaryReaction: S(114) => C2H4(11) + CH2O(9) + OH(15)>,
#  <ElementaryReaction: S(186) <=> S(223)>,
#  <PlogReaction: C2H5(33) + O2(2) <=> C2H5O2(47)>,
#  <PlogReaction: C2H5O2(47) <=> C2H4(11) + HO2(16)>,
#  <FalloffReaction: CH3(18) + O2(2) (+M) <=> CH3O2(45) (+M)>,
#  <PlogReaction: C2H5(33) + O2(2) <=> C2H4O(51) + OH(15)>,
#  <PlogReaction: C2H5O2(47) <=> C2H4O(51) + OH(15)>,
#  <ElementaryReaction: C2H4O(51) <=> CH3(18) + HCO(19)>,
#  <ElementaryReaction: C2H4(11) + HO2(16) <=> C2H4O(51) + OH(15)>,
#  <ElementaryReaction: C2H4O(51) <=> CH2CHO(21) + H(14)>,
#  <ElementaryReaction: C2H4O(51) <=> CH3CO(20) + H(14)>,
#  <ElementaryReaction: C2H4O(51) <=> CH2CO(24) + H2(13)>,
#  <ElementaryReaction: C2H4O(51) <=> C2H2(25) + H2O(8)>,
#  <ElementaryReaction: C2H4O(51) + H(14) <=> C2H3(22) + H2O(8)>,
#  <ElementaryReaction: C2H4O(51) + H(14) <=> C2H4(11) + OH(15)>,
#  <ElementaryReaction: C4H8(189) + H(14) <=> SC4H9(183)>,
#  <ElementaryReaction: O2(2) + SC4H9(183) <=> C4H8(189) + HO2(16)>,
#  <ElementaryReaction: S(186) <=> C4H8(189) + HO2(16)>,
#  <ElementaryReaction: 2 SC4H9(183) <=> C4H8(189) + butane(1)>,
#  <ElementaryReaction: O2(2) + S(223) <=> S(229)>,
#  <ElementaryReaction: S(229) <=> S(244)>,
#  <ElementaryReaction: H(14) + PC4H9(182) <=> butane(1)>,
#  <ElementaryReaction: O2(2) + butane(1) <=> HO2(16) + PC4H9(182)>,
#  <ElementaryReaction: C2H3(22) + butane(1) <=> C2H4(11) + PC4H9(182)>,
#  <ElementaryReaction: CH3(18) + butane(1) <=> CH4(10) + PC4H9(182)>,
#  <ElementaryReaction: H(14) + butane(1) <=> H2(13) + PC4H9(182)>,
#  <ElementaryReaction: OH(15) + butane(1) <=> H2O(8) + PC4H9(182)>,
#  <ElementaryReaction: O(5) + butane(1) <=> OH(15) + PC4H9(182)>,
#  <ElementaryReaction: HO2(16) + butane(1) <=> H2O2(17) + PC4H9(182)>,
#  <ElementaryReaction: PC4H9(182) + butane(1) <=> SC4H9(183) + butane(1)>,
#  <ElementaryReaction: PC4H9(182) <=> SC4H9(183)>,
#  <ElementaryReaction: PC4H9(182) <=> SC4H9(183)>,
#  <PlogReaction: PC4H9(182) <=> C2H4(11) + C2H5(33)>,
#  <ElementaryReaction: CH2O(9) + PC4H9(182) <=> HCO(19) + butane(1)>,
#  <ElementaryReaction: CH3CO(20) + PC4H9(182) <=> CH2CO(24) + butane(1)>,
#  <ElementaryReaction: CH2CHO(21) + PC4H9(182) <=> CH2CO(24) + butane(1)>,
#  <ElementaryReaction: C2H3(22) + PC4H9(182) <=> C2H2(25) + butane(1)>,
#  <ElementaryReaction: HCO(19) + PC4H9(182) <=> CO(6) + butane(1)>,
#  <ElementaryReaction: C2H5(33) + PC4H9(182) <=> C2H4(11) + butane(1)>,
#  <ElementaryReaction: NC3H7(92) + PC4H9(182) <=> C3H6(12) + butane(1)>,
#  <ElementaryReaction: PC4H9(182) + SC4H9(183) <=> C4H8(189) + butane(1)>,
#  <ChebyshevReaction: PC4H9(182) <=> CH2(23) + NC3H7(92)>,
#  <ElementaryReaction: O2(2) + PC4H9(182) <=> S(184)>,
#  <ElementaryReaction: S(244) <=> OH(15) + S(256)>,
#  <ElementaryReaction: S(184) <=> S(219)>,
#  <ElementaryReaction: S(219) => C3H6(12) + CH2O(9) + OH(15)>,
#  <ElementaryReaction: S(184) <=> S(220)>,
#  <ChebyshevReaction: S(220) <=> S(219)>,
#  <ChebyshevReaction: S(219) <=> CH2(23) + S(114)>,
#  <ChebyshevReaction: S(220) <=> CH2(23) + S(114)>,
#  <ElementaryReaction: C4H8(188) + H(14) <=> PC4H9(182)>,
#  <ElementaryReaction: C4H8(188) + H(14) <=> SC4H9(183)>,
#  <ElementaryReaction: O2(2) + PC4H9(182) <=> C4H8(188) + HO2(16)>,
#  <ElementaryReaction: O2(2) + SC4H9(183) <=> C4H8(188) + HO2(16)>,
#  <ElementaryReaction: C2H3(22) + C2H5(33) <=> C4H8(188)>,
#  <ElementaryReaction: S(184) <=> C4H8(188) + HO2(16)>,
#  <ElementaryReaction: S(186) <=> C4H8(188) + HO2(16)>,
#  <ChebyshevReaction: 2 C2H4(11) <=> C4H8(188)>,
#  <ElementaryReaction: PC4H9(182) + SC4H9(183) <=> C4H8(188) + butane(1)>,
#  <ElementaryReaction: 2 SC4H9(183) <=> C4H8(188) + butane(1)>,
#  <ElementaryReaction: 2 PC4H9(182) <=> C4H8(188) + butane(1)>,
#  <ElementaryReaction: PC4H9(182) + SC4H9(183) <=> C4H8(188) + butane(1)>,
#  <ElementaryReaction: O2(2) + S(219) <=> S(225)>,
#  <ElementaryReaction: S(229) <=> S(225)>,
#  <ElementaryReaction: S(225) <=> S(244)>,
#  <ElementaryReaction: S(225) <=> S(238)>,
#  <ElementaryReaction: S(229) <=> S(238)>,
#  <ElementaryReaction: S(238) <=> S(244)>,
#  <ElementaryReaction: S(238) <=> OH(15) + S(252)>,
#  <ChebyshevReaction: S(256) <=> OH(15) + S(818)>,
#  <ElementaryReaction: CH2CO(24) + CH3(18) <=> C3H5O(70)>,
#  <ElementaryReaction: S(256) => C3H5O(70) + CH2O(9) + OH(15)>,
#  <ChebyshevReaction: S(818) <=> C3H5O(70) + CH2O(9)>,
#  <ChebyshevReaction: C3H5O(70) <=> CH2(23) + CH3CO(20)>,
#  <ElementaryReaction: C3H5O(70) + O2(2) <=> C3H5O3(72)>,
#  <ChebyshevReaction: C3H5O3(72) <=> C2H5O2(47) + CO(6)>,
#  <ChebyshevReaction: S(911) <=> C3H5O3(72)>,
#  <ChebyshevReaction: S(911) <=> C2H5O2(47) + CO(6)>,
#  <ChebyshevReaction: O2(2) + S(911) <=> S(928)>,
#  <ChebyshevReaction: C3H5O3(72) <=> OH(15) + S(917)>,
#  <ChebyshevReaction: S(911) <=> OH(15) + S(917)>,
#  <ChebyshevReaction: S(917) <=> CH2CO(24) + CH2O(9)>,
#  <ChebyshevReaction: C3H5O3(72) <=> OH(15) + S(920)>,
#  <ChebyshevReaction: S(911) <=> OH(15) + S(920)>,
#  <ChebyshevReaction: S(920) <=> S(917)>,
#  <ChebyshevReaction: O2(2) + S(917) <=> O2(2) + S(920)>,
#  <ChebyshevReaction: S(920) <=> CH2CO(24) + CH2O(9)>,
#  <ElementaryReaction: CH3CHO(35) + H(14) <=> CH2CHO(21) + H2(13)>,
#  <ElementaryReaction: CH3CHO(35) + H(14) <=> CH3CO(20) + H2(13)>,
#  <ElementaryReaction: CH3CHO(35) + O(5) <=> CH2CHO(21) + OH(15)>,
#  <ElementaryReaction: CH3CHO(35) + O(5) <=> CH3CO(20) + OH(15)>,
#  <ElementaryReaction: CH3CHO(35) + OH(15) <=> CH3CO(20) + H2O(8)>,
#  <ElementaryReaction: CH3CHO(35) + O2(2) <=> CH3CO(20) + HO2(16)>,
#  <ElementaryReaction: CH3CHO(35) + HO2(16) <=> CH3CO(20) + H2O2(17)>,
#  <ElementaryReaction: CH3(18) + CH3CHO(35) <=> CH3CO(20) + CH4(10)>,
#  <ElementaryReaction: C2H4(11) + OH(15) <=> CH3CHO(35) + H(14)>,
#  <ElementaryReaction: C2H4(11) + OH(15) <=> CH3CHO(35) + H(14)>,
#  <ElementaryReaction: C2H5(33) + O(5) <=> CH3CHO(35) + H(14)>,
#  <PlogReaction: C2H5(33) + O2(2) <=> CH3CHO(35) + OH(15)>,
#  <PlogReaction: C2H5O2(47) <=> CH3CHO(35) + OH(15)>,
#  <ElementaryReaction: C2H4O(51) <=> CH3CHO(35)>,
#  <ElementaryReaction: CH3CHO(35) + OH(15) <=> CH2CHO(21) + H2O(8)>,
#  <PlogReaction: C3H6(12) + OH(15) <=> CH3(18) + CH3CHO(35)>,
#  <ElementaryReaction: S(223) => C2H4(11) + CH3CHO(35) + OH(15)>,
#  <ElementaryReaction: S(252) => CH2CHO(21) + CH3CHO(35) + OH(15)>,
#  <PlogReaction: CH3CHO(35) <=> CH2CO(24) + H2(13)>,
#  <ElementaryReaction: CH3CHO(35) + HO2(16) <=> CH2CHO(21) + H2O2(17)>,
#  <ElementaryReaction: CH3CHO(35) + O2(2) <=> CH2CHO(21) + HO2(16)>,
#  <ElementaryReaction: CH3(18) + CH3CHO(35) <=> CH2CHO(21) + CH4(10)>,
#  <ElementaryReaction: C2H4O(51) + H(14) <=> CH3CHO(35) + H(14)>,
#  <ElementaryReaction: CH3CHO(35) + SC4H9(183) <=> CH2CHO(21) + butane(1)>,
#  <ElementaryReaction: CH3CHO(35) + PC4H9(182) <=> CH2CHO(21) + butane(1)>,
#  <ChebyshevReaction: CH3CHO(35) <=> CH4(10) + CO(6)>,
#  <ChebyshevReaction: CH3CHO(35) <=> CH3(18) + HCO(19)>,
#  <ChebyshevReaction: CH3CHO(35) <=> CH2CHO(21) + H(14)>,
#  <ChebyshevReaction: CH3CHO(35) <=> CH3CO(20) + H(14)>,
#  <ElementaryReaction: H(14) + IC3H7(93) <=> C2H5(33) + CH3(18)>,
#  <ElementaryReaction: IC3H7(93) + OH(15) <=> C3H6(12) + H2O(8)>,
#  <ElementaryReaction: IC3H7(93) + O(5) <=> CH3(18) + CH3CHO(35)>,
#  <PlogReaction: C3H6(12) + HO2(16) <=> IC3H7(93) + O2(2)>,
#  <PlogReaction: C3H6(12) + H(14) <=> IC3H7(93)>,
#  <PlogReaction: C3H6(12) + H(14) <=> IC3H7(93)>,
#  <ElementaryReaction: IC3H7(93) + SC4H9(183) <=> C3H6(12) + butane(1)>,
#  <ElementaryReaction: IC3H7(93) + PC4H9(182) <=> C3H6(12) + butane(1)>,
#  <ChebyshevReaction: NC3H7(92) <=> IC3H7(93)>,
#  <PlogReaction: CH2CHO(21) + O2(2) <=> C2H3O3(56)>,
#  <PlogReaction: C2H3O3(56) <=> CH2CO(24) + HO2(16)>,
#  <ChebyshevReaction: C2H3O3(56) <=> CH3O2(45) + CO(6)>,
#  <ChebyshevReaction: IC3H7(93) <=> C2H5(33) + CH2(23)>,
#  <ElementaryReaction: CH2(23) + H2O2(17) <=> CH3(18) + HO2(16)>,
#  <ElementaryReaction: CH2(23) + NC3H7(92) <=> C3H6(12) + CH3(18)>,
#  <ElementaryReaction: CH2(23) + IC3H7(93) <=> C3H6(12) + CH3(18)>,
#  <ElementaryReaction: C2H3(22) + NC3H7(92) <=> C2H4(11) + C3H6(12)>,
#  <ElementaryReaction: C2H3(22) + IC3H7(93) <=> C2H4(11) + C3H6(12)>,
#  <ChebyshevReaction: C4H8(776) <=> C4H8(189)>,
#  <ChebyshevReaction: 2 C2H4(11) <=> C4H8(776)>,
#  <ChebyshevReaction: C4H8(776) <=> C4H8(188)>,
#  <ChebyshevReaction: 2 C2H4(11) <=> C4H8(189)>,
#  <ChebyshevReaction: C4H8(188) <=> C4H8(189)>,
#  <ElementaryReaction: HO2(16) + NC3H7(92) <=> C3H6(12) + H2O2(17)>,
#  <ElementaryReaction: HO2(16) + IC3H7(93) <=> C3H6(12) + H2O2(17)>,
#  <ElementaryReaction: CH2(23) + SC4H9(183) <=> C4H8(189) + CH3(18)>,
#  <ElementaryReaction: CH2(23) + PC4H9(182) <=> C4H8(188) + CH3(18)>,
#  <ElementaryReaction: CH2(23) + SC4H9(183) <=> C4H8(188) + CH3(18)>,
#  <ElementaryReaction: NC3H7(92) + OH(15) <=> C3H6(12) + H2O(8)>,
#  <ElementaryReaction: OH(15) + PC4H9(182) <=> C4H8(188) + H2O(8)>,
#  <ElementaryReaction: OH(15) + SC4H9(183) <=> C4H8(188) + H2O(8)>,
#  <ElementaryReaction: HCO(19) + NC3H7(92) <=> C3H6(12) + CH2O(9)>,
#  <ElementaryReaction: HCO(19) + IC3H7(93) <=> C3H6(12) + CH2O(9)>,
#  <ElementaryReaction: CH3(18) + NC3H7(92) <=> C3H6(12) + CH4(10)>,
#  <ElementaryReaction: CH3(18) + IC3H7(93) <=> C3H6(12) + CH4(10)>,
#  <ElementaryReaction: CH3(18) + PC4H9(182) <=> C4H8(188) + CH4(10)>,
#  <ElementaryReaction: CH3(18) + SC4H9(183) <=> C4H8(188) + CH4(10)>,
#  <ElementaryReaction: C2H3(22) + SC4H9(183) <=> C2H4(11) + C4H8(189)>,
#  <ElementaryReaction: C2H3(22) + PC4H9(182) <=> C2H4(11) + C4H8(188)>,
#  <ElementaryReaction: C2H3(22) + SC4H9(183) <=> C2H4(11) + C4H8(188)>,
#  <ElementaryReaction: H(14) + NC3H7(92) <=> C3H6(12) + H2(13)>,
#  <ElementaryReaction: H(14) + IC3H7(93) <=> C3H6(12) + H2(13)>,
#  <ElementaryReaction: OH(15) + SC4H9(183) <=> C4H8(189) + H2O(8)>,
#  <ElementaryReaction: CH3CO(20) + HO2(16) <=> CH2CO(24) + H2O2(17)>,
#  <ElementaryReaction: CH2CHO(21) + HO2(16) <=> CH2CO(24) + H2O2(17)>,
#  <ElementaryReaction: HO2(16) + SC4H9(183) <=> C4H8(189) + H2O2(17)>,
#  <ElementaryReaction: HO2(16) + PC4H9(182) <=> C4H8(188) + H2O2(17)>,
#  <ElementaryReaction: HO2(16) + SC4H9(183) <=> C4H8(188) + H2O2(17)>,
#  <ElementaryReaction: CH3CO(20) + HCO(19) <=> CH2CO(24) + CH2O(9)>,
#  <ElementaryReaction: CH2CHO(21) + HCO(19) <=> CH2CO(24) + CH2O(9)>,
#  <ElementaryReaction: CH2CHO(21) + CH3CO(20) <=> CH2CO(24) + CH3CHO(35)>,
#  <ElementaryReaction: 2 CH3CO(20) <=> CH2CO(24) + CH3CHO(35)>,
#  <ElementaryReaction: 2 CH2CHO(21) <=> CH2CO(24) + CH3CHO(35)>,
#  <ElementaryReaction: CH2CHO(21) + CH3CO(20) <=> CH2CO(24) + CH3CHO(35)>,
#  <ElementaryReaction: CH2CHO(21) + HCO(19) <=> CH3CHO(35) + CO(6)>,
#  <ElementaryReaction: CH3CO(20) + HCO(19) <=> CH3CHO(35) + CO(6)>,
#  <ElementaryReaction: HCO(19) + SC4H9(183) <=> C4H8(189) + CH2O(9)>,
#  <ElementaryReaction: HCO(19) + PC4H9(182) <=> C4H8(188) + CH2O(9)>,
#  <ElementaryReaction: HCO(19) + SC4H9(183) <=> C4H8(188) + CH2O(9)>,
#  <ElementaryReaction: C2H5(33) + CH2CHO(21) <=> C2H4(11) + CH3CHO(35)>,
#  <ElementaryReaction: C2H5(33) + CH3CO(20) <=> C2H4(11) + CH3CHO(35)>,
#  <ElementaryReaction: CH2CHO(21) + NC3H7(92) <=> C3H6(12) + CH3CHO(35)>,
#  <ElementaryReaction: CH3CO(20) + NC3H7(92) <=> C3H6(12) + CH3CHO(35)>,
#  <ElementaryReaction: CH2CHO(21) + IC3H7(93) <=> C3H6(12) + CH3CHO(35)>,
#  <ElementaryReaction: CH3CO(20) + IC3H7(93) <=> C3H6(12) + CH3CHO(35)>,
#  <ElementaryReaction: CH2CHO(21) + SC4H9(183) <=> C4H8(189) + CH3CHO(35)>,
#  <ElementaryReaction: CH3CO(20) + SC4H9(183) <=> C4H8(189) + CH3CHO(35)>,
#  <ElementaryReaction: CH2CHO(21) + PC4H9(182) <=> C4H8(188) + CH3CHO(35)>,
#  <ElementaryReaction: CH3CO(20) + PC4H9(182) <=> C4H8(188) + CH3CHO(35)>,
#  <ElementaryReaction: CH2CHO(21) + SC4H9(183) <=> C4H8(188) + CH3CHO(35)>,
#  <ElementaryReaction: CH3CO(20) + SC4H9(183) <=> C4H8(188) + CH3CHO(35)>,
#  <ChebyshevReaction: CH2O(9) + S(917) <=> CH2O(9) + S(920)>,
#  <PlogReaction: IC3H7(93) + O2(2) <=> C3H7O2(97)>,
#  <ElementaryReaction: C3H7O2(97) <=> C3H6(12) + HO2(16)>,
#  <ElementaryReaction: S(219) <=> C4H8O(214) + OH(15)>,
#  <ElementaryReaction: S(223) <=> C4H8O(214) + OH(15)>,
#  <ChebyshevReaction: C4H8O(214) <=> C3H6(12) + CH2O(9)>,
#  <ChebyshevReaction: C4H8O(214) <=> C2H4(11) + CH3CHO(35)>,
#  <ChebyshevReaction: C3H6(12) + CH2O(9) <=> C2H4(11) + CH3CHO(35)>,
#  <ElementaryReaction: NC3H7(92) + O(5) <=> C3H6(12) + OH(15)>,
#  <ElementaryReaction: IC3H7(93) + O(5) <=> C3H6(12) + OH(15)>,
#  <ElementaryReaction: H(14) + SC4H9(183) <=> C4H8(189) + H2(13)>,
#  <ElementaryReaction: H(14) + PC4H9(182) <=> C4H8(188) + H2(13)>,
#  <ElementaryReaction: H(14) + SC4H9(183) <=> C4H8(188) + H2(13)>,
#  <ElementaryReaction: CH3(18) + SC4H9(183) <=> C4H8(189) + CH4(10)>,
#  <ChebyshevReaction: CH2CO(24) + CH3CHO(35) <=> C2H(4) + C2H5O2(47)>,
#  <ChebyshevReaction: CH2CO(24) + CH2O(9) <=> C2H(4) + CH3O2(45)>,
#  <ChebyshevReaction: CH2CO(24) + CH3CHO(35) <=> 2 CH2CHO(21)>,
#  <ChebyshevReaction: 2 CH3CHO(35) <=> C2H3(22) + C2H5O2(47)>,
#  <ElementaryReaction: CH2CHO(21) + CH3(18) <=> CH2CO(24) + CH4(10)>,
#  <ChebyshevReaction: CH2O(9) + CH3CHO(35) <=> C2H3(22) + CH3O2(45)>,
#  <ChebyshevReaction: CH4(10) + CO(6) <=> CH2CHO(21) + H(14)>,
#  <ChebyshevReaction: CH4(10) + CO(6) <=> CH3CO(20) + H(14)>,
#  <ElementaryReaction: CH2(23) + CH3CO(20) <=> CH2CO(24) + CH3(18)>,
#  <ElementaryReaction: CH2(23) + CH2CHO(21) <=> CH2CO(24) + CH3(18)>,
#  <ChebyshevReaction: OH(15) + S(917) <=> C2H5O2(47) + CO(6)>,
#  <ChebyshevReaction: C2H5O2(47) + CO(6) <=> OH(15) + S(920)>,
#  <ChebyshevReaction: S(223) <=> C4H8O(766) + OH(15)>,
#  <ChebyshevReaction: C2H4(11) + CH3CHO(35) <=> C4H8O(766)>,
#  <ChebyshevReaction: C3H6(12) + CH2O(9) <=> C4H8O(766)>,
#  <ChebyshevReaction: C4H8O(214) <=> C4H8O(766)>,
#  <ChebyshevReaction: C4H8O(214) + O2(2) <=> C4H8O(766) + O2(2)>,
#  <ElementaryReaction: O(5) + SC4H9(183) <=> C4H8(189) + OH(15)>,
#  <ElementaryReaction: O(5) + PC4H9(182) <=> C4H8(188) + OH(15)>,
#  <ElementaryReaction: O(5) + SC4H9(183) <=> C4H8(188) + OH(15)>,
#  <ElementaryReaction: CH2(23) + OH(15) <=> CH3(18) + O(5)>,
#  <ElementaryReaction: C2H(4) + HCO(19) <=> C2H2(25) + CO(6)>,
#  <ElementaryReaction: C2H3(22) + HCO(19) <=> C2H2(25) + CH2O(9)>,
#  <ElementaryReaction: C2H(4) + C2H5(33) <=> C2H2(25) + C2H4(11)>,
#  <ElementaryReaction: C2H(4) + NC3H7(92) <=> C2H2(25) + C3H6(12)>,
#  <ElementaryReaction: C2H(4) + IC3H7(93) <=> C2H2(25) + C3H6(12)>,
#  <ElementaryReaction: C2H(4) + SC4H9(183) <=> C2H2(25) + C4H8(189)>,
#  <ElementaryReaction: C2H(4) + PC4H9(182) <=> C2H2(25) + C4H8(188)>,
#  <ElementaryReaction: C2H(4) + SC4H9(183) <=> C2H2(25) + C4H8(188)>,
#  <ElementaryReaction: C2H5(33) + CH2O(9) <=> C2H6(32) + HCO(19)>,
#  <ElementaryReaction: C2H6(32) + H(14) <=> C2H5(33) + H2(13)>,
#  <ElementaryReaction: C2H6(32) + O(5) <=> C2H5(33) + OH(15)>,
#  <ElementaryReaction: C2H6(32) + OH(15) <=> C2H5(33) + H2O(8)>,
#  <ElementaryReaction: C2H6(32) + CH(3) <=> C2H4(11) + CH3(18)>,
#  <ElementaryReaction: C2H6(32) + CH3(18) <=> C2H5(33) + CH4(10)>,
#  <ElementaryReaction: C2H6(32) + CH3(18) <=> C2H5(33) + CH4(10)>,
#  <ElementaryReaction: C2H6(32) + O2(2) <=> C2H5(33) + HO2(16)>,
#  <ElementaryReaction: C2H6(32) + HO2(16) <=> C2H5(33) + H2O2(17)>,
#  <ElementaryReaction: C2H6(32) + CH(3) <=> C2H5(33) + CH2(23)>,
#  <ElementaryReaction: C2H5(33) + butane(1) <=> C2H6(32) + PC4H9(182)>,
#  <ElementaryReaction: C2H5(33) + butane(1) <=> C2H6(32) + SC4H9(183)>,
#  <ElementaryReaction: C2H5(33) + HCO(19) <=> C2H6(32) + CO(6)>,
#  <ElementaryReaction: 2 C2H5(33) <=> C2H4(11) + C2H6(32)>,
#  <ElementaryReaction: CH3(18) + CH3CO(20) <=> C2H6(32) + CO(6)>,
#  <ChebyshevReaction: 2 CH3(18) <=> C2H6(32)>,
#  <ElementaryReaction: C2H6(32) + CH2(23) <=> C2H5(33) + CH3(18)>,
#  <ElementaryReaction: C2H3(22) + C2H6(32) <=> C2H4(11) + C2H5(33)>,
#  <ChebyshevReaction: C2H6(32) <=> C2H5(33) + H(14)>,
#  <ElementaryReaction: C2H5(33) + NC3H7(92) <=> C2H6(32) + C3H6(12)>,
#  <ElementaryReaction: C2H5(33) + IC3H7(93) <=> C2H6(32) + C3H6(12)>,
#  <ElementaryReaction: C2H5(33) + SC4H9(183) <=> C2H6(32) + C4H8(189)>,
#  <ElementaryReaction: C2H5(33) + PC4H9(182) <=> C2H6(32) + C4H8(188)>,
#  <ElementaryReaction: C2H5(33) + SC4H9(183) <=> C2H6(32) + C4H8(188)>,
#  <ElementaryReaction: CH3(18) + HO2(16) <=> CH3O(31) + OH(15)>,
#  <ElementaryReaction: CH3(18) + O2(2) <=> CH3O(31) + O(5)>,
#  <ElementaryReaction: CH3O(31) + H(14) <=> CH2O(9) + H2(13)>,
#  <ElementaryReaction: CH3O(31) + H(14) <=> CH3(18) + OH(15)>,
#  <ElementaryReaction: CH3O(31) + O(5) <=> CH2O(9) + OH(15)>,
#  <ElementaryReaction: CH3O(31) + OH(15) <=> CH2O(9) + H2O(8)>,
#  <ElementaryReaction: CH3O(31) + O2(2) <=> CH2O(9) + HO2(16)>,
#  <ElementaryReaction: CH3(18) + CH3O(31) <=> CH2O(9) + CH4(10)>,
#  <ElementaryReaction: CH3O(31) + CO(6) <=> CH3(18) + CO2(7)>,
#  <ElementaryReaction: CH3O(31) + HO2(16) <=> CH2O(9) + H2O2(17)>,
#  <ElementaryReaction: CH3(18) + CH3O2(45) <=> 2 CH3O(31)>,
#  <ElementaryReaction: 2 CH3O2(45) => 2 CH3O(31) + O2(2)>,
#  <ElementaryReaction: CH3O2(45) + H(14) <=> CH3O(31) + OH(15)>,
#  <ElementaryReaction: CH3O2(45) + O(5) <=> CH3O(31) + O2(2)>,
#  <ElementaryReaction: C2H4(11) + CH3O2(45) <=> C2H4O(51) + CH3O(31)>,
#  <PlogReaction: C2H3(22) + O2(2) <=> CH3O(31) + CO(6)>,
#  <PlogReaction: C2H3(22) + O2(2) <=> CH3O(31) + CO(6)>,
#  <ElementaryReaction: CH3O2(45) + HCO(19) <=> CH3O(31) + CO2(7) + H(14)>,
#  <ElementaryReaction: CH3O2(45) + CO(6) <=> CH3O(31) + CO2(7)>,
#  <PlogReaction: C2H2(25) + HO2(16) <=> CH3O(31) + CO(6)>,
#  <ElementaryReaction: CH3CO(20) + CH3O2(45) <=> CH3(18) + CH3O(31) + CO2(7)>,
#  <ElementaryReaction: CH3O(31) + SC4H9(183) <=> CH2O(9) + butane(1)>,
#  <ElementaryReaction: CH3O(31) + PC4H9(182) <=> CH2O(9) + butane(1)>,
#  <ElementaryReaction: CH3O(31) + HCO(19) <=> 2 CH2O(9)>,
#  <ElementaryReaction: C2H3(22) + CH3O(31) <=> C2H4(11) + CH2O(9)>,
#  <ChebyshevReaction: CH3O2(45) <=> CH3O(31) + O(5)>,
#  <ElementaryReaction: CH2(23) + CH3O(31) <=> CH2O(9) + CH3(18)>,
#  <ElementaryReaction: CH2CHO(21) + CH3O(31) <=> CH2O(9) + CH3CHO(35)>,
#  <ElementaryReaction: CH3CO(20) + CH3O(31) <=> CH2O(9) + CH3CHO(35)>,
#  <ChebyshevReaction: CH2O(9) + CH3CHO(35) <=> CH2CHO(21) + CH3O(31)>,
#  <ElementaryReaction: C2H(4) + CH3O(31) <=> C2H2(25) + CH2O(9)>,
#  <ElementaryReaction: C2H5(33) + CH3O(31) <=> C2H6(32) + CH2O(9)>,
#  <ChebyshevReaction: CH2O(9) + H(14) <=> CH3O(31)>,
#  <ChebyshevReaction: CH3(18) + O(5) <=> CH3O(31)>,
#  <ElementaryReaction: CH2CHO(21) + CH2O(9) <=> CH3CHO(35) + HCO(19)>,
#  <ElementaryReaction: CH2CHO(21) + CH3CHO(35) <=> CH3CHO(35) + CH3CO(20)>,
#  <ElementaryReaction: CH3CHO(35) + SC4H9(183) <=> CH3CO(20) + butane(1)>,
#  <ChebyshevReaction: C4H8O(214) + HO2(16) <=> C4H8O(766) + HO2(16)>,
#  <ElementaryReaction: C2H3(22) + CH3CHO(35) <=> C2H4(11) + CH2CHO(21)>,
#  <ElementaryReaction: C2H5(33) + CH3CO(20) <=> C2H6(32) + CH2CO(24)>,
#  <ElementaryReaction: C2H5(33) + CH2CHO(21) <=> C2H6(32) + CH2CO(24)>,
#  <ElementaryReaction: C2H3(22) + C2H5(33) <=> C2H2(25) + C2H6(32)>,
#  <PlogReaction: C2H3(22) + CH3(18) <=> C3H5-A(94) + H(14)>,
#  <PlogReaction: C2H3(22) + CH3(18) <=> C3H5-A(94) + H(14)>,
#  <PlogReaction: C3H6(12) <=> C3H5-A(94) + H(14)>,
#  <PlogReaction: C3H6(12) <=> C3H5-A(94) + H(14)>,
#  <ElementaryReaction: C3H6(12) + O(5) <=> C3H5-A(94) + OH(15)>,
#  <ElementaryReaction: C3H6(12) + OH(15) <=> C3H5-A(94) + H2O(8)>,
#  <ElementaryReaction: C3H6(12) + HO2(16) <=> C3H5-A(94) + H2O2(17)>,
#  <ElementaryReaction: C3H6(12) + H(14) <=> C3H5-A(94) + H2(13)>,
#  <ElementaryReaction: C3H6(12) + O2(2) <=> C3H5-A(94) + HO2(16)>,
#  <ElementaryReaction: C3H6(12) + CH3(18) <=> C3H5-A(94) + CH4(10)>,
#  <ElementaryReaction: C2H5(33) + C3H6(12) <=> C2H6(32) + C3H5-A(94)>,
#  <PlogReaction: C2H2(25) + CH3(18) <=> C3H5-A(94)>,
#  <ElementaryReaction: C2H5(33) + C3H5-A(94) <=> C2H4(11) + C3H6(12)>,
#  <PlogReaction: C3H5-A(94) + O2(2) <=> CH2O(9) + CH3CO(20)>,
#  <ElementaryReaction: C3H5-A(94) + HCO(19) <=> C3H6(12) + CO(6)>,
#  <ElementaryReaction: C3H5-A(94) + butane(1) <=> C3H6(12) + PC4H9(182)>,
#  <ElementaryReaction: C3H5-A(94) + butane(1) <=> C3H6(12) + SC4H9(183)>,
#  <FalloffReaction: C3H5-A(94) + CH3(18) (+M) <=> C4H8(188) (+M)>,
#  <ElementaryReaction: C4H8O(214) + OH(15) => C3H5-A(94) + CH2O(9) + H2O(8)>,
#  <ElementaryReaction: C4H8O(214) + H(14) => C3H5-A(94) + CH2O(9) + H2(13)>,
#  <ElementaryReaction: C4H8O(214) + O(5) => C3H5-A(94) + CH2O(9) + OH(15)>,
#  <ElementaryReaction: C4H8O(214) + HO2(16) => C3H5-A(94) + CH2O(9) + H2O2(17)>,
#  <ElementaryReaction: C4H8O(214) + CH3(18) => C3H5-A(94) + CH2O(9) + CH4(10)>,
#  <ElementaryReaction: C3H5-A(94) + CH3O(31) <=> C3H6(12) + CH2O(9)>,
#  <ElementaryReaction: C3H5-A(94) + NC3H7(92) <=> 2 C3H6(12)>,
#  <ElementaryReaction: C3H5-A(94) + IC3H7(93) <=> 2 C3H6(12)>,
#  <ElementaryReaction: C3H5-A(94) + SC4H9(183) <=> C3H6(12) + C4H8(189)>,
#  <ElementaryReaction: C3H5-A(94) + PC4H9(182) <=> C3H6(12) + C4H8(188)>,
#  <ElementaryReaction: C3H5-A(94) + SC4H9(183) <=> C3H6(12) + C4H8(188)>,
#  <ElementaryReaction: C3H5-A(94) + CH3CO(20) <=> C3H6(12) + CH2CO(24)>,
#  <ElementaryReaction: C3H5-A(94) + CH2CHO(21) <=> C3H6(12) + CH2CO(24)>,
#  <ElementaryReaction: C2H3(22) + C3H5-A(94) <=> C2H2(25) + C3H6(12)>,
#  <ElementaryReaction: C2H(4) + H2O2(17) <=> C2H2(25) + HO2(16)>,
#  <ElementaryReaction: C2H3(22) + HO2(16) <=> C2H2(25) + H2O2(17)>,
#  <ElementaryReaction: C3H6(12) + CH2(23) <=> C3H5-A(94) + CH3(18)>,
#  <ElementaryReaction: C3H5-A(94) + CH2O(9) <=> C3H6(12) + HCO(19)>,
#  <ElementaryReaction: C3H6(12) + CH2CHO(21) <=> C3H5-A(94) + CH3CHO(35)>,
#  <ElementaryReaction: C2H3(22) + CH2CHO(21) <=> C2H2(25) + CH3CHO(35)>,
#  <ElementaryReaction: C2H3(22) + CH3CO(20) <=> C2H2(25) + CH3CHO(35)>,
#  <ElementaryReaction: C2H3(22) + C3H6(12) <=> C2H4(11) + C3H5-A(94)>,
#  <ElementaryReaction: C3H5-A(94) + CH3CHO(35) <=> C3H6(12) + CH3CO(20)>,
#  <ChebyshevReaction: C3H5-A(94) <=> C2H3(22) + CH2(23)>,
#  <ChebyshevReaction: C3H5-A(94) + O2(2) <=> S(3513)>,
#  <ChebyshevReaction: OH(15) + S(917) <=> OH(15) + S(920)>,
#  <ElementaryReaction: CH2CHO(21) + O(5) <=> CH2CO(24) + OH(15)>,
#  <ChebyshevReaction: C3H5(3498) <=> C3H5-A(94)>,
#  <ChebyshevReaction: C3H5(3498) <=> C2H3(22) + CH2(23)>,
#  <ElementaryReaction: C2H5(33) + CH3CHO(35) <=> C2H6(32) + CH2CHO(21)>,
#  <ElementaryReaction: C2H6(32) + CH3CO(20) <=> C2H5(33) + CH3CHO(35)>,
#  <ChebyshevReaction: CH2CHO(21) + CH3CHO(35) <=> C2H4O(51) + CH2CHO(21)>,
#  <ElementaryReaction: C2H(4) + CH3CO(20) <=> C2H2(25) + CH2CO(24)>,
#  <ElementaryReaction: C2H(4) + CH2CHO(21) <=> C2H2(25) + CH2CO(24)>,
#  <ElementaryReaction: CH3CHO(35) + PC4H9(182) <=> CH3CO(20) + butane(1)>,
#  <ElementaryReaction: C2H(4) + C3H6(12) <=> C2H2(25) + C3H5-A(94)>,
#  <ElementaryReaction: 2 S(186) => 2 C4H9O(217) + O2(2)>,
#  <ElementaryReaction: CH3O2(45) + S(186) => C4H9O(217) + CH3O(31) + O2(2)>,
#  <ElementaryReaction: CH3(18) + S(186) <=> C4H9O(217) + CH3O(31)>,
#  <ElementaryReaction: S(186) + SC4H9(183) <=> 2 C4H9O(217)>,
#  <ElementaryReaction: HO2(16) + SC4H9(183) <=> C4H9O(217) + OH(15)>,
#  <ElementaryReaction: CH3O2(45) + SC4H9(183) <=> C4H9O(217) + CH3O(31)>,
#  <ElementaryReaction: C2H5(33) + CH3CHO(35) <=> C4H9O(217)>,
#  <ChebyshevReaction: S(186) <=> C4H9O(217) + O(5)>,
#  <ChebyshevReaction: C4H9O(217) <=> O(5) + SC4H9(183)>,
#  <ChebyshevReaction: C4H9O(217) <=> C4H8O(766) + H(14)>,
#  <ElementaryReaction: C2H4O(703) + SC4H9(183) <=> CH2CHO(21) + butane(1)>,
#  <ElementaryReaction: C2H4O(703) + PC4H9(182) <=> CH2CHO(21) + butane(1)>,
#  <ChebyshevReaction: C2H4O(703) <=> C2H4O(51)>,
#  <ChebyshevReaction: C2H4O(51) + O2(2) <=> C2H4O(703) + O2(2)>,
#  <ChebyshevReaction: S(818) <=> C2H4O(703) + CH3CO(20)>,
#  <ChebyshevReaction: C2H4(11) + CH2O(9) <=> C2H4O(703) + CH2(23)>,
#  <ChebyshevReaction: C2H4O(703) <=> CH3CHO(35)>,
#  <ChebyshevReaction: 2 CH2O(9) <=> C2H4O(703) + O(5)>,
#  <ChebyshevReaction: C2H4(11) + CH2O(9) <=> C2H4O(703) + CH2(23)>,
#  <ChebyshevReaction: CH2CO(24) + CH2O(9) <=> C2H4O(703) + CO(6)>,
#  <ChebyshevReaction: C2H4(11) + CO2(7) <=> C2H4O(703) + CO(6)>,
#  <ChebyshevReaction: C2H4O(703) <=> CH4(10) + CO(6)>,
#  <ChebyshevReaction: C2H4O(51) + HO2(16) <=> C2H4O(703) + HO2(16)>,
#  <ChebyshevReaction: C3H5O(70) + CH2O(9) <=> C2H4O(703) + CH3CO(20)>,
#  <ElementaryReaction: C2H4O(703) + HO2(16) <=> CH2CHO(21) + H2O2(17)>,
#  <ElementaryReaction: C2H4O(703) + OH(15) <=> CH2CHO(21) + H2O(8)>,
#  <ElementaryReaction: C2H4O(703) + HCO(19) <=> CH2CHO(21) + CH2O(9)>,
#  <ElementaryReaction: C2H4O(703) + CH2CHO(21) <=> CH2CHO(21) + CH3CHO(35)>,
#  <ElementaryReaction: C2H4O(703) + CH3CO(20) <=> CH2CHO(21) + CH3CHO(35)>,
#  <ElementaryReaction: C2H3(22) + C2H4O(703) <=> C2H4(11) + CH2CHO(21)>,
#  <ElementaryReaction: C2H4O(703) + H(14) <=> CH2CHO(21) + H2(13)>,
#  <ElementaryReaction: C2H4O(703) + C3H5-A(94) <=> C3H6(12) + CH2CHO(21)>,
#  <ChebyshevReaction: C2H4O(51) + CH3O2(45) <=> C2H4O(703) + CH3O2(45)>,
#  <ChebyshevReaction: CH2CHO(21) + CH3CHO(35) <=> C2H4O(703) + CH2CHO(21)>,
#  <ElementaryReaction: C2H4O(703) + CH3(18) <=> CH2CHO(21) + CH4(10)>,
#  <ChebyshevReaction: C2H4O(51) + C2H5O2(47) <=> C2H4O(703) + C2H5O2(47)>,
#  <ChebyshevReaction: C2H4(11) + O(5) <=> C2H4O(703)>,
#  <ChebyshevReaction: C2H4(11) + O(5) <=> C2H4O(51)>,
#  <ChebyshevReaction: C2H4(11) + O(5) <=> CH3CHO(35)>,
#  <ChebyshevReaction: C2H4O(51) <=> CH2(23) + CH2O(9)>,
#  <ChebyshevReaction: C2H4O(51) <=> CH4(10) + CO(6)>,
#  <ChebyshevReaction: CH3CHO(35) <=> CH2(23) + CH2O(9)>,
#  <ChebyshevReaction: CH4(10) + CO(6) <=> CH2(23) + CH2O(9)>,
#  <ChebyshevReaction: C2H4O(703) <=> CH2CHO(21) + H(14)>,
#  <ChebyshevReaction: C2H4O(703) <=> CH2(23) + CH2O(9)>,
#  <ElementaryReaction: C4H8(748) + HO2(16) <=> O2(2) + SC4H9(183)>,
#  <ChebyshevReaction: SC4H9(183) <=> C4H8(748) + H(14)>,
#  <ChebyshevReaction: 2 C2H4(11) <=> C4H8(748)>,
#  <ChebyshevReaction: S(223) <=> C4H8(748) + HO2(16)>,
#  <ChebyshevReaction: C4H8(748) <=> C4H8(189)>,
#  <ElementaryReaction: C4H8(748) + HO2(16) <=> O2(2) + PC4H9(182)>,
#  <ChebyshevReaction: PC4H9(182) <=> C4H8(748) + H(14)>,
#  <ChebyshevReaction: S(219) <=> C4H8(748) + HO2(16)>,
#  <ChebyshevReaction: S(220) <=> C4H8(748) + HO2(16)>,
#  <ChebyshevReaction: C4H8(748) <=> C4H8(188)>,
#  <ChebyshevReaction: C2H4(11) + C3H6(12) <=> C4H8(748) + CH2(23)>,
#  <ChebyshevReaction: C2H4(11) + C3H6(12) <=> C4H8(748) + CH2(23)>,
#  <ChebyshevReaction: C3H6(12) + CH2O(9) <=> C4H8(748) + O(5)>,
#  <ChebyshevReaction: C2H4(11) + CH3CHO(35) <=> C4H8(748) + O(5)>,
#  <ChebyshevReaction: C4H8(776) <=> C4H8(748)>,
#  <ChebyshevReaction: C3H6(12) + CH2CO(24) <=> C4H8(748) + CO(6)>,
#  <ChebyshevReaction: C4H8O(214) <=> C4H8(748) + O(5)>,
#  <ElementaryReaction: C2H5(33) + C4H8(748) <=> C2H4(11) + SC4H9(183)>,
#  <ElementaryReaction: C4H8(748) + NC3H7(92) <=> C3H6(12) + SC4H9(183)>,
#  <ElementaryReaction: C4H8(748) + IC3H7(93) <=> C3H6(12) + SC4H9(183)>,
#  <ElementaryReaction: C4H8(748) + HCO(19) <=> CO(6) + SC4H9(183)>,
#  <ElementaryReaction: C4H8(748) + CH3O(31) <=> CH2O(9) + SC4H9(183)>,
#  <ElementaryReaction: C4H8(748) + SC4H9(183) <=> C4H8(189) + SC4H9(183)>,
#  <ElementaryReaction: C4H8(748) + PC4H9(182) <=> C4H8(188) + SC4H9(183)>,
#  <ElementaryReaction: C4H8(748) + SC4H9(183) <=> C4H8(188) + SC4H9(183)>,
#  <ElementaryReaction: C2H5(33) + C4H8(748) <=> C2H4(11) + PC4H9(182)>,
#  <ElementaryReaction: C4H8(748) + NC3H7(92) <=> C3H6(12) + PC4H9(182)>,
#  <ElementaryReaction: C4H8(748) + IC3H7(93) <=> C3H6(12) + PC4H9(182)>,
#  <ElementaryReaction: C4H8(748) + CH3CO(20) <=> CH2CO(24) + SC4H9(183)>,
#  <ElementaryReaction: C4H8(748) + CH2CHO(21) <=> CH2CO(24) + SC4H9(183)>,
#  <ElementaryReaction: C4H8(748) + SC4H9(183) <=> C4H8(189) + PC4H9(182)>,
#  <ElementaryReaction: C4H8(748) + PC4H9(182) <=> C4H8(188) + PC4H9(182)>,
#  <ElementaryReaction: C4H8(748) + SC4H9(183) <=> C4H8(188) + PC4H9(182)>,
#  <ElementaryReaction: C4H8(748) + CH3O(31) <=> CH2O(9) + PC4H9(182)>,
#  <ElementaryReaction: C4H8(748) + HCO(19) <=> CO(6) + PC4H9(182)>,
#  <ChebyshevReaction: 2 C2H4(11) <=> C3H6(12) + CH2(23)>,
#  <ChebyshevReaction: C4H8(189) <=> C3H6(12) + CH2(23)>,
#  <ChebyshevReaction: C4H8(188) <=> C3H6(12) + CH2(23)>,
#  <ChebyshevReaction: C4H8(776) <=> C3H6(12) + CH2(23)>,
#  <ChebyshevReaction: C2H4O(703) <=> CH3(18) + HCO(19)>,
#  <ChebyshevReaction: C2H4O(703) <=> CH3CO(20) + H(14)>,
#  <ElementaryReaction: C2H4O(703) + C2H5(33) <=> C2H6(32) + CH2CHO(21)>,
#  <ElementaryReaction: C4H8O(766) + HO2(16) <=> C4H9O(217) + O2(2)>,
#  <ElementaryReaction: C2H4O(703) + O2(2) <=> CH2CHO(21) + HO2(16)>,
#  <ChebyshevReaction: C4H8(748) <=> C3H6(12) + CH2(23)>,
#  <ChebyshevReaction: C3H6(689) <=> C3H6(12)>,
#  <ChebyshevReaction: CH2CO(24) + H(14) <=> CH2(23) + HCO(19)>,
#  <ElementaryReaction: C4H7(190) + H(14) <=> C4H8(188)>,
#  <ElementaryReaction: C4H8(188) + O2(2) <=> C4H7(190) + HO2(16)>,
#  <ElementaryReaction: C4H8(188) + O(5) <=> C4H7(190) + OH(15)>,
#  <ElementaryReaction: C4H8(189) + O(5) <=> C4H7(190) + OH(15)>,
#  <ElementaryReaction: C4H8(188) + H(14) <=> C4H7(190) + H2(13)>,
#  <ElementaryReaction: C4H8(188) + OH(15) <=> C4H7(190) + H2O(8)>,
#  <ElementaryReaction: C4H8(188) + CH3(18) <=> C4H7(190) + CH4(10)>,
#  <ElementaryReaction: C4H8(188) + HO2(16) <=> C4H7(190) + H2O2(17)>,
#  <ElementaryReaction: C3H5-A(94) + C4H8(188) <=> C3H6(12) + C4H7(190)>,
#  <ElementaryReaction: C4H7(190) + H(14) <=> C4H8(189)>,
#  <ElementaryReaction: C4H8(189) + O2(2) <=> C4H7(190) + HO2(16)>,
#  <ElementaryReaction: C4H8(189) + H(14) <=> C4H7(190) + H2(13)>,
#  <ElementaryReaction: C4H8(189) + OH(15) <=> C4H7(190) + H2O(8)>,
#  <ElementaryReaction: C4H8(189) + CH3(18) <=> C4H7(190) + CH4(10)>,
#  <ElementaryReaction: C4H8(189) + HO2(16) <=> C4H7(190) + H2O2(17)>,
#  <ElementaryReaction: C2H5(33) + C4H7(190) <=> C2H4(11) + C4H8(188)>,
#  <ElementaryReaction: C4H7(190) + CH3O(31) <=> C4H8(188) + CH2O(9)>,
#  <ElementaryReaction: C2H5(33) + C4H7(190) <=> C2H4(11) + C4H8(189)>,
#  <ElementaryReaction: C4H7(190) + NC3H7(92) <=> C3H6(12) + C4H8(189)>,
#  <ElementaryReaction: C4H7(190) + IC3H7(93) <=> C3H6(12) + C4H8(189)>,
#  <ElementaryReaction: C4H7(190) + NC3H7(92) <=> C3H6(12) + C4H8(188)>,
#  <ElementaryReaction: C4H7(190) + IC3H7(93) <=> C3H6(12) + C4H8(188)>,
#  <ElementaryReaction: C4H7(190) + CH3CO(20) <=> C4H8(189) + CH2CO(24)>,
#  <ElementaryReaction: C4H7(190) + CH2CHO(21) <=> C4H8(189) + CH2CO(24)>,
#  <ElementaryReaction: C4H7(190) + CH3CO(20) <=> C4H8(188) + CH2CO(24)>,
#  <ElementaryReaction: C4H7(190) + CH2CHO(21) <=> C4H8(188) + CH2CO(24)>,
#  <ElementaryReaction: C4H7(190) + HCO(19) <=> C4H8(189) + CO(6)>,
#  <ElementaryReaction: C4H7(190) + HCO(19) <=> C4H8(188) + CO(6)>,
#  <ElementaryReaction: C4H7(190) + CH3O(31) <=> C4H8(189) + CH2O(9)>,
#  <ElementaryReaction: C4H7(190) + SC4H9(183) <=> 2 C4H8(189)>,
#  <ElementaryReaction: C4H7(190) + PC4H9(182) <=> C4H8(188) + C4H8(189)>,
#  <ElementaryReaction: C4H7(190) + SC4H9(183) <=> C4H8(188) + C4H8(189)>,
#  <ElementaryReaction: C4H7(190) + SC4H9(183) <=> C4H8(188) + C4H8(189)>,
#  <ElementaryReaction: C4H7(190) + PC4H9(182) <=> 2 C4H8(188)>,
#  <ElementaryReaction: C4H7(190) + SC4H9(183) <=> 2 C4H8(188)>,
#  <ElementaryReaction: C2H3(22) + C4H7(190) <=> C2H2(25) + C4H8(189)>,
#  <ElementaryReaction: C2H3(22) + C4H7(190) <=> C2H2(25) + C4H8(188)>,
#  <ElementaryReaction: C2H6(32) + C4H7(190) <=> C2H5(33) + C4H8(189)>,
#  <ElementaryReaction: C2H6(32) + C4H7(190) <=> C2H5(33) + C4H8(188)>,
#  <ElementaryReaction: C2H4O(703) + C4H7(190) <=> C4H8(189) + CH2CHO(21)>,
#  <ElementaryReaction: C4H8(189) + CH2CHO(21) <=> C4H7(190) + CH3CHO(35)>,
#  <ElementaryReaction: C2H4O(703) + C4H7(190) <=> C4H8(188) + CH2CHO(21)>,
#  <ElementaryReaction: C4H8(188) + CH2CHO(21) <=> C4H7(190) + CH3CHO(35)>,
#  <ElementaryReaction: C4H8(189) + SC4H9(183) <=> C4H7(190) + butane(1)>,
#  <ElementaryReaction: C4H8(188) + SC4H9(183) <=> C4H7(190) + butane(1)>,
#  <ElementaryReaction: C3H6(12) + C4H7(190) <=> C3H5-A(94) + C4H8(189)>,
#  <ElementaryReaction: C4H8(189) + PC4H9(182) <=> C4H7(190) + butane(1)>,
#  <ElementaryReaction: C4H8(188) + PC4H9(182) <=> C4H7(190) + butane(1)>,
#  <ChebyshevReaction: 2 C2H4(11) <=> C4H7(190) + H(14)>,
#  <ChebyshevReaction: C4H8(776) <=> C4H7(190) + H(14)>,
#  <ChebyshevReaction: C4H8(748) <=> C4H7(190) + H(14)>,
#  <ElementaryReaction: C4H8(189) + HCO(19) <=> C4H7(190) + CH2O(9)>,
#  <ElementaryReaction: C4H8(188) + HCO(19) <=> C4H7(190) + CH2O(9)>,
#  <ElementaryReaction: C4H8(748) + O2(2) <=> C4H7(190) + HO2(16)>,
#  <ElementaryReaction: C4H8(748) + HO2(16) <=> C4H7(190) + H2O2(17)>,
#  <ElementaryReaction: C4H8(748) + CH2(23) <=> C4H7(190) + CH3(18)>,
#  <ElementaryReaction: C4H8(188) + CH2(23) <=> C4H7(190) + CH3(18)>,
#  <ElementaryReaction: C4H8(189) + CH2(23) <=> C4H7(190) + CH3(18)>,
#  <ElementaryReaction: C2H(4) + C4H8(748) <=> C2H2(25) + C4H7(190)>,
#  <ElementaryReaction: C2H(4) + C4H8(188) <=> C2H2(25) + C4H7(190)>,
#  <ElementaryReaction: C2H(4) + C4H8(189) <=> C2H2(25) + C4H7(190)>,
#  <ElementaryReaction: C4H8(748) + SC4H9(183) <=> C4H7(190) + butane(1)>,
#  <ElementaryReaction: C4H8(748) + PC4H9(182) <=> C4H7(190) + butane(1)>,
#  <ElementaryReaction: C4H8(748) + OH(15) <=> C4H7(190) + H2O(8)>,
#  <ElementaryReaction: C4H8(748) + HCO(19) <=> C4H7(190) + CH2O(9)>,
#  <ElementaryReaction: C4H8(748) + CH3(18) <=> C4H7(190) + CH4(10)>,
#  <ElementaryReaction: C2H3(22) + C4H8(748) <=> C2H4(11) + C4H7(190)>,
#  <ElementaryReaction: C2H3(22) + C4H8(188) <=> C2H4(11) + C4H7(190)>,
#  <ElementaryReaction: C2H4(11) + C4H7(190) <=> C2H3(22) + C4H8(189)>,
#  <ElementaryReaction: C3H5-A(94) + C4H8(748) <=> C3H6(12) + C4H7(190)>,
#  <ElementaryReaction: C4H8(748) + H(14) <=> C4H7(190) + H2(13)>,
#  <ElementaryReaction: C4H7(190) + C4H8(748) <=> C4H7(190) + C4H8(189)>,
#  <ElementaryReaction: C4H7(190) + C4H8(188) <=> C4H7(190) + C4H8(189)>,
#  <ElementaryReaction: C4H7(190) + C4H8(748) <=> C4H7(190) + C4H8(188)>,
#  <ElementaryReaction: C4H8(748) + CH2CHO(21) <=> C4H7(190) + CH3CHO(35)>,
#  <ElementaryReaction: C4H8(748) + CH3CO(20) <=> C4H7(190) + CH3CHO(35)>,
#  <ElementaryReaction: C4H8(188) + CH3CO(20) <=> C4H7(190) + CH3CHO(35)>,
#  <ElementaryReaction: C4H7(190) + CH3CHO(35) <=> C4H8(189) + CH3CO(20)>,
#  <ElementaryReaction: C2H5(33) + C4H8(748) <=> C2H6(32) + C4H7(190)>,
#  <ChebyshevReaction: C4H7(190) + O2(2) <=> S(4243)>,
#  <ChebyshevReaction: C4H7(190) + O2(2) <=> S(4243)>,
#  <ChebyshevReaction: C4H7(190) + O2(2) <=> S(4244)>,
#  <ChebyshevReaction: C4H7(190) + O2(2) <=> S(4244)>,
#  <ChebyshevReaction: S(4243) <=> S(4244)>,
#  <ElementaryReaction: 2 C4H7(190) <=> C4H6(194) + C4H8(188)>,
#  <ElementaryReaction: C4H6(194) + H(14) <=> C4H7(190)>,
#  <ElementaryReaction: C3H5-A(94) + C4H7(190) <=> C3H6(12) + C4H6(194)>,
#  <ElementaryReaction: C4H7(190) + O2(2) <=> C4H6(194) + HO2(16)>,
#  <ElementaryReaction: C4H7(190) + H(14) <=> C4H6(194) + H2(13)>,
#  <ElementaryReaction: C2H5(33) + C4H7(190) <=> C2H6(32) + C4H6(194)>,
#  <ElementaryReaction: C2H3(22) + C4H7(190) <=> C2H4(11) + C4H6(194)>,
#  <PlogReaction: C4H6(194) + H(14) <=> C2H3(22) + C2H4(11)>,
#  <ElementaryReaction: C4H6(194) + O(5) <=> C2H2(25) + C2H4O(51)>,
#  <ElementaryReaction: C4H6(194) + OH(15) <=> C3H5-A(94) + CH2O(9)>,
#  <PlogReaction: 2 C2H3(22) <=> C4H6(194)>,
#  <ChebyshevReaction: C2H2(25) + C2H4(11) <=> C4H6(194)>,
#  <ElementaryReaction: C4H7(190) + HO2(16) <=> C4H6(194) + H2O2(17)>,
#  <ElementaryReaction: C4H7(190) + CH3(18) <=> C4H6(194) + CH4(10)>,
#  <ElementaryReaction: 2 C4H7(190) <=> C4H6(194) + C4H8(189)>,
#  <ChebyshevReaction: C4H6(194) + HO2(16) <=> S(4243)>,
#  <ChebyshevReaction: C4H6(194) + HO2(16) <=> S(4244)>,
#  <ElementaryReaction: C4H7(190) + SC4H9(183) <=> C4H6(194) + butane(1)>,
#  <ElementaryReaction: C4H7(190) + PC4H9(182) <=> C4H6(194) + butane(1)>,
#  <ElementaryReaction: C4H7(190) + OH(15) <=> C4H6(194) + H2O(8)>,
#  <ElementaryReaction: C4H7(190) + HCO(19) <=> C4H6(194) + CH2O(9)>,
#  <ElementaryReaction: C4H7(190) + CH2CHO(21) <=> C4H6(194) + CH3CHO(35)>,
#  <ElementaryReaction: C4H7(190) + CH3CO(20) <=> C4H6(194) + CH3CHO(35)>,
#  <ElementaryReaction: S(787) + SC4H9(183) <=> S(229) + butane(1)>,
#  <ElementaryReaction: PC4H9(182) + S(787) <=> S(229) + butane(1)>,
#  <ElementaryReaction: S(787) + SC4H9(183) <=> S(244) + butane(1)>,
#  <ElementaryReaction: PC4H9(182) + S(787) <=> S(244) + butane(1)>,
#  <ElementaryReaction: S(787) + SC4H9(183) <=> S(225) + butane(1)>,
#  <ElementaryReaction: PC4H9(182) + S(787) <=> S(225) + butane(1)>,
#  <ElementaryReaction: S(787) + SC4H9(183) <=> S(238) + butane(1)>,
#  <ElementaryReaction: PC4H9(182) + S(787) <=> S(238) + butane(1)>,
#  <ElementaryReaction: HO2(16) + S(229) <=> O2(2) + S(787)>,
#  <ElementaryReaction: HO2(16) + S(225) <=> O2(2) + S(787)>,
#  <ElementaryReaction: H2O2(17) + S(225) <=> HO2(16) + S(787)>,
#  <ElementaryReaction: OH(15) + S(787) <=> H2O(8) + S(229)>,
#  <ElementaryReaction: OH(15) + S(787) <=> H2O(8) + S(225)>,
#  <ElementaryReaction: HCO(19) + S(787) <=> CH2O(9) + S(229)>,
#  <ElementaryReaction: HCO(19) + S(787) <=> CH2O(9) + S(225)>,
#  <ElementaryReaction: C4H7(190) + S(787) <=> C4H8(189) + S(229)>,
#  <ElementaryReaction: C4H7(190) + S(787) <=> C4H8(189) + S(225)>,
#  <ElementaryReaction: C4H8(188) + S(225) <=> C4H7(190) + S(787)>,
#  <ElementaryReaction: H2O2(17) + S(229) <=> HO2(16) + S(787)>,
#  <ElementaryReaction: C4H8(188) + S(229) <=> C4H7(190) + S(787)>,
#  <ElementaryReaction: CH2CHO(21) + S(787) <=> CH3CHO(35) + S(229)>,
#  <ElementaryReaction: CH3CO(20) + S(787) <=> CH3CHO(35) + S(229)>,
#  <ElementaryReaction: CH2CHO(21) + S(787) <=> CH3CHO(35) + S(225)>,
#  <ElementaryReaction: CH3CO(20) + S(787) <=> CH3CHO(35) + S(225)>,
#  <ElementaryReaction: C2H3(22) + S(787) <=> C2H4(11) + S(229)>,
#  <ElementaryReaction: C2H3(22) + S(787) <=> C2H4(11) + S(225)>,
#  <ElementaryReaction: C3H5-A(94) + S(787) <=> C3H6(12) + S(225)>,
#  <ElementaryReaction: C3H5-A(94) + S(787) <=> C3H6(12) + S(229)>,
#  <ElementaryReaction: CH4(10) + S(225) <=> CH3(18) + S(787)>,
#  <ElementaryReaction: HO2(16) + S(219) <=> S(787)>,
#  <ElementaryReaction: HO2(16) + S(223) <=> S(787)>,
#  <ElementaryReaction: H(14) + S(225) <=> S(787)>,
#  <ElementaryReaction: H(14) + S(229) <=> S(787)>,
#  <ElementaryReaction: H(14) + S(244) <=> S(787)>,
#  <ElementaryReaction: H(14) + S(238) <=> S(787)>,
#  <ElementaryReaction: H2O2(17) + S(244) <=> HO2(16) + S(787)>,
#  <ElementaryReaction: HO2(16) + S(787) <=> H2O2(17) + S(238)>,
#  <ElementaryReaction: HO2(16) + S(244) <=> O2(2) + S(787)>,
#  <ElementaryReaction: HO2(16) + S(238) <=> O2(2) + S(787)>,
#  <ElementaryReaction: CH3O(31) + S(225) <=> CH2O(9) + S(787)>,
#  <ElementaryReaction: CH3O(31) + S(229) <=> CH2O(9) + S(787)>,
#  <ElementaryReaction: CH3O(31) + S(244) <=> CH2O(9) + S(787)>,
#  <ElementaryReaction: CH3O(31) + S(238) <=> CH2O(9) + S(787)>,
#  <ElementaryReaction: S(225) + SC4H9(183) <=> C4H8(189) + S(787)>,
#  <ElementaryReaction: S(229) + SC4H9(183) <=> C4H8(189) + S(787)>,
#  <ElementaryReaction: S(244) + SC4H9(183) <=> C4H8(189) + S(787)>,
#  <ElementaryReaction: S(238) + SC4H9(183) <=> C4H8(189) + S(787)>,
#  <ElementaryReaction: PC4H9(182) + S(225) <=> C4H8(188) + S(787)>,
#  <ElementaryReaction: PC4H9(182) + S(229) <=> C4H8(188) + S(787)>,
#  <ElementaryReaction: PC4H9(182) + S(244) <=> C4H8(188) + S(787)>,
#  <ElementaryReaction: PC4H9(182) + S(238) <=> C4H8(188) + S(787)>,
#  <ElementaryReaction: S(225) + SC4H9(183) <=> C4H8(188) + S(787)>,
#  <ElementaryReaction: S(229) + SC4H9(183) <=> C4H8(188) + S(787)>,
#  <ElementaryReaction: S(244) + SC4H9(183) <=> C4H8(188) + S(787)>,
#  <ElementaryReaction: S(238) + SC4H9(183) <=> C4H8(188) + S(787)>,
#  <ElementaryReaction: C2H4O(703) + S(225) <=> CH2CHO(21) + S(787)>,
#  <ElementaryReaction: C2H4O(703) + S(229) <=> CH2CHO(21) + S(787)>,
#  <ElementaryReaction: C2H4O(703) + S(244) <=> CH2CHO(21) + S(787)>,
#  <ElementaryReaction: C2H4O(703) + S(238) <=> CH2CHO(21) + S(787)>,
#  <ElementaryReaction: CH2CHO(21) + S(787) <=> CH3CHO(35) + S(244)>,
#  <ElementaryReaction: CH3CHO(35) + S(238) <=> CH2CHO(21) + S(787)>,
#  <ElementaryReaction: CH3CO(20) + S(225) <=> CH2CO(24) + S(787)>,
#  <ElementaryReaction: CH3CO(20) + S(229) <=> CH2CO(24) + S(787)>,
#  <ElementaryReaction: CH3CO(20) + S(244) <=> CH2CO(24) + S(787)>,
#  <ElementaryReaction: CH3CO(20) + S(238) <=> CH2CO(24) + S(787)>,
#  <ElementaryReaction: CH2CHO(21) + S(225) <=> CH2CO(24) + S(787)>,
#  <ElementaryReaction: CH2CHO(21) + S(229) <=> CH2CO(24) + S(787)>,
#  <ElementaryReaction: CH2CHO(21) + S(244) <=> CH2CO(24) + S(787)>,
#  <ElementaryReaction: CH2CHO(21) + S(238) <=> CH2CO(24) + S(787)>,
#  <ElementaryReaction: HCO(19) + S(225) <=> CO(6) + S(787)>,
#  <ElementaryReaction: HCO(19) + S(229) <=> CO(6) + S(787)>,
#  <ElementaryReaction: HCO(19) + S(244) <=> CO(6) + S(787)>,
#  <ElementaryReaction: HCO(19) + S(238) <=> CO(6) + S(787)>,
#  <ElementaryReaction: C2H5(33) + S(225) <=> C2H4(11) + S(787)>,
#  <ElementaryReaction: C2H5(33) + S(229) <=> C2H4(11) + S(787)>,
#  <ElementaryReaction: C2H5(33) + S(244) <=> C2H4(11) + S(787)>,
#  <ElementaryReaction: C2H5(33) + S(238) <=> C2H4(11) + S(787)>,
#  <ElementaryReaction: NC3H7(92) + S(225) <=> C3H6(12) + S(787)>,
#  <ElementaryReaction: NC3H7(92) + S(229) <=> C3H6(12) + S(787)>,
#  <ElementaryReaction: NC3H7(92) + S(244) <=> C3H6(12) + S(787)>,
#  <ElementaryReaction: NC3H7(92) + S(238) <=> C3H6(12) + S(787)>,
#  <ElementaryReaction: IC3H7(93) + S(225) <=> C3H6(12) + S(787)>,
#  <ElementaryReaction: IC3H7(93) + S(229) <=> C3H6(12) + S(787)>,
#  <ElementaryReaction: IC3H7(93) + S(244) <=> C3H6(12) + S(787)>,
#  <ElementaryReaction: IC3H7(93) + S(238) <=> C3H6(12) + S(787)>,
#  <ElementaryReaction: S(229) + S(787) <=> S(225) + S(787)>,
#  <ElementaryReaction: S(244) + S(787) <=> S(229) + S(787)>,
#  <ElementaryReaction: S(238) + S(787) <=> S(229) + S(787)>,
#  <ElementaryReaction: S(244) + S(787) <=> S(225) + S(787)>,
#  <ElementaryReaction: S(238) + S(787) <=> S(225) + S(787)>,
#  <ElementaryReaction: C3H6(12) + S(244) <=> C3H5-A(94) + S(787)>,
#  <ElementaryReaction: C3H6(12) + S(238) <=> C3H5-A(94) + S(787)>,
#  <ElementaryReaction: C4H8(748) + S(225) <=> C4H7(190) + S(787)>,
#  <ElementaryReaction: C4H8(748) + S(229) <=> C4H7(190) + S(787)>,
#  <ElementaryReaction: C4H8(748) + S(244) <=> C4H7(190) + S(787)>,
#  <ElementaryReaction: C4H8(748) + S(238) <=> C4H7(190) + S(787)>,
#  <ElementaryReaction: C4H8(188) + S(244) <=> C4H7(190) + S(787)>,
#  <ElementaryReaction: C4H8(188) + S(238) <=> C4H7(190) + S(787)>,
#  <ElementaryReaction: C4H8(189) + S(244) <=> C4H7(190) + S(787)>,
#  <ElementaryReaction: C4H8(189) + S(238) <=> C4H7(190) + S(787)>,
#  <ElementaryReaction: C4H7(190) + S(225) <=> C4H6(194) + S(787)>,
#  <ElementaryReaction: C4H7(190) + S(229) <=> C4H6(194) + S(787)>,
#  <ElementaryReaction: C4H7(190) + S(244) <=> C4H6(194) + S(787)>,
#  <ElementaryReaction: C4H7(190) + S(238) <=> C4H6(194) + S(787)>,
#  <ChebyshevReaction: C2H2(25) + C2H4(11) <=> C4H6(2530)>,
#  <ChebyshevReaction: C4H6(2530) <=> C4H6(194)>,
#  <ElementaryReaction: C4H7(190) + CH2(23) <=> C4H6(194) + CH3(18)>,
#  <ElementaryReaction: C2H(4) + C4H7(190) <=> C2H2(25) + C4H6(194)>,
#  <ElementaryReaction: O(5) + S(777) <=> S(229)>,
#  <ElementaryReaction: S(777) + SC4H9(183) <=> S(252) + butane(1)>,
#  <ElementaryReaction: PC4H9(182) + S(777) <=> S(252) + butane(1)>,
#  <ElementaryReaction: O2(2) + S(777) <=> HO2(16) + S(252)>,
#  <ElementaryReaction: OH(15) + S(777) <=> H2O(8) + S(252)>,
#  <ElementaryReaction: C4H7(190) + S(777) <=> C4H8(189) + S(252)>,
#  <ElementaryReaction: HO2(16) + S(777) <=> H2O2(17) + S(252)>,
#  <ElementaryReaction: HCO(19) + S(777) <=> CH2O(9) + S(252)>,
#  <ElementaryReaction: C2H3(22) + S(777) <=> C2H4(11) + S(252)>,
#  <ElementaryReaction: C3H5-A(94) + S(777) <=> C3H6(12) + S(252)>,
#  <ElementaryReaction: C4H7(190) + S(777) <=> C4H8(188) + S(252)>,
#  <ElementaryReaction: CH2CHO(21) + S(777) <=> CH3CHO(35) + S(252)>,
#  <ElementaryReaction: CH3CO(20) + S(777) <=> CH3CHO(35) + S(252)>,
#  <ElementaryReaction: CH3(18) + S(777) <=> CH4(10) + S(252)>,
#  <ElementaryReaction: C4H8(748) + S(777) <=> S(252) + SC4H9(183)>,
#  <ElementaryReaction: H(14) + S(777) <=> H2(13) + S(252)>,
#  <ElementaryReaction: O(5) + S(777) <=> OH(15) + S(252)>,
#  <ElementaryReaction: C2H5(33) + S(777) <=> C2H6(32) + S(252)>,
#  <ElementaryReaction: CH2(23) + S(777) <=> CH3(18) + S(252)>,
#  <ElementaryReaction: OH(15) + S(777) <=> S(787)>,
#  <ElementaryReaction: S(225) + S(777) <=> S(252) + S(787)>,
#  <ElementaryReaction: S(229) + S(777) <=> S(252) + S(787)>,
#  <ElementaryReaction: S(244) + S(777) <=> S(252) + S(787)>,
#  <ElementaryReaction: S(238) + S(777) <=> S(252) + S(787)>,
#  <ChebyshevReaction: S(777) <=> O(5) + S(223)>,
#  <ChebyshevReaction: S(777) <=> H(14) + S(252)>,
#  <ChebyshevReaction: S(777) <=> S(5093)>,
#  <ChebyshevReaction: S(777) <=> OH(15) + S(5151)>,
#  <ChebyshevReaction: S(5093) <=> OH(15) + S(5151)>,
#  <ChebyshevReaction: S(5093) <=> O(5) + S(223)>,
#  <ChebyshevReaction: S(5093) <=> H(14) + S(252)>,
#  <ElementaryReaction: C2H5(33) + HO2(16) <=> C2H5O(49) + OH(15)>,
#  <ElementaryReaction: C2H5(33) + CH3O2(45) <=> C2H5O(49) + CH3O(31)>,
#  <ElementaryReaction: C2H5O(49) + O2(2) <=> CH3CHO(35) + HO2(16)>,
#  <ElementaryReaction: CH2O(9) + CH3(18) <=> C2H5O(49)>,
#  <ElementaryReaction: CH3CHO(35) + H(14) <=> C2H5O(49)>,
#  <ElementaryReaction: C2H4(11) + C2H5O2(47) <=> C2H4O(51) + C2H5O(49)>,
#  <ElementaryReaction: C2H5O2(47) + S(186) => C2H5O(49) + C4H9O(217) + O2(2)>,
#  <ElementaryReaction: C2H5(33) + S(186) <=> C2H5O(49) + C4H9O(217)>,
#  <ElementaryReaction: C2H5O(49) + H(14) <=> CH3CHO(35) + H2(13)>,
#  <ElementaryReaction: C2H5O(49) + OH(15) <=> CH3CHO(35) + H2O(8)>,
#  <ElementaryReaction: C2H5O(49) + CO(6) <=> C2H5(33) + CO2(7)>,
#  <ElementaryReaction: C2H5O2(47) + H(14) <=> C2H5O(49) + OH(15)>,
#  <ElementaryReaction: C2H5O2(47) + O(5) <=> C2H5O(49) + O2(2)>,
#  <ElementaryReaction: C2H5O2(47) + CO(6) <=> C2H5O(49) + CO2(7)>,
#  <ElementaryReaction: C2H5O2(47) + CH3(18) <=> C2H5O(49) + CH3O(31)>,
#  <ElementaryReaction: C2H5(33) + C2H5O2(47) <=> 2 C2H5O(49)>,
#  <ElementaryReaction: 2 C2H5O2(47) <=> 2 C2H5O(49) + O2(2)>,
#  <ChebyshevReaction: C2H5O2(47) <=> C2H5O(49) + O(5)>,
#  <ElementaryReaction: C2H5O(49) + SC4H9(183) <=> CH3CHO(35) + butane(1)>,
#  <ElementaryReaction: C2H5O(49) + PC4H9(182) <=> CH3CHO(35) + butane(1)>,
#  <ElementaryReaction: C2H5O(49) + HO2(16) <=> CH3CHO(35) + H2O2(17)>,
#  <ElementaryReaction: C2H5O(49) + HCO(19) <=> CH2O(9) + CH3CHO(35)>,
#  <ElementaryReaction: C2H3(22) + C2H5O(49) <=> C2H4(11) + CH3CHO(35)>,
#  <ElementaryReaction: C2H5O(49) + C3H5-A(94) <=> C3H6(12) + CH3CHO(35)>,
#  <ElementaryReaction: C2H5O(49) + C4H7(190) <=> C4H8(189) + CH3CHO(35)>,
#  <ElementaryReaction: C2H5O(49) + C4H7(190) <=> C4H8(188) + CH3CHO(35)>,
#  <ElementaryReaction: C2H5O(49) + CH2CHO(21) <=> 2 CH3CHO(35)>,
#  <ElementaryReaction: C2H5O(49) + CH3CO(20) <=> 2 CH3CHO(35)>,
#  <ChebyshevReaction: 2 CH3CHO(35) <=> C2H5O(49) + CH2CHO(21)>,
#  ...]

# %%
len(identical_rxns)

# %%
print(len(reactions1), len(reactions2))

# %%
reactions1[0].reactants == reactions1[0].reactants

# %%
reactions1[0].reaction_type

# %%
reactions1[0].rate.activation_energy

# %%
dir(reactions1[0])

# %%
a= {'A': 0, 'B': 1}
b= {'A': 0, 'B': 2}
a == b

# %%
rtype = set()
for rxn in reactions1:
    rtype.add(rxn.reaction_type)
    if rxn.reaction_type == 4:
#         print(dir(rxn))
        print(dir(rxn.falloff))
        print(rxn.falloff.parameters)
#         print(type(rxn.rate))
        break
# print(rtype)
# Out:
# ['__call__', '__class__', '__delattr__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__setstate__', '__sizeof__', '__str__', '__subclasshook__', 'falloff_type', 'parameters', 'type']
# [5.e-01 1.e-30 1.e+30 0.e+00]

# %%
4: cantera._cantera.FalloffReaction
5: cantera._cantera.PlogReaction
6: cantera._cantera.ChebyshevReaction
